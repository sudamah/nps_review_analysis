# %%
from transformers import AutoTokenizer, AutoModel
import torch
import pandas as pd
import numpy as np
import re
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import warnings
from wordcloud import WordCloud, STOPWORDS

warnings.filterwarnings("ignore")

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
model = AutoModel.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0]  # First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min = 1e-9)


def embeding_calc(sentences):

    # tokenizing
    encoded_input = tokenizer(sentences, padding = True, truncation = True, return_tensors = 'pt')

    # passing though model
    with torch.no_grad():
        model_output = model(**encoded_input)

    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    return sentence_embeddings

# %%
result = embeding_calc(['balanced sound','good sound'])

# %%
len(result)
# Out:
# 2

# %%
score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))

# %%
score[0][0]
# Out:
# 0.7417778

# %%
def similarity_calc(input1,input2):
    result = embeding_calc([input1,input2])
    score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))
    return score[0][0]

# %%
similarity_calc('balanced sound','poor bose')
# Out:
# 0.16619003

# %% [markdown]
# # Data processing

# %%
df = pd.read_csv('/home/heptagon/Desktop/nps_review_analysis/bank_detail_review_sentiments.csv')

# %%
df.shape
# Out:
# (1717, 4)

# %%
df.head()
# Out:
#                                             comments  \
# 0  I truly enjoyed Ms Jennifer at the Jasper bran...
# 1  Nice service and I can testify they have one o...
# 2  The staff there are always helpful and willing...
# 3  Great bank very good customer service In and o...
# 4  The Nederland branch is the best I am always t...
#
#                                  topic sentiment          type
# 0       special lady,different account  POSITIVE     complaint
# 1  nice service,best staff,online bank  POSITIVE  appreciation
# 2                      prompt decision  POSITIVE   information
# 3                        good customer  POSITIVE  appreciation
# 4       important person,best interest  POSITIVE  appreciation

# %%
all_keyword = []
for key_str in tqdm(df.topic):
#     print(key_str)
    splited_str = key_str.split(',')
    if len(splited_str)>0:
        all_keyword += splited_str
#     break

all_keyword
# Out:
# 100%|███████████████████████████████████| 1717/1717 [00:00<00:00, 377482.96it/s]
# ['special lady',
#  'different account',
#  'nice service',
#  'best staff',
#  'online bank',
#  'prompt decision',
#  'good customer',
#  'important person',
#  'best interest',
#  'wonderful relief',
#  'wonderful reminder',
#  'sweet lady',
#  'courteous time',
#  'helpful thank',
#  'sincere gratitude',
#  'special time',
#  'fond holiday',
#  'preferred location',
#  'great agent',
#  'excellent customer',
#  'grateful assistance',
#  'great staff',
#  'easy opening',
#  'great company',
#  'wiht customer',
#  'ready sign',
#  'easy talk',
#  'friendly point',
#  'pleased timeliness',
#  'little direction',
#  'smooth process',
#  'prompt customer',
#  'financial need',
#  'excellent rate',
#  'great experience',
#  'new customer',
#  'last month',
#  'easy work',
#  'fast response',
#  'fast releasing',
#  'interested daughter',
#  'enough help',
#  'many year',
#  'friendly make',
#  'overall experience',
#  'pleased customer',
#  'short notice',
#  'smooth hassle',
#  'personal loan',
#  'dugood bank',
#  'low interest',
#  'fast sign',
#  'free pleasure',
#  'tara baloney',
#  'favorite place',
#  'happy holiday',
#  'welcome atmusefear',
#  'quick stress',
#  'free cara',
#  'speak loan',
#  'important today',
#  'easy office',
#  'dugood branch',
#  'easy transfer',
#  'complete transaction',
#  'local branch',
#  'complete portion',
#  'many year',
#  'local branch',
#  'best option',
#  'financial need',
#  'great job',
#  'pleasant staff',
#  'great customer',
#  'different time',
#  'new air',
#  'easy access',
#  'mean information',
#  'financial business',
#  'anytime day',
#  'dugood app',
#  'easy access',
#  'real person',
#  'new vehicle',
#  'concerned lunch',
#  'online experience',
#  'representative branch',
#  'confirm information',
#  'knowledgeable thanks',
#  'perfect opportunity',
#  'easy purchase',
#  'helpful kind',
#  'nice point',
#  'local credit',
#  'cu employee',
#  'great work',
#  'dugood staff',
#  'first pauline',
#  'villarreal christine',
#  'religious belief',
#  'necessary experience',
#  'great service',
#  'great experience',
#  'open account',
#  'pleased service',
#  'new job',
#  'personal account',
#  'worth area',
#  'bad experience',
#  'financial institution',
#  'smooth process',
#  'great communication',
#  'new money',
#  'online process',
#  'simple call',
#  'great customer',
#  'friendly one',
#  'auxiliary air',
#  'easy use',
#  'whole process',
#  'pleased service',
#  'easy end',
#  'nice work',
#  'whole process',
#  'top world',
#  'wonderful employee',
#  'great work',
#  'thrilled experience',
#  'second loan',
#  'new vehicle',
#  'happy member',
#  'difficult time',
#  'grateful member',
#  'courteous star',
#  'dugood year',
#  'fast help',
#  'pro painless',
#  'wonderful work',
#  'great experience',
#  'live hour',
#  'want business',
#  'many year',
#  'exceptional loan',
#  'efficient thank',
#  'happy staff',
#  'nice business',
#  'long time',
#  'many year',
#  'personal loan',
#  'knowledgeable product',
#  'small loan',
#  'many year',
#  'pleased service',
#  'frank estes',
#  'whole process',
#  'reliable communication',
#  'good customer',
#  'quick service',
#  'big help',
#  'main line',
#  'direct line',
#  'applied loan',
#  'open bank',
#  'professional staff',
#  'late day',
#  'new account',
#  'bad experience',
#  'enough word',
#  'special make',
#  'pleasant experience',
#  'answered question',
#  'easy simple',
#  'helpful employee',
#  'wonderful job',
#  'trustworthy customer',
#  'happy ease',
#  'dugood banking',
#  'professional service',
#  'many year',
#  'awesome people',
#  'great thank',
#  'outstanding work',
#  'wonderful work',
#  'great experience',
#  'patient bit',
#  'important thank',
#  'excellent care',
#  'accurate look',
#  'dugood future',
#  'exceptional service',
#  'hard work',
#  'wonderful customer',
#  'new account',
#  'friendly staff',
#  'convenient location',
#  'awesome experience',
#  'finicial affair',
#  'assest company',
#  'comfortable communication',
#  'high touch',
#  'clear step',
#  'quick help',
#  'easy transaction',
#  'federal credit',
#  'happy service',
#  'federal credit',
#  'quick response',
#  'excellent service',
#  'expert advice',
#  'real people',
#  'excellent experience',
#  'helpful service',
#  'easy thank',
#  'timely manner',
#  'first class',
#  'helpful informative',
#  'better service',
#  'new account',
#  'big bank',
#  'helpful vidor',
#  'friendly name',
#  'best customer',
#  'respectful work',
#  'excellent customer',
#  'great experience',
#  'great experience',
#  'excellent experience',
#  'helpful staff',
#  'great customer',
#  'nice people',
#  'new account',
#  'easy process',
#  'great service',
#  'helpful pleasure',
#  'great attention',
#  'much appreciate',
#  'helpful team',
#  'fabulous experience',
#  'amazing customer',
#  'amazing help',
#  'future business',
#  'good result',
#  'little trouble',
#  'closed loan',
#  'friendly staff',
#  'easy process',
#  'amazing service',
#  'great member',
#  'friendly service',
#  'easy process',
#  'personal service',
#  'great love',
#  'best banking',
#  'easy effortless',
#  'friendly employee',
#  'great customer',
#  'quick loan',
#  'helpful staff',
#  'best experience',
#  'excellent service',
#  'easy work',
#  'true customer',
#  'great experience',
#  'efficient manner',
#  'nice lady',
#  'big girl',
#  'key car',
#  'nice bank',
#  'key car',
#  'whole experience',
#  'fast sign',
#  'competent person',
#  'easy deal',
#  'great question',
#  'open account',
#  'young lady',
#  'pleasant deal',
#  'great customer',
#  'courteous problem',
#  'much maintenance',
#  'able login',
#  'exact thing',
#  'new account',
#  'definite star',
#  'amazing job',
#  'good service',
#  'ferrell team',
#  'honest people',
#  'friendly loan',
#  'easy process',
#  'entire process',
#  'ridiculous understand',
#  'awesome staff',
#  'easy work',
#  'friendly welcoming',
#  'thoughtful give',
#  'nice considerate',
#  'awesome thanks',
#  'calm nerve',
#  'big deal',
#  'able help',
#  'great experience',
#  'fast service',
#  'open confirm',
#  'great service',
#  'good work',
#  'pleased service',
#  'whole staff',
#  'helpful kind',
#  'new account',
#  'awesome loan',
#  'quick painless',
#  'awesome loan',
#  'excellent customer',
#  'great people',
#  'better rate',
#  'better customer',
#  'friendly erin',
#  'amazing employee',
#  'satisfied service',
#  'local branch',
#  'sorry job',
#  'dugood bank',
#  'awesome experience',
#  'quick response',
#  'timely manner',
#  'fast response',
#  'great experience',
#  'outstanding service',
#  'efficient customer',
#  'young lady',
#  'tara auto',
#  'huge asset',
#  'helpful thank',
#  'short period',
#  'professional personable',
#  'informed action',
#  'great service',
#  'informed process',
#  'friendly time',
#  'acceptable thank',
#  'smooth transition',
#  'easy communication',
#  'great customer',
#  'fwd banking',
#  'new account',
#  'several day',
#  'joint account',
#  'top notch',
#  'entire process',
#  'dynamic duo',
#  'helpful need',
#  'best crystal',
#  'lower car',
#  'wonderful thank',
#  'new home',
#  'top game',
#  'big help',
#  'satisfied service',
#  'great service',
#  'open account',
#  'helpful staff',
#  'new account',
#  'whole experience',
#  'easy help',
#  'wonderful staff',
#  'entire loan',
#  'great job',
#  'dugood employee',
#  'matter problem',
#  'new account',
#  'informed make',
#  'knowledgeable account',
#  'proper help',
#  'many year',
#  'nice envoirment',
#  'best experience',
#  'fast making',
#  'good experience',
#  'exceptional service',
#  'first time',
#  'thankful service',
#  'thorough explanation',
#  'new car',
#  'great experience',
#  'patient question',
#  'different option',
#  'quick respond',
#  'online application',
#  'nice lady',
#  'great job',
#  'courteous employee',
#  'finished business',
#  'old senior',
#  'ready payment',
#  'good experience',
#  'personal loan',
#  'medical expense',
#  'smooth experience',
#  'great customer',
#  'easy use',
#  'online banking',
#  'great service',
#  'great attitude',
#  'confident decision',
#  'open account',
#  'young lady',
#  'informative fast',
#  'financial help',
#  'new unit',
#  'dugood thanks',
#  'courteous helping',
#  'personal loan',
#  'pleasant transition',
#  'overall experience',
#  'pleasant business',
#  'good people',
#  'satisfied experience',
#  'nice visit',
#  'dugood credit',
#  'grateful part',
#  'local person',
#  'best service',
#  'easier thought',
#  'excellent job',
#  'open account',
#  'different account',
#  'online banking',
#  'new truck',
#  'detailed dealership',
#  'dugood year',
#  'courteous appreciate',
#  'dugood friend',
#  'excellent business',
#  'pleasant experience',
#  'new account',
#  'top notch',
#  'easy work',
#  'second mortgage',
#  'first time',
#  'sandy look',
#  'dugood future',
#  'helpful kind',
#  'long run',
#  'great experience',
#  'smoothest financing',
#  'easy talk',
#  'simple need',
#  'simple day',
#  'best customer',
#  'nice polite',
#  'good experience',
#  'first time',
#  'able sign',
#  'friendly credit',
#  'last cling',
#  'godly county',
#  'many year',
#  'good job',
#  'lower interest',
#  'dugood family',
#  'smooth look',
#  'great work',
#  'entire process',
#  'pleased loan',
#  'courteous knowing',
#  'excellent service',
#  'new account',
#  'nice employee',
#  'smooth process',
#  'fast paste',
#  'great customer',
#  'best experience',
#  'personal loan',
#  'appreciative attention',
#  'excellent loan',
#  'able call',
#  'great service',
#  'straight point',
#  'helpful thank',
#  'easy experience',
#  'best credit',
#  'dugood credit',
#  'exemplary individual',
#  'rv purchase',
#  'personalized service',
#  'new account',
#  'new loan',
#  'eager help',
#  'personal purchase',
#  'awesome transferring',
#  'best credit',
#  'clear check',
#  'online banking',
#  'online banking',
#  'polite madison',
#  'dugood year',
#  'marissa process',
#  'incredible interest',
#  'quick follow',
#  'excited end',
#  'recent experience',
#  'amazing job',
#  'awesome job',
#  'happy stay',
#  'extra perk',
#  'new account',
#  'outstanding customer',
#  'special shout',
#  'tara baloney',
#  'best loan',
#  'best option',
#  'best choice',
#  'diligent work',
#  'various product',
#  'perfect opening',
#  'quick banker',
#  'entire process',
#  'mobile banking',
#  'best interest',
#  'entire team',
#  'sandy staff',
#  'whole experience',
#  'dugood mortgage',
#  'fast simple',
#  'professional taking',
#  'amazing people',
#  'amazing service',
#  'whole process',
#  'professional patient',
#  'easy work',
#  'able help',
#  'monthly payment',
#  'local branch',
#  'overall experience',
#  'excited part',
#  'dugood family',
#  'personal loan',
#  'seamless genise',
#  'great experience',
#  'little time',
#  'friendly staff',
#  'quick help',
#  'open account',
#  'polite patient',
#  'whole process',
#  'knowledgeable staff',
#  'great place',
#  'kind understanding',
#  'complete process',
#  'commercial loan',
#  'easiest load',
#  'informative lot',
#  'different type',
#  'dugood website',
#  'smooth process',
#  'able call',
#  'dugood credit',
#  'first time',
#  'great experience',
#  'cu staff',
#  'dugood cu',
#  'single person',
#  'first land',
#  'better service',
#  'young lady',
#  'beautiful personality',
#  'first time',
#  'new employee',
#  'excellent job',
#  'professional patient',
#  'big thanks',
#  'first time',
#  'happy part',
#  'helpful make',
#  'recommend bank',
#  'fast response',
#  'awesome lady',
#  'dugood employee',
#  'usual pleasure',
#  'knowledgeable service',
#  'dugood friend',
#  'answered question',
#  'great customer',
#  'great customer',
#  'awesome thank',
#  'fantastic job',
#  'great people',
#  'great service',
#  'easiest process',
#  'nice top',
#  'successful experience',
#  'easy contact',
#  'excellent experance',
#  'dugood staff',
#  'excellent customer',
#  'easy app',
#  'great process',
#  'heavy lifting',
#  'easy home',
#  'new vehicle',
#  'great service',
#  'able sign',
#  'easy stress',
#  'helpful experience',
#  'happy willingness',
#  'detailed answer',
#  'satisfied service',
#  'great job',
#  'friendly service',
#  'new auto',
#  'short amount',
#  'great credit',
#  'pleasant employee',
#  'satisfied service',
#  'clean environment',
#  'warm welcome',
#  'helpful look',
#  'last step',
#  'bad experience',
#  'great group',
#  'great care',
#  'easier walk',
#  'better bank',
#  'easy process',
#  'quickest banking',
#  'simple thank',
#  'low credit',
#  'new account',
#  'great lady',
#  'friendly atmosphere',
#  'professional service',
#  'little paperwork',
#  'pleasant experience',
#  'good fcu',
#  'friendly service',
#  'good fcu',
#  'knowledgeable job',
#  'thankful help',
#  'grand wagoneer',
#  'great experience',
#  'easy walk',
#  'pleasant staff',
#  'happy dugood',
#  'dugood credit',
#  'several year',
#  'knowledgeable service',
#  'ok boy',
#  'new account',
#  'new debit',
#  'long term',
#  'glad member',
#  'dugood person',
#  'friendly staff',
#  'pleasant trip',
#  'pleasant business',
#  'professional service',
#  'satisfied customer',
#  'new member',
#  'timely manner',
#  'good family',
#  'next vehicle',
#  'best bank',
#  'good job',
#  'amazing helpful',
#  'dugood others',
#  'best credit',
#  'pleasant experience',
#  'dugood year',
#  'great experience',
#  'great staff',
#  'friendly glad',
#  'happy holiday',
#  'wonderful setting',
#  'long time',
#  'polite people',
#  'dugood u',
#  'dugood credit',
#  'open account',
#  'excellent service',
#  'valuable customer',
#  'friendly try',
#  'friendly go',
#  'personal loan',
#  'new checking',
#  'easy talk',
#  'stressful moment',
#  'knowledgeable answer',
#  'happy experience',
#  'great bank',
#  'excellent service',
#  'excellent service',
#  'great banking',
#  'least year',
#  'awesome loan',
#  'great work',
#  'perfect service',
#  'happy way',
#  'first visit',
#  'open saving',
#  'pleasant work',
#  'much experience',
#  'dugood credit',
#  'responsible people',
#  'friendly people',
#  'open account',
#  'friendly service',
#  'dugood friend',
#  'great service',
#  'personal loan',
#  'ready time',
#  'helpful town',
#  'know problem',
#  'better rate',
#  'quick result',
#  'great way',
#  'great bank',
#  'federal credit',
#  'friendly bank',
#  'great job',
#  'great rate',
#  'awesome work',
#  'monty carrie',
#  'best person',
#  'helpful thank',
#  'hard time',
#  'good time',
#  'knowledgeable loan',
#  'polite waste',
#  'great business',
#  'good work',
#  'kind service',
#  'quick painless',
#  'current rate',
#  'best area',
#  'excellent branch',
#  'great line',
#  'knowledgeable situation',
#  'great people',
#  'great environment',
#  'financial resource',
#  'easy work',
#  'new car',
#  'great rate',
#  'excellent customer',
#  'great experience',
#  'away step',
#  'financial need',
#  'great mortgage',
#  'right place',
#  'easier others',
#  'open account',
#  'little time',
#  'new checking',
#  'courteous staff',
#  'great experience',
#  'blue buy',
#  'major beaumont',
#  'new car',
#  'low rate',
#  'amazing job',
#  'friendly treat',
#  'happy experience',
#  'open account',
#  'helpful know',
#  'right choice',
#  'helpful patient',
#  'first time',
#  'fantastic experience',
#  'representative moment',
#  'comfortable screen',
#  'helpful information',
#  'available service',
#  'brief time',
#  'personal banker',
#  'achieve reason',
#  'wonderful overview',
#  'soon door',
#  'satisfied conduct',
#  'great people',
#  'online application',
#  'nice lady',
#  'informative telling',
#  'good get',
#  'front lobby',
#  'last window',
#  'nice kind',
#  'nice incentive',
#  'enough time',
#  'ahead time',
#  'lovely place',
#  'great help',
#  'great customer',
#  'helpful people',
#  'wonderful people',
#  'new membership',
#  'pleased professionalism',
#  'personal business',
#  'pleased experience',
#  'new account',
#  'friendly service',
#  'applied dollar',
#  'dugood treat',
#  'excellent service',
#  'first time',
#  'easy reference',
#  'best loan',
#  'great credit',
#  'fraudulent transaction',
#  'helpful patient',
#  'horrible ordeal',
#  'helpful dugood',
#  'sure treasure',
#  'stressful situation',
#  'many blessing',
#  'great service',
#  'local credit',
#  'good customer',
#  'great experience',
#  'happy business',
#  'awesome answer',
#  'good work',
#  'helpful patience',
#  'away process',
#  'awhile figure',
#  'many time',
#  'exceptional employee',
#  'better interest',
#  'easy work',
#  'simplified credit',
#  'much bureaucracy',
#  'easy service',
#  'whole process',
#  'pleasant experience',
#  'open account',
#  'good opening',
#  'good offer',
#  'good day',
#  'sweet professional',
#  'top nephew',
#  'super star',
#  'successful account',
#  'federal credit',
#  'dugood customer',
#  'open account',
#  'much time',
#  'nice people',
#  'great rate',
#  'great service',
#  'new account',
#  'online account',
#  'best personality',
#  'happy member',
#  'dugood look',
#  'new credit',
#  'outstanding customer',
#  'regular bank',
#  'dugood credit',
#  'great experience',
#  'recent loan',
#  'simplified process',
#  'electronic process',
#  'wonderful credit',
#  'small loan',
#  'simple loan',
#  'gracious kind',
#  'excellent treatment',
#  'dugood credit',
#  'helpfulness katrina',
#  'different account',
#  'entire process',
#  'dugood place',
#  'future banking',
#  'great experience',
#  'fantastic job',
#  'personal loan',
#  'pushy patient',
#  'grand opening',
#  'right home',
#  'great service',
#  'fast turnaround',
#  'friendly people',
#  'proper step',
#  'amazing rate',
#  'great service',
#  'efficient auto',
#  'great location',
#  'easiest experience',
#  'dugood ease',
#  'excellent customer',
#  'financial support',
#  'great service',
#  'friendly staff',
#  'mindy neail',
#  'great place',
#  'new truck',
#  'awesome experience',
#  'professional service',
#  'personal loan',
#  'easy hassel',
#  'gud service',
#  'entire process',
#  'little effort',
#  'whole process',
#  'dugood member',
#  'pleased interaction',
#  'friendly conversation',
#  'good withi',
#  'federal credit',
#  'great customer',
#  'full need',
#  'great response',
#  'dugood year',
#  'able text',
#  'friendly service',
#  'painless loan',
#  'great service',
#  'easy operate',
#  'good bank',
#  'timely manner',
#  'long time',
#  'great service',
#  'dugood thanks',
#  'dugood refer',
#  'helpful people',
#  'great service',
#  'great customer',
#  'great customer',
#  'easy process',
#  'easiest loan',
#  'convenient loan',
#  'single aspect',
#  'excellent service',
#  'great job',
#  'smooth process',
#  'whole process',
#  'wonderful customer',
#  'helpful want',
#  'hard refinance',
#  'helpful kind',
#  'polite tentative',
#  'entire process',
#  'helpful appreciate',
#  'first experience',
#  'positive experience',
#  'great service',
#  'quick help',
#  'friendly face',
#  'friendly service',
#  'young lady',
#  'local vidor',
#  'new facility',
#  'pleasant sooooo',
#  'easiest loan',
#  'great experience',
#  'dugood personnel',
#  'efficient people',
#  'able refinance',
#  'simple loan',
#  'eager satisfy',
#  'excellent rating',
#  'great experience',
#  'wonderful customer',
#  'good care',
#  'great customer',
#  'new auto',
#  'pleased service',
#  'randal carla',
#  'fast service',
#  'great experience',
#  'convenient loan',
#  'open account',
#  'great experience',
#  'entire process',
#  'applied loan',
#  'helpful customer',
#  'representative pleasure',
#  'early saving',
#  'many people',
#  'easiest person',
#  'aggravated trust',
#  'valuable asset',
#  'answered question',
#  'best credit',
#  'best job',
#  'thankful part',
#  'quick get',
#  'representative friend',
#  'professional rate',
#  'excellent time',
#  'possible vidor',
#  'excellent experience',
#  'dugood employee',
#  'open account',
#  'good interest',
#  'right home',
#  'pleased quality',
#  'helpful nice',
#  'late night',
#  'first thing',
#  ...]

# %%
freq_count = {}
for key in all_keyword:
    if key in freq_count:
        freq_count[key] +=1
    else:
        freq_count[key] = 1

# %%
len(freq_count)
# Out:
# 1933

# %%
freq_count
# Out:
# {'special lady': 1,
#  'different account': 6,
#  'nice service': 1,
#  'best staff': 2,
#  'online bank': 1,
#  'prompt decision': 1,
#  'good customer': 10,
#  'important person': 1,
#  'best interest': 4,
#  'wonderful relief': 1,
#  'wonderful reminder': 1,
#  'sweet lady': 1,
#  'courteous time': 1,
#  'helpful thank': 6,
#  'sincere gratitude': 1,
#  'special time': 2,
#  'fond holiday': 1,
#  'preferred location': 1,
#  'great agent': 1,
#  'excellent customer': 20,
#  'grateful assistance': 1,
#  'great staff': 6,
#  'easy opening': 2,
#  'great company': 3,
#  'wiht customer': 1,
#  'ready sign': 4,
#  'easy talk': 3,
#  'friendly point': 1,
#  'pleased timeliness': 1,
#  'little direction': 1,
#  'smooth process': 5,
#  'prompt customer': 1,
#  'financial need': 12,
#  'excellent rate': 2,
#  'great experience': 63,
#  'new customer': 4,
#  'last month': 2,
#  'easy work': 27,
#  'fast response': 3,
#  'fast releasing': 1,
#  'interested daughter': 1,
#  'enough help': 1,
#  'many year': 29,
#  'friendly make': 1,
#  'overall experience': 4,
#  'pleased customer': 1,
#  'short notice': 1,
#  'smooth hassle': 1,
#  'personal loan': 23,
#  'dugood bank': 2,
#  'low interest': 2,
#  'fast sign': 2,
#  'free pleasure': 1,
#  'tara baloney': 4,
#  'favorite place': 1,
#  'happy holiday': 2,
#  'welcome atmusefear': 1,
#  'quick stress': 1,
#  'free cara': 1,
#  'speak loan': 1,
#  'important today': 1,
#  'easy office': 1,
#  'dugood branch': 5,
#  'easy transfer': 1,
#  'complete transaction': 4,
#  'local branch': 9,
#  'complete portion': 1,
#  'best option': 2,
#  'great job': 23,
#  'pleasant staff': 3,
#  'great customer': 49,
#  'different time': 1,
#  'new air': 1,
#  'easy access': 4,
#  'mean information': 1,
#  'financial business': 1,
#  'anytime day': 2,
#  'dugood app': 2,
#  'real person': 3,
#  'new vehicle': 7,
#  'concerned lunch': 1,
#  'online experience': 1,
#  'representative branch': 1,
#  'confirm information': 1,
#  'knowledgeable thanks': 2,
#  'perfect opportunity': 1,
#  'easy purchase': 1,
#  'helpful kind': 7,
#  'nice point': 1,
#  'local credit': 5,
#  'cu employee': 1,
#  'great work': 11,
#  'dugood staff': 9,
#  'first pauline': 1,
#  'villarreal christine': 1,
#  'religious belief': 1,
#  'necessary experience': 1,
#  'great service': 56,
#  'open account': 27,
#  'pleased service': 13,
#  'new job': 1,
#  'personal account': 3,
#  'worth area': 1,
#  'bad experience': 9,
#  'financial institution': 16,
#  'great communication': 3,
#  'new money': 1,
#  'online process': 1,
#  'simple call': 1,
#  'friendly one': 1,
#  'auxiliary air': 1,
#  'easy use': 4,
#  'whole process': 17,
#  'easy end': 1,
#  'nice work': 3,
#  'top world': 1,
#  'wonderful employee': 1,
#  'thrilled experience': 1,
#  'second loan': 1,
#  'happy member': 7,
#  'difficult time': 2,
#  'grateful member': 2,
#  'courteous star': 1,
#  'dugood year': 30,
#  'fast help': 1,
#  'pro painless': 1,
#  'wonderful work': 4,
#  'live hour': 1,
#  'want business': 1,
#  'exceptional loan': 1,
#  'efficient thank': 1,
#  'happy staff': 1,
#  'nice business': 1,
#  'long time': 21,
#  'knowledgeable product': 2,
#  'small loan': 5,
#  'frank estes': 1,
#  'reliable communication': 1,
#  'quick service': 2,
#  'big help': 3,
#  'main line': 1,
#  'direct line': 1,
#  'applied loan': 2,
#  'open bank': 1,
#  'professional staff': 6,
#  'late day': 1,
#  'new account': 35,
#  'enough word': 1,
#  'special make': 1,
#  'pleasant experience': 19,
#  'answered question': 9,
#  'easy simple': 1,
#  'helpful employee': 2,
#  'wonderful job': 2,
#  'trustworthy customer': 1,
#  'happy ease': 1,
#  'dugood banking': 6,
#  'professional service': 12,
#  'awesome people': 3,
#  'great thank': 1,
#  'outstanding work': 1,
#  'patient bit': 1,
#  'important thank': 1,
#  'excellent care': 2,
#  'accurate look': 1,
#  'dugood future': 3,
#  'exceptional service': 4,
#  'hard work': 2,
#  'wonderful customer': 5,
#  'friendly staff': 20,
#  'convenient location': 4,
#  'awesome experience': 7,
#  'finicial affair': 1,
#  'assest company': 1,
#  'comfortable communication': 1,
#  'high touch': 1,
#  'clear step': 1,
#  'quick help': 4,
#  'easy transaction': 2,
#  'federal credit': 11,
#  'happy service': 5,
#  'quick response': 6,
#  'excellent service': 32,
#  'expert advice': 1,
#  'real people': 1,
#  'excellent experience': 8,
#  'helpful service': 1,
#  'easy thank': 2,
#  'timely manner': 11,
#  'first class': 2,
#  'helpful informative': 1,
#  'better service': 3,
#  'big bank': 3,
#  'helpful vidor': 2,
#  'friendly name': 1,
#  'best customer': 10,
#  'respectful work': 1,
#  'helpful staff': 8,
#  'nice people': 10,
#  'easy process': 12,
#  'helpful pleasure': 2,
#  'great attention': 1,
#  'much appreciate': 1,
#  'helpful team': 1,
#  'fabulous experience': 1,
#  'amazing customer': 4,
#  'amazing help': 1,
#  'future business': 1,
#  'good result': 1,
#  'little trouble': 1,
#  'closed loan': 1,
#  'amazing service': 5,
#  'great member': 3,
#  'friendly service': 24,
#  'personal service': 2,
#  'great love': 1,
#  'best banking': 6,
#  'easy effortless': 1,
#  'friendly employee': 5,
#  'quick loan': 1,
#  'best experience': 7,
#  'true customer': 1,
#  'efficient manner': 1,
#  'nice lady': 4,
#  'big girl': 1,
#  'key car': 2,
#  'nice bank': 1,
#  'whole experience': 4,
#  'competent person': 1,
#  'easy deal': 3,
#  'great question': 1,
#  'young lady': 13,
#  'pleasant deal': 3,
#  'courteous problem': 1,
#  'much maintenance': 1,
#  'able login': 1,
#  'exact thing': 1,
#  'definite star': 1,
#  'amazing job': 4,
#  'good service': 9,
#  'ferrell team': 1,
#  'honest people': 1,
#  'friendly loan': 2,
#  'entire process': 17,
#  'ridiculous understand': 1,
#  'awesome staff': 3,
#  'friendly welcoming': 2,
#  'thoughtful give': 1,
#  'nice considerate': 1,
#  'awesome thanks': 1,
#  'calm nerve': 1,
#  'big deal': 1,
#  'able help': 3,
#  'fast service': 14,
#  'open confirm': 1,
#  'good work': 10,
#  'whole staff': 1,
#  'awesome loan': 4,
#  'quick painless': 6,
#  'great people': 21,
#  'better rate': 2,
#  'better customer': 1,
#  'friendly erin': 1,
#  'amazing employee': 2,
#  'satisfied service': 9,
#  'sorry job': 1,
#  'outstanding service': 2,
#  'efficient customer': 1,
#  'tara auto': 1,
#  'huge asset': 1,
#  'short period': 1,
#  'professional personable': 2,
#  'informed action': 1,
#  'informed process': 2,
#  'friendly time': 1,
#  'acceptable thank': 1,
#  'smooth transition': 1,
#  'easy communication': 1,
#  'fwd banking': 1,
#  'several day': 1,
#  'joint account': 1,
#  'top notch': 8,
#  'dynamic duo': 1,
#  'helpful need': 3,
#  'best crystal': 1,
#  'lower car': 1,
#  'wonderful thank': 2,
#  'new home': 2,
#  'top game': 1,
#  'easy help': 1,
#  'wonderful staff': 5,
#  'entire loan': 2,
#  'dugood employee': 11,
#  'matter problem': 1,
#  'informed make': 1,
#  'knowledgeable account': 2,
#  'proper help': 1,
#  'nice envoirment': 1,
#  'fast making': 1,
#  'good experience': 28,
#  'first time': 16,
#  'thankful service': 1,
#  'thorough explanation': 1,
#  'new car': 13,
#  'patient question': 1,
#  'different option': 3,
#  'quick respond': 7,
#  'online application': 4,
#  'courteous employee': 3,
#  'finished business': 1,
#  'old senior': 1,
#  'ready payment': 1,
#  'medical expense': 1,
#  'smooth experience': 1,
#  'online banking': 12,
#  'great attitude': 3,
#  'confident decision': 1,
#  'informative fast': 1,
#  'financial help': 3,
#  'new unit': 1,
#  'dugood thanks': 4,
#  'courteous helping': 1,
#  'pleasant transition': 1,
#  'pleasant business': 2,
#  'good people': 5,
#  'satisfied experience': 4,
#  'nice visit': 2,
#  'dugood credit': 49,
#  'grateful part': 1,
#  'local person': 2,
#  'best service': 3,
#  'easier thought': 1,
#  'excellent job': 4,
#  'new truck': 8,
#  'detailed dealership': 1,
#  'courteous appreciate': 1,
#  'dugood friend': 4,
#  'excellent business': 1,
#  'second mortgage': 1,
#  'sandy look': 1,
#  'long run': 1,
#  'smoothest financing': 1,
#  'simple need': 1,
#  'simple day': 1,
#  'nice polite': 1,
#  'able sign': 2,
#  'friendly credit': 2,
#  'last cling': 1,
#  'godly county': 1,
#  'good job': 6,
#  'lower interest': 5,
#  'dugood family': 11,
#  'smooth look': 1,
#  'pleased loan': 1,
#  'courteous knowing': 1,
#  'nice employee': 2,
#  'fast paste': 1,
#  'appreciative attention': 1,
#  'excellent loan': 1,
#  'able call': 2,
#  'straight point': 2,
#  'easy experience': 5,
#  'best credit': 13,
#  'exemplary individual': 1,
#  'rv purchase': 1,
#  'personalized service': 1,
#  'new loan': 2,
#  'eager help': 6,
#  'personal purchase': 1,
#  'awesome transferring': 1,
#  'clear check': 1,
#  'polite madison': 1,
#  'marissa process': 1,
#  'incredible interest': 1,
#  'quick follow': 1,
#  'excited end': 1,
#  'recent experience': 4,
#  'awesome job': 1,
#  'happy stay': 1,
#  'extra perk': 1,
#  'outstanding customer': 3,
#  'special shout': 1,
#  'best loan': 5,
#  'best choice': 1,
#  'diligent work': 1,
#  'various product': 1,
#  'perfect opening': 1,
#  'quick banker': 1,
#  'mobile banking': 1,
#  'entire team': 2,
#  'sandy staff': 1,
#  'dugood mortgage': 1,
#  'fast simple': 1,
#  'professional taking': 1,
#  'amazing people': 3,
#  'professional patient': 2,
#  'monthly payment': 3,
#  'excited part': 1,
#  'seamless genise': 1,
#  'little time': 3,
#  'polite patient': 1,
#  'knowledgeable staff': 8,
#  'great place': 12,
#  'kind understanding': 2,
#  'complete process': 1,
#  'commercial loan': 1,
#  'easiest load': 1,
#  'informative lot': 1,
#  'different type': 3,
#  'dugood website': 1,
#  'cu staff': 1,
#  'dugood cu': 5,
#  'single person': 1,
#  'first land': 1,
#  'beautiful personality': 1,
#  'new employee': 1,
#  'big thanks': 1,
#  'happy part': 1,
#  'helpful make': 3,
#  'recommend bank': 1,
#  'awesome lady': 1,
#  'usual pleasure': 1,
#  'knowledgeable service': 3,
#  'awesome thank': 2,
#  'fantastic job': 3,
#  'easiest process': 1,
#  'nice top': 1,
#  'successful experience': 1,
#  'easy contact': 1,
#  'excellent experance': 1,
#  'easy app': 1,
#  'great process': 2,
#  'heavy lifting': 1,
#  'easy home': 2,
#  'easy stress': 2,
#  'helpful experience': 2,
#  'happy willingness': 1,
#  'detailed answer': 1,
#  'new auto': 2,
#  'short amount': 1,
#  'great credit': 15,
#  'pleasant employee': 1,
#  'clean environment': 1,
#  'warm welcome': 2,
#  'helpful look': 1,
#  'last step': 1,
#  'great group': 2,
#  'great care': 2,
#  'easier walk': 1,
#  'better bank': 2,
#  'quickest banking': 1,
#  'simple thank': 1,
#  'low credit': 1,
#  'great lady': 1,
#  'friendly atmosphere': 4,
#  'little paperwork': 1,
#  'good fcu': 3,
#  'knowledgeable job': 1,
#  'thankful help': 2,
#  'grand wagoneer': 1,
#  'easy walk': 1,
#  'happy dugood': 1,
#  'several year': 3,
#  'ok boy': 1,
#  'new debit': 2,
#  'long term': 3,
#  'glad member': 3,
#  'dugood person': 1,
#  'pleasant trip': 1,
#  'satisfied customer': 1,
#  'new member': 7,
#  'good family': 2,
#  'next vehicle': 1,
#  'best bank': 8,
#  'amazing helpful': 1,
#  'dugood others': 1,
#  'friendly glad': 1,
#  'wonderful setting': 1,
#  'polite people': 2,
#  'dugood u': 1,
#  'valuable customer': 1,
#  'friendly try': 1,
#  'friendly go': 2,
#  'new checking': 4,
#  'stressful moment': 1,
#  'knowledgeable answer': 2,
#  'happy experience': 3,
#  'great bank': 3,
#  'great banking': 4,
#  'least year': 3,
#  'perfect service': 1,
#  'happy way': 2,
#  'first visit': 3,
#  'open saving': 1,
#  'pleasant work': 3,
#  'much experience': 1,
#  'responsible people': 1,
#  'friendly people': 16,
#  'ready time': 1,
#  'helpful town': 1,
#  'know problem': 1,
#  'quick result': 1,
#  'great way': 1,
#  'friendly bank': 1,
#  'great rate': 10,
#  'awesome work': 5,
#  'monty carrie': 1,
#  'best person': 1,
#  'hard time': 5,
#  'good time': 4,
#  'knowledgeable loan': 1,
#  'polite waste': 1,
#  'great business': 5,
#  'kind service': 1,
#  'current rate': 1,
#  'best area': 1,
#  'excellent branch': 1,
#  'great line': 1,
#  'knowledgeable situation': 1,
#  'great environment': 2,
#  'financial resource': 1,
#  'away step': 1,
#  'great mortgage': 1,
#  'right place': 1,
#  'easier others': 1,
#  'courteous staff': 3,
#  'blue buy': 1,
#  'major beaumont': 1,
#  'low rate': 5,
#  'friendly treat': 2,
#  'helpful know': 1,
#  'right choice': 2,
#  'helpful patient': 3,
#  'fantastic experience': 1,
#  'representative moment': 1,
#  'comfortable screen': 1,
#  'helpful information': 1,
#  'available service': 1,
#  'brief time': 1,
#  'personal banker': 2,
#  'achieve reason': 1,
#  'wonderful overview': 1,
#  'soon door': 1,
#  'satisfied conduct': 1,
#  'informative telling': 1,
#  'good get': 1,
#  'front lobby': 1,
#  'last window': 1,
#  'nice kind': 1,
#  'nice incentive': 1,
#  'enough time': 1,
#  'ahead time': 1,
#  'lovely place': 1,
#  'great help': 3,
#  'helpful people': 7,
#  'wonderful people': 3,
#  'new membership': 1,
#  'pleased professionalism': 1,
#  'personal business': 2,
#  'pleased experience': 2,
#  'applied dollar': 1,
#  'dugood treat': 1,
#  'easy reference': 1,
#  'fraudulent transaction': 1,
#  'horrible ordeal': 1,
#  'helpful dugood': 1,
#  'sure treasure': 1,
#  'stressful situation': 2,
#  'many blessing': 1,
#  'happy business': 2,
#  'awesome answer': 1,
#  'helpful patience': 1,
#  'away process': 1,
#  'awhile figure': 1,
#  'many time': 4,
#  'exceptional employee': 1,
#  'better interest': 4,
#  'simplified credit': 1,
#  'much bureaucracy': 1,
#  'easy service': 2,
#  'good opening': 1,
#  'good offer': 1,
#  'good day': 2,
#  'sweet professional': 1,
#  'top nephew': 1,
#  'super star': 1,
#  'successful account': 1,
#  'dugood customer': 6,
#  'much time': 2,
#  'online account': 1,
#  'best personality': 1,
#  'dugood look': 1,
#  'new credit': 1,
#  'regular bank': 2,
#  'recent loan': 2,
#  'simplified process': 2,
#  'electronic process': 1,
#  'wonderful credit': 1,
#  'simple loan': 3,
#  'gracious kind': 1,
#  'excellent treatment': 1,
#  'helpfulness katrina': 1,
#  'dugood place': 1,
#  'future banking': 2,
#  'pushy patient': 1,
#  'grand opening': 1,
#  'right home': 3,
#  'fast turnaround': 1,
#  'proper step': 1,
#  'amazing rate': 1,
#  'efficient auto': 1,
#  'great location': 2,
#  'easiest experience': 2,
#  'dugood ease': 1,
#  'financial support': 1,
#  'mindy neail': 1,
#  'easy hassel': 1,
#  'gud service': 1,
#  'little effort': 2,
#  'dugood member': 8,
#  'pleased interaction': 1,
#  'friendly conversation': 1,
#  'good withi': 1,
#  'full need': 1,
#  'great response': 2,
#  'able text': 1,
#  'painless loan': 2,
#  'easy operate': 1,
#  'good bank': 2,
#  'dugood refer': 1,
#  'easiest loan': 5,
#  'convenient loan': 2,
#  'single aspect': 1,
#  'helpful want': 1,
#  'hard refinance': 1,
#  'polite tentative': 1,
#  'helpful appreciate': 1,
#  'first experience': 1,
#  'positive experience': 8,
#  'friendly face': 4,
#  'local vidor': 1,
#  'new facility': 1,
#  'pleasant sooooo': 1,
#  'dugood personnel': 1,
#  'efficient people': 1,
#  'able refinance': 4,
#  'eager satisfy': 1,
#  'excellent rating': 1,
#  'good care': 4,
#  'randal carla': 1,
#  'helpful customer': 4,
#  'representative pleasure': 1,
#  'early saving': 1,
#  'many people': 2,
#  'easiest person': 1,
#  'aggravated trust': 1,
#  'valuable asset': 1,
#  'best job': 1,
#  'thankful part': 1,
#  'quick get': 1,
#  'representative friend': 1,
#  'professional rate': 1,
#  'excellent time': 1,
#  'possible vidor': 1,
#  'good interest': 3,
#  'pleased quality': 1,
#  'helpful nice': 1,
#  'late night': 1,
#  'first thing': 1,
#  'next morning': 2,
#  'dugood loan': 3,
#  'quick set': 1,
#  'new bank': 2,
#  'knowledgeable lending': 1,
#  'miss work': 1,
#  'new dupont': 1,
#  'entire transaction': 1,
#  'past year': 5,
#  'personal vacation': 1,
#  'financial opportunity': 1,
#  'timely star': 1,
#  'last loan': 1,
#  'best rate': 5,
#  'professional kind': 3,
#  'phenomenal customer': 1,
#  'helpful process': 4,
#  'dugood woman': 1,
#  'biggest asset': 1,
#  'busy lady': 1,
#  'friendly process': 1,
#  'exceptional communication': 1,
#  'professional tara': 1,
#  'extra mile': 9,
#  'last vehicle': 2,
#  'great purchase': 1,
#  'responsive question': 1,
#  'able answer': 4,
#  'next car': 1,
#  'efficient service': 4,
#  'much enthusiasm': 1,
#  'accurate answer': 1,
#  'right direction': 1,
#  'great hospitality': 1,
#  'classic beaumont': 1,
#  'professional yes': 1,
#  'different others': 1,
#  'financial transaction': 1,
#  'dugood way': 2,
#  'best way': 1,
#  'different scenario': 1,
#  'worked hour': 1,
#  'good thing': 5,
#  'exceptional customer': 1,
#  'courteous look': 1,
#  'free situation': 1,
#  'whole credit': 1,
#  'special thanks': 4,
#  'excited thanks': 1,
#  'dugood dream': 1,
#  'jeep folk': 1,
#  'unsurpassable customer': 1,
#  'right vehicle': 1,
#  'courteous service': 8,
#  'accurate service': 1,
#  'resourceful amazing': 1,
#  'happier experience': 1,
#  'wonderful deal': 1,
#  'easy pleasant': 1,
#  'ready closing': 1,
#  'free calendar': 1,
#  'good credit': 3,
#  'perdue help': 1,
#  'attentive sum': 1,
#  'first impression': 1,
#  'last impression': 1,
#  'long customer': 2,
#  'knowledgeable car': 1,
#  'great girl': 1,
#  'much privilege': 1,
#  'wholesome people': 1,
#  'top thing': 2,
#  'sandy amburn': 1,
#  'efficient question': 1,
#  'external account': 1,
#  'online loan': 4,
#  'early afternoon': 1,
#  'stressful dugood': 1,
#  'terrific employee': 1,
#  'nice company': 1,
#  'wonderful way': 2,
#  'profesional loan': 1,
#  'awesome ability': 1,
#  'amazing patient': 1,
#  'sure answer': 1,
#  'third loan': 1,
#  'straight schedule': 1,
#  'helpful personable': 1,
#  'strong arm': 1,
#  'moral compass': 1,
#  'low side': 1,
#  'nice staff': 3,
#  'efficient considerate': 1,
#  'great personality': 1,
#  'informative question': 1,
#  'happy refinance': 1,
#  'efficient stress': 1,
#  'great folk': 1,
#  'able process': 1,
#  'nederland branch': 1,
#  'knowledgeable option': 1,
#  'great year': 1,
#  'main reason': 1,
#  'informed detail': 1,
#  'recommend others': 1,
#  'main banking': 1,
#  'great team': 1,
#  'sure info': 1,
#  'knowledgeable people': 2,
#  'stellar service': 1,
#  'knowledgeable employee': 2,
#  'fantastic service': 1,
#  'wonderful help': 1,
#  'current credit': 1,
#  'dugood thought': 1,
#  'easy processing': 1,
#  'else staff': 1,
#  'willing help': 17,
#  'new card': 2,
#  'able check': 1,
#  'stupid reason': 1,
#  'courteous thanks': 2,
#  'helpful kellie': 1,
#  'assist sister': 1,
#  'possible way': 1,
#  'upcoming age': 1,
#  'amazing member': 1,
#  'several change': 1,
#  'wonderful reputation': 1,
#  'second deposit': 1,
#  'excellent staff': 1,
#  'secured loan': 1,
#  'dugood work': 2,
#  'needed hour': 1,
#  'pleasant people': 1,
#  'lower note': 1,
#  'nice love': 1,
#  'friendly lady': 1,
#  'outstanding job': 1,
#  'second payment': 1,
#  'dugood arrange': 1,
#  'outstanding balance': 1,
#  'great employee': 3,
#  'courteous branch': 1,
#  'cu loan': 1,
#  'entire financing': 1,
#  'prompt assistance': 1,
#  'able online': 1,
#  'next day': 6,
#  'final paperwork': 1,
#  'dugood account': 2,
#  'timely transaction': 1,
#  'portal improvement': 1,
#  'compliment phone': 1,
#  'fastest service': 1,
#  'easy procedure': 1,
#  'helpful transaction': 1,
#  'sandy jasper': 2,
#  'new boat': 1,
#  'immediate answer': 1,
#  'fastest experience': 2,
#  'easy staff': 3,
#  'current company': 1,
#  'fantastic program': 1,
#  'many way': 3,
#  'complete home': 1,
#  'long trip': 1,
#  'complete application': 1,
#  'total time': 1,
#  'amazing staff': 1,
#  'several office': 1,
#  'pleasant willing': 1,
#  'second account': 1,
#  'remote experience': 1,
#  'dugood associate': 3,
#  'friendly experience': 1,
#  'pleasant love': 1,
#  'ready help': 8,
#  'new trailer': 1,
#  'dugood people': 3,
#  'misquoted purchase': 1,
#  'different unit': 1,
#  'happy working': 1,
#  'warm family': 1,
#  'able start': 1,
#  'disappointed decision': 1,
#  'full amount': 1,
#  'due finance': 1,
#  'friendly customer': 3,
#  'excellent curiosity': 1,
#  'online advertisement': 1,
#  'timely process': 1,
#  'pandemic time': 1,
#  'superb customer': 1,
#  'big pet': 1,
#  'quick flawless': 1,
#  'awesome customer': 4,
#  'amazing thank': 2,
#  'top tier': 1,
#  'willing work': 4,
#  'purdue lending': 1,
#  'old auto': 1,
#  'several option': 1,
#  'significant saving': 1,
#  'good reason': 1,
#  'great example': 1,
#  'great interest': 4,
#  'utmost professionalism': 1,
#  'exceptional job': 1,
#  'attentiveness willingness': 1,
#  'helpful car': 1,
#  'outstanding assistance': 1,
#  'beaumont area': 1,
#  'friendly person': 1,
#  'many question': 1,
#  'great advice': 2,
#  'best decision': 1,
#  'best platform': 1,
#  'timely manor': 1,
#  'online finish': 1,
#  'pleasant professional': 1,
#  'fantastic thanks': 1,
#  'quick awsome': 1,
#  'longtime member': 1,
#  'valid card': 1,
#  'next time': 1,
#  'facial expression': 1,
#  'whole face': 1,
#  'professional employee': 2,
#  'normal bank': 1,
#  'amazing agent': 1,
#  'better experience': 2,
#  'knowledgeable gap': 1,
#  'friendly soul': 1,
#  'small give': 1,
#  'several loan': 2,
#  'informative honest': 1,
#  'helpful husband': 1,
#  'lower rate': 4,
#  'wonderful experiance': 1,
#  'certain amount': 1,
#  'dugood team': 4,
#  'original application': 1,
#  'little information': 1,
#  'easier work': 1,
#  'available closing': 1,
#  'entire experience': 1,
#  'easiest people': 1,
#  'awesome way': 1,
#  'worked anavel': 1,
#  'overall customer': 1,
#  'perfect thanks': 1,
#  'awesome patient': 1,
#  'first auto': 1,
#  'satisfied thanks': 1,
#  'professional prompt': 1,
#  'qualified loan': 1,
#  'available transaction': 1,
#  'great combination': 1,
#  'entire banking': 1,
#  'professional thank': 2,
#  'amazing experience': 2,
#  'free time': 1,
#  'professional atmosphere': 1,
#  'sixth vehicle': 1,
#  'pleasant patient': 1,
#  'half metal': 1,
#  'front employer': 1,
#  'due damage': 1,
#  'close month': 1,
#  'hard feeling': 1,
#  'whole lot': 1,
#  'late appointment': 1,
#  'remind appointment': 1,
#  'short time': 3,
#  'personal test': 1,
#  'nice place': 1,
#  'glad meet': 1,
#  'best place': 1,
#  'confused time': 1,
#  'professional customer': 1,
#  'special care': 1,
#  'dugood auto': 1,
#  'strong suit': 1,
#  'dugood service': 1,
#  'little year': 1,
#  'upmost respect': 1,
#  'friendly kind': 1,
#  'thankful business': 1,
#  'dugood thank': 2,
#  'regular loan': 1,
#  'cordial helpful': 1,
#  'prompt manner': 2,
#  'notary drive': 2,
#  'live person': 2,
#  'great deal': 4,
#  'painless brandi': 1,
#  'best banker': 2,
#  'last account': 2,
#  'fraudulent activity': 1,
#  'open arm': 1,
#  'specific banking': 1,
#  'half hour': 1,
#  'able provide': 1,
#  'amazing effort': 1,
#  'unusual circumstance': 1,
#  'fantastic ty': 1,
#  'instrumental development': 1,
#  'financial literacy': 1,
#  'solid advice': 1,
#  'current condition': 1,
#  'awesome time': 1,
#  'knowledgeable thank': 1,
#  'available answer': 1,
#  'major hurricane': 1,
#  'courteous paperwork': 1,
#  'easy loan': 1,
#  'helpful prompt': 1,
#  'lose work': 1,
#  'smooth worry': 1,
#  'lollipop love': 1,
#  'excellent response': 1,
#  'friendly appreciate': 2,
#  'new banking': 1,
#  'ancillary banking': 1,
#  'available phone': 1,
#  'caring branch': 1,
#  'beautiful office': 1,
#  'efficient option': 1,
#  'knowledgeable member': 1,
#  'beneficial party': 1,
#  ...}

# %%
unique_keywords = freq_count.keys()
unique_keywords
# Out:
# dict_keys(['special lady', 'different account', 'nice service', 'best staff', 'online bank', 'prompt decision', 'good customer', 'important person', 'best interest', 'wonderful relief', 'wonderful reminder', 'sweet lady', 'courteous time', 'helpful thank', 'sincere gratitude', 'special time', 'fond holiday', 'preferred location', 'great agent', 'excellent customer', 'grateful assistance', 'great staff', 'easy opening', 'great company', 'wiht customer', 'ready sign', 'easy talk', 'friendly point', 'pleased timeliness', 'little direction', 'smooth process', 'prompt customer', 'financial need', 'excellent rate', 'great experience', 'new customer', 'last month', 'easy work', 'fast response', 'fast releasing', 'interested daughter', 'enough help', 'many year', 'friendly make', 'overall experience', 'pleased customer', 'short notice', 'smooth hassle', 'personal loan', 'dugood bank', 'low interest', 'fast sign', 'free pleasure', 'tara baloney', 'favorite place', 'happy holiday', 'welcome atmusefear', 'quick stress', 'free cara', 'speak loan', 'important today', 'easy office', 'dugood branch', 'easy transfer', 'complete transaction', 'local branch', 'complete portion', 'best option', 'great job', 'pleasant staff', 'great customer', 'different time', 'new air', 'easy access', 'mean information', 'financial business', 'anytime day', 'dugood app', 'real person', 'new vehicle', 'concerned lunch', 'online experience', 'representative branch', 'confirm information', 'knowledgeable thanks', 'perfect opportunity', 'easy purchase', 'helpful kind', 'nice point', 'local credit', 'cu employee', 'great work', 'dugood staff', 'first pauline', 'villarreal christine', 'religious belief', 'necessary experience', 'great service', 'open account', 'pleased service', 'new job', 'personal account', 'worth area', 'bad experience', 'financial institution', 'great communication', 'new money', 'online process', 'simple call', 'friendly one', 'auxiliary air', 'easy use', 'whole process', 'easy end', 'nice work', 'top world', 'wonderful employee', 'thrilled experience', 'second loan', 'happy member', 'difficult time', 'grateful member', 'courteous star', 'dugood year', 'fast help', 'pro painless', 'wonderful work', 'live hour', 'want business', 'exceptional loan', 'efficient thank', 'happy staff', 'nice business', 'long time', 'knowledgeable product', 'small loan', 'frank estes', 'reliable communication', 'quick service', 'big help', 'main line', 'direct line', 'applied loan', 'open bank', 'professional staff', 'late day', 'new account', 'enough word', 'special make', 'pleasant experience', 'answered question', 'easy simple', 'helpful employee', 'wonderful job', 'trustworthy customer', 'happy ease', 'dugood banking', 'professional service', 'awesome people', 'great thank', 'outstanding work', 'patient bit', 'important thank', 'excellent care', 'accurate look', 'dugood future', 'exceptional service', 'hard work', 'wonderful customer', 'friendly staff', 'convenient location', 'awesome experience', 'finicial affair', 'assest company', 'comfortable communication', 'high touch', 'clear step', 'quick help', 'easy transaction', 'federal credit', 'happy service', 'quick response', 'excellent service', 'expert advice', 'real people', 'excellent experience', 'helpful service', 'easy thank', 'timely manner', 'first class', 'helpful informative', 'better service', 'big bank', 'helpful vidor', 'friendly name', 'best customer', 'respectful work', 'helpful staff', 'nice people', 'easy process', 'helpful pleasure', 'great attention', 'much appreciate', 'helpful team', 'fabulous experience', 'amazing customer', 'amazing help', 'future business', 'good result', 'little trouble', 'closed loan', 'amazing service', 'great member', 'friendly service', 'personal service', 'great love', 'best banking', 'easy effortless', 'friendly employee', 'quick loan', 'best experience', 'true customer', 'efficient manner', 'nice lady', 'big girl', 'key car', 'nice bank', 'whole experience', 'compet ...

# %%
clustures = []

used_keywords = []

for i in tqdm(unique_keywords):
    current_custer = [i]
    
    if (i in used_keywords):
        continue
    
    used_keywords.append(i)
    
    
    for j in unique_keywords:
        if  (j in used_keywords):
            continue
    
        current_score = similarity_calc(i,j)
        if current_score>0.7:
            current_custer.append(j)
            used_keywords.append(j)
            
    
    clustures.append(current_custer)
        
#     break
# Out:
#   1%|▎                                     | 14/1933 [07:48<14:36:24, 27.40s/it]

# %%
len(clustures)

# %%
clustures[:10]

# %%
final_result = []
for cp in clustures:
    cluster_key_count = {}
    for key_c in cp:
        cluster_key_count[key_c] = freq_count[key_c]
    
    items = []
    for i in list(tuple(cluster_key_count.keys())):
        items.append(i.split()[0])
    dict1 = {}
    for item in items:
        if not item in dict1:
            dict1[item] = items.count(item)
    dict1 = sorted(dict1.keys(), reverse=True)[0]

    curr_cul_keys = list(cluster_key_count.keys())
    curr_cul_values = list(cluster_key_count.values())
    sum_of_similar_words = np.sum(curr_cul_values)
    highest_count_key = curr_cul_keys[np.argmax(curr_cul_values)]
    highest_count_value = np.max(curr_cul_values)
    final_result.append([cluster_key_count,sum_of_similar_words,highest_count_key,len(cluster_key_count), dict1])
    
#     break

# %%
final_result

# %%
df = pd.DataFrame(final_result,columns=["similar_words_and_count","count_of_similar_words","most_used_similar_word","total_similar_words", "key_expressions"])

# %%
sorted_df = df.sort_values('total_similar_words',ascending=False).reset_index(drop=True)

# %%
sorted_df

# %%
sorted_df.to_csv("/home/heptagon/Desktop/nps_review_analysis/most_keywords.csv", index=False)

# %%
print((sorted_df.most_used_similar_word).to_list()[:20])
