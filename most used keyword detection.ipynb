# %%
from transformers import AutoTokenizer, AutoModel
import torch
import pandas as pd
import numpy as np
import re
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import warnings
from wordcloud import WordCloud, STOPWORDS

warnings.filterwarnings("ignore")

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
model = AutoModel.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0]  # First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min = 1e-9)


def embeding_calc(sentences):

    # tokenizing
    encoded_input = tokenizer(sentences, padding = True, truncation = True, return_tensors = 'pt')

    # passing though model
    with torch.no_grad():
        model_output = model(**encoded_input)

    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    return sentence_embeddings

# %%
result = embeding_calc(['balanced sound','good sound'])

# %%
len(result)
# Out:
# 2

# %%
score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))

# %%
score[0][0]
# Out:
# 0.7417778

# %%
def similarity_calc(input1,input2):
    result = embeding_calc([input1,input2])
    score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))
    return score[0][0]

# %%
similarity_calc('balanced sound','poor bose')
# Out:
# 0.16619003

# %% [markdown]
# # Data processing

# %%
df = pd.read_csv('/home/heptagon/Desktop/nps_review_analysis/dataset/network_capital_funding_detail_review_topic.csv')
df.head()
# Out:
#                                             comments  \
# 0  Working with Eddie Claus was a great experienc...
# 1  Deiago Lorenzo excellent service My wife just ...
# 2  Our experience with Network Capital was awesom...
# 3  I recently expirenced an online home loan refi...
# 4  Chris our processor was friendly personable an...
#
#                                                topic sentiment          type
# 0        great experience,previous loan,left company  NEGATIVE   information
# 1     excellent service,whole process,whole progress  POSITIVE  appreciation
# 2                                  knowledgeable job  POSITIVE   information
# 3  online home,nervous process,technical skill,pa...  POSITIVE   information
# 4             hard team,stressful side,quick process  POSITIVE   information

# %%
all_keyword = []
for key_str in tqdm(df.topic):
#     print(key_str)
    splited_str = key_str.split(',')
    if len(splited_str)>0:
        all_keyword += splited_str
#     break

all_keyword
# Out:
# 100%|█████████████████████████████████████| 315/315 [00:00<00:00, 333469.40it/s]
# ['great experience',
#  'previous loan',
#  'left company',
#  'excellent service',
#  'whole process',
#  'whole progress',
#  'knowledgeable job',
#  'online home',
#  'nervous process',
#  'technical skill',
#  'patient question',
#  'best way',
#  'entire process',
#  'hard team',
#  'stressful side',
#  'quick process',
#  'many year',
#  'married home',
#  'quick mortgage',
#  'close contact',
#  'great guy',
#  'recommend service',
#  'crazy money',
#  'top notch',
#  'long relationship',
#  'front line',
#  'best network',
#  'overall experience',
#  'much norm',
#  'appraiser return',
#  'round trip',
#  'expensive amount',
#  'original visit',
#  'great word',
#  'due way',
#  'available answer',
#  'upbeat attitude',
#  'pleasing voice',
#  'many year',
#  'best knowledge',
#  'great human',
#  'nice lady',
#  'final process',
#  'future assistance',
#  'shortest time',
#  'best outcome',
#  'accurate information',
#  'good work',
#  'new property',
#  'whole package',
#  'fantastic work',
#  'much leg',
#  'indispensable process',
#  'great rate',
#  'courteous deliver',
#  'whole process',
#  'courteous professional',
#  'full detail',
#  'right angel',
#  'whole time',
#  'awesome company',
#  'conditional approval',
#  'ryan barrientos',
#  'helpful question',
#  'satisfied result',
#  'separate people',
#  'great job',
#  'numerous obstacle',
#  'good thing',
#  'many lender',
#  'entire process',
#  'wonderful experience',
#  'past year',
#  'net capital',
#  'alexa love',
#  'informed process',
#  'stressful knowing',
#  'helpful hurdle',
#  'great work',
#  'entire process',
#  'anytime question',
#  'first time',
#  'nice patient',
#  'dumb question',
#  'critical time',
#  'excellent experience',
#  'thankful way',
#  'several hurdle',
#  'easy thank',
#  'timely fashion',
#  'facilitated processing',
#  'smooth look',
#  'informative understanding',
#  'melissa title',
#  'disappointed lack',
#  'expeditious processing',
#  'financial crunch',
#  'industrious execution',
#  'bureaucratic process',
#  'excellent customer',
#  'qualified loan',
#  'extreme patience',
#  'several occasion',
#  'current experience',
#  'great customer',
#  'adrian fernandez',
#  'current refinance',
#  'entire process',
#  'great team',
#  'future mortgage',
#  'ethic appreciate',
#  'much company',
#  'high quality',
#  'necessary paper',
#  'recommend network',
#  'knowledgeable spencer',
#  'good thing',
#  'good thing',
#  'able match',
#  'bad company',
#  'easiest refi',
#  'financial paper',
#  'great interest',
#  'netcap team',
#  'entire process',
#  'finish line',
#  'quick response',
#  'true word',
#  'many detour',
#  'satisfied communication',
#  'satisfied service',
#  'good rate',
#  'high interest',
#  'minimal work',
#  'high praise',
#  'diligent work',
#  'whole process',
#  'satisfied network',
#  'much jenifer',
#  'closed week',
#  'great team',
#  'best refinance',
#  'bad mailing',
#  'good information',
#  'excellent service',
#  'senior loan',
#  'excellent service',
#  'different department',
#  'several message',
#  'notary call',
#  'personal service',
#  'whole process',
#  'professional network',
#  'human asset',
#  'rough lady',
#  'administrative staff',
#  'close begin',
#  'best work',
#  'excellent service',
#  'grateful loan',
#  'amazing help',
#  'flexible waste',
#  'professional job',
#  'good listener',
#  'hard work',
#  'closed loan',
#  'large debt',
#  'great part',
#  'great team',
#  'next mortgage',
#  'zachary team',
#  'great year',
#  'ramos talk',
#  'willing help',
#  'great birthday',
#  'easy company',
#  'human help',
#  'awesome thanks',
#  'personal attention',
#  'helpful process',
#  'great company',
#  'individual case',
#  'best thanksnoushin',
#  'long order',
#  'sure team',
#  'easy need',
#  'glad today',
#  'marvelous job',
#  'best experience',
#  'best job',
#  'helpful completing',
#  'able use',
#  'big raise',
#  'entire refinance',
#  'overall experience',
#  'helpful company',
#  'limited insight',
#  'exceptional employee',
#  'ryan barrientos',
#  'thorough attention',
#  'comfortable staff',
#  'available patience',
#  'outstanding work',
#  'first phone',
#  'several day',
#  'favorable need',
#  'best product',
#  'available answer',
#  'major freak',
#  'bureaucratic nightmare',
#  'humorous presence',
#  'prime shipping',
#  'samuel louellens',
#  'whole process',
#  'fantastic work',
#  'different company',
#  'invaluable wife',
#  'best loan',
#  'many mortgage',
#  'best loan',
#  'immediate grasp',
#  'extensive request',
#  'multiple option',
#  'perfect loan',
#  'many friend',
#  'relative contact',
#  'first choice',
#  'extended family',
#  'helpful making',
#  'wonderful experience',
#  'real life',
#  'extraordinary experience',
#  'committed schedule',
#  'urgent need',
#  'close refinancing',
#  'effective planning',
#  'unbelievable achievement',
#  'successful financing',
#  'first place',
#  'sincere person',
#  'patient folk',
#  'sure information',
#  'confident friend',
#  'incredible job',
#  'amazing team',
#  'professional enjoy',
#  'perfect pair',
#  'excellent customer',
#  'knowledgeable area',
#  'current mortgage',
#  'overall rating',
#  'easy process',
#  'professional prompt',
#  'great experience',
#  'explained process',
#  'close week',
#  'great service',
#  'first time',
#  'empathic situation',
#  'difficult process',
#  'amazing friend',
#  'new family',
#  'best job',
#  'great job',
#  'enjoyable work',
#  'best addition',
#  'great work',
#  'easy work',
#  'testy moment',
#  'pleased interaction',
#  'total loan',
#  'personal touch',
#  'several experience',
#  'financial institution',
#  'outstanding teamwork',
#  'efficient help',
#  'complete task',
#  'financial assistance',
#  'future thing',
#  'personal nature',
#  'good job',
#  'necessary feedback',
#  'ongoing process',
#  'excellent work',
#  'excellent team',
#  'helpful guy',
#  'able answer',
#  'great experience',
#  'excellent experience',
#  'good credit',
#  'good bonus',
#  'attractive user',
#  'friendly site',
#  'regular customer',
#  'amazing app',
#  'transparent thoughtful',
#  'best rate',
#  'huge thank',
#  'stressful team',
#  'right thank',
#  'hard work',
#  'different property',
#  'complete mortgage',
#  'longer network',
#  'first date',
#  'initial call',
#  'positive experience',
#  'pleasant manner',
#  'great experience',
#  'available help',
#  'extra effort',
#  'great experience',
#  'sarah franc',
#  'future thank',
#  'unorganized loan',
#  'awesome experience',
#  'able answer',
#  'good rush',
#  'good attitude',
#  'responsive question',
#  'sure process',
#  'scan document',
#  'usual thinking',
#  'outside job',
#  'complete loan',
#  'best experience',
#  'excellent service',
#  'dedicated people',
#  'great work',
#  'much zach',
#  'great people',
#  'great work',
#  'thankful team',
#  'good company',
#  'professional staff',
#  'pleasant work',
#  'great employee',
#  'final stage',
#  'quick claim',
#  'wonderful job',
#  'truthful talking',
#  'sabeastian aviles',
#  'wonderful company',
#  'primary residence',
#  'bandaid loan',
#  'best understanding',
#  'many suggestion',
#  'necessary document',
#  'professional trouble',
#  'whole process',
#  'gracious appreciate',
#  'easy thank',
#  'excellent service',
#  'able help',
#  'fast service',
#  'happy service',
#  'second business',
#  'pleased process',
#  'happy outcome',
#  'excellent attention',
#  'motivated way',
#  'many year',
#  'past week',
#  'great recommendation',
#  'great friend',
#  'high school',
#  'best lot',
#  'good loan',
#  'genuine person',
#  'great attribute',
#  'many step',
#  'amazed pace',
#  'overall experience',
#  'great experience',
#  'amazing people',
#  'beautiful thank',
#  'available question',
#  'best loan',
#  'difficult circumstance',
#  'difficult set',
#  'creative follow',
#  'divorced woman',
#  'financial situation',
#  'many time',
#  'amazing mortgage',
#  'bad joke',
#  'professional demeaner',
#  'rocky journey',
#  'ethic patience',
#  'honesty drive',
#  'pleasant work',
#  'reliable transaction',
#  'best place',
#  'several time',
#  'great result',
#  'first time',
#  'new sale',
#  'quick turn',
#  'responsive help',
#  'professional style',
#  'priceless paul',
#  'top notch',
#  'excellent customer',
#  'nayeli processing',
#  'stressful moment',
#  'awful deal',
#  'critical time',
#  'deserved review',
#  'stressful period',
#  'entire process',
#  'great experience',
#  'honest company',
#  'fantastic advice',
#  'corporate ethic',
#  'happy coustmer',
#  'helpful process',
#  'great thanks',
#  'great job',
#  'great people',
#  'better rate',
#  'new purchase',
#  'different lender',
#  'sure loan',
#  'excellent job',
#  'new purchase',
#  'top notch',
#  'fantastic experience',
#  'friendly service',
#  'good communication',
#  'fast service',
#  'best customer',
#  'trustworthy employee',
#  'good service',
#  'exceptional service',
#  'top account',
#  'substantial saving',
#  'third party',
#  'unbiased lending',
#  'normal debt',
#  'easy process',
#  'wonderful staff',
#  'great attitude',
#  'fast action',
#  'good team',
#  'multiple call',
#  'nebulous answer',
#  'next step',
#  'old survey',
#  'least pocket',
#  'reduced income',
#  'national capital',
#  'initial quote',
#  'easy process',
#  'free process',
#  'lower others',
#  'least people',
#  'expensive way',
#  'recommend network',
#  'quick professional',
#  'whole team',
#  'great alot',
#  'great communication',
#  'easy talk',
#  'excellent service',
#  'thankful speed',
#  'different people',
#  'lower rate',
#  'certain thing',
#  'correct path',
#  'good communication',
#  'close mortgage',
#  'main goal',
#  'main goal',
#  'satisfied thank',
#  'hesitate refer',
#  'lower rate',
#  'higher ups',
#  'personal conversation',
#  'personal phone',
#  'exceptional salesman',
#  'great guy',
#  'lucky team',
#  'smoothest transaction',
#  'awesome deal',
#  'refi simple',
#  'informed requirement',
#  'great service',
#  'answered question',
#  'financial scenario',
#  'best experience',
#  'current information',
#  'whole process',
#  'whole process',
#  'great guy',
#  'entire process',
#  'accessible attentive',
#  'entire process',
#  'outstanding tyler',
#  'professional tyler',
#  'closed time',
#  'reassured process',
#  'smooth sailing',
#  'big thank',
#  'whole way',
#  'great asset',
#  'proper expectation',
#  'whole process',
#  'amazing experience',
#  'edgar guide',
#  'whole way',
#  'insurmountable obstacle',
#  'initial conversation',
#  'tremendous network',
#  'excellent loan',
#  'excellent term',
#  'pleased company',
#  'terrible chose',
#  'afraid process',
#  'positive experience',
#  'much money',
#  'due debt',
#  'stellar credit',
#  'advantageous refinance',
#  'financial shape',
#  'monthly bill',
#  'respectful professionalism',
#  'much people',
#  'happen network',
#  'satisfied service',
#  'financial transaction',
#  'entire process',
#  'well professionalism',
#  'small hoop',
#  'best loan',
#  'professional polite',
#  'close loan',
#  'first language',
#  'sure wife',
#  'new goto',
#  'many deal',
#  'twice refinance',
#  'necessary loan',
#  'ready purchase',
#  'pleasant experience',
#  'senior mortgage',
#  'many question',
#  'matter hour',
#  'least day',
#  'whole process',
#  'great people',
#  'whole process',
#  'second time',
#  'wonderful experience',
#  'first time',
#  'highest review',
#  'possible paperwork',
#  'great thing',
#  'whole procedure',
#  'pleasant experience',
#  'first contact',
#  'total understanding',
#  'important person',
#  'reassured process',
#  'little question',
#  'satisfied refi',
#  'great experience',
#  'awesome percent',
#  'whole process',
#  'entire process',
#  'great transaction',
#  'easy process',
#  'helpful agent',
#  'pleased report',
#  'initial conversation',
#  'interested loan',
#  'competitive offer',
#  'entire process',
#  'key point',
#  'competitive rate',
#  'closer textbook',
#  'fantastic company',
#  'easy loan',
#  'professional mortgage',
#  'close home',
#  'higher promotion',
#  'great people',
#  'great job',
#  'quickest mortgage',
#  'financial document',
#  'right discount',
#  'aware discount',
#  'necessary correction',
#  'new proposal',
#  'ready close',
#  'new loan',
#  'new proposal',
#  'monthly mortgage',
#  'innumerable hour',
#  'long story',
#  'new loan',
#  'several month',
#  'sorry tax',
#  'real estate',
#  'frustrating refi',
#  'nice guy',
#  'professional issue',
#  'financial future',
#  'entire experience',
#  'helpful experience',
#  'nice people',
#  'great company',
#  'great experience',
#  'recommend company',
#  'reasonable expense',
#  'major disappointment',
#  'prior appraisal',
#  'excessive insult',
#  'good condition',
#  'excessive opinion',
#  'great team',
#  'whole process',
#  'new home',
#  'competitive interest',
#  'double cash',
#  'abreast loan',
#  'comfortable retirement',
#  'several option',
#  'net closing',
#  'third company',
#  'certain question',
#  'previous lender',
#  'quickly loan',
#  'direct lending',
#  'exceptional customer',
#  'knowledgeable process',
#  'friendly customer',
#  'excellent work',
#  'knowledgeable process',
#  'difficult task',
#  'easy pleasure',
#  'many thanks',
#  'exceptional service',
#  'safe company',
#  'hard work',
#  'great service',
#  'right path',
#  'servicing lead',
#  'smooth stress',
#  'free thank',
#  'right decision',
#  'great rate',
#  'associate ericka',
#  'easy work',
#  'matter thanks',
#  'amazing joy',
#  'professional process',
#  'fast thank',
#  'professional work',
#  'recommend network',
#  'relative thank',
#  'rough time',
#  'sole income',
#  'entire process',
#  'regular basis',
#  'timely manner',
#  'honest refinance',
#  'enough professionalism',
#  'much guy',
#  'great service',
#  'great rate',
#  'excellent result',
#  'streamlined communication',
#  'senior loan',
#  'professional manner',
#  'satisfied star',
#  'helpful refinancing',
#  'great work',
#  'happy service',
#  'personable thinking',
#  'rite lady',
#  'helpful time',
#  'good work',
#  'top paper',
#  'last week',
#  'large part',
#  'awesome part',
#  'entire process',
#  'normal work',
#  'many instance',
#  'honest company',
#  'single email',
#  'entire email',
#  'separate email',
#  'common practice',
#  'new thread',
#  'original agreement',
#  'several house',
#  'free concern',
#  'final word',
#  'good person',
#  'matter time',
#  'easy experience',
#  'good job',
#  'great job',
#  'weekly update',
#  'perfect credit',
#  'happen network',
#  'hard work',
#  'past working',
#  'top process',
#  'smooth process',
#  'first time',
#  'second time',
#  'fantastic member',
#  'informative encouraging',
#  'wonderful woman',
#  'bigger house',
#  'tight spot',
#  'single family',
#  'little hand',
#  'top mother',
#  'past year',
#  'good thing',
#  'little unsure',
#  'knowledgeable line',
#  'good job',
#  'little life',
#  'open heart',
#  'old hospital',
#  'great hope',
#  'separate occasion',
#  'compassionate life',
#  'serious surgery',
#  'great job',
#  'concerned son',
#  'awesome job',
#  'professional service',
#  'fastest refi',
#  'fantastic work',
#  'trustworthy work',
#  'consolidated mortgage',
#  'better term',
#  'good communication',
#  'many question',
#  'amazing people',
#  'higher star',
#  'successful experience',
#  'future thank',
#  'first house',
#  'right mortgage',
#  'stressful process',
#  'repetitive sincerity',
#  'first time',
#  'whole process',
#  'whole process',
#  'great rate',
#  'good company',
#  'fast time',
#  'better broker',
#  'recommend people',
#  'hard work',
#  'able refin',
#  'current lender',
#  'timely manner',
#  'good experience',
#  'effective thought',
#  'first situation',
#  'effortlessly execution',
#  'painless process',
#  'easy process',
#  'good experience',
#  'nice work',
#  'standard practice',
#  'many thanks',
#  'monthly payment',
#  'due change',
#  'actual payment',
#  'huge difference',
#  'monthly payment',
#  'criminal practice',
#  'close attention',
#  'reputable company',
#  'easy work',
#  'smooth process',
#  'financial need',
#  'courteous agent',
#  'fortunate agent',
#  'helpful time',
#  'best interest',
#  'thankful feel',
#  'recommend company',
#  'informed case',
#  'simple thanks',
#  'respectful time',
#  'next thing',
#  'best remortgage',
#  'great job',
#  'happy way',
#  'great rate',
#  'previous network',
#  'smoother loan',
#  'wonderful experience',
#  'excellent deal',
#  'best company',
#  'whole process',
#  'great job',
#  'random call',
#  'explicit company',
#  'absolute professionalism',
#  'good experience',
#  'helpful polite',
#  'back question',
#  'great experience',
#  'complicated mortgage',
#  'top thing',
#  'whole process',
#  'phenomenal timing',
#  'special thanks',
#  'great rate',
#  'entire process',
#  'wonderful experience',
#  'timely pain',
#  'developed rely',
#  'kind information',
#  'last week',
#  'representative company',
#  'leery scam',
#  'serious consequence',
#  'able research',
#  'real company',
#  'several ups',
#  'due requirement',
#  'previous refinance',
#  'new load',
#  'first refi',
#  'initial refi',
#  'fantastic job',
#  'different company',
#  'closer underwriting',
#  'wrong check',
#  'nice people',
#  'wonderful work',
#  'seamless process',
#  'best interest',
#  'professional kind',
#  'professional refi',
#  'great company',
#  'available help',
#  'fast service',
#  'multiple fi',
#  'last minute',
#  'successful experience',
#  'positive attitude',
#  'glad wife',
#  'informed loan',
#  'excellent customer',
#  'constant communication',
#  'personal touch',
#  'exemplary employee',
#  'high tech',
#  'highest rate',
#  'satisfied service',
#  'bottom heart',
#  'wonderful job',
#  'excellent service',
#  'second refinance',
#  'complete transaction',
#  'correct paper',
#  'much anouk',
#  'many people',
#  'excellent service',
#  'recommend network',
#  'beat competitor',
#  'reliable service',
#  'whole process',
#  'entire way',
#  'reassuring time',
#  'representative company',
#  'great advice',
#  'good job',
#  'great customer',
#  'smooth silk',
#  'easiest refi',
#  'understandable employee',
#  'speak finance',
#  'single time',
#  'best example',
#  'amazing thank',
#  'third home',
#  'amazing experience',
#  'great work',
#  'able lock',
#  'good experience',
#  'happy result',
#  'online tool',
#  'several refi',
#  'last year',
#  'friendly lender',
#  'lowest cost',
#  'quick respond',
#  'possible time',
#  'easiest process',
#  'outstanding work',
#  'excellent customer',
#  'closed week',
#  'exceptional help',
#  'knowledgeable loan',
#  'great company',
#  'conventional loan',
#  'genuine experience',
#  'pleasant experience',
#  'great job',
#  'pleased w',
#  'firm network',
#  'great interaction',
#  'anytime question',
#  'much information',
#  'previous mortgage',
#  'smooth transition',
#  'great company',
#  'monthly payment',
#  'pleasant experience',
#  'unsolicited robo',
#  'first instinct',
#  'good credit',
#  'closed day',
#  'able reach',
#  'stressful process',
#  'well expedience',
#  'main reason',
#  'whole process',
#  'extreme pleasure',
#  'first mortgage',
#  'previous home',
#  'close professionalism',
#  'representative company',
#  'excellent procurement',
#  'full time',
#  'personal note',
#  'traditional bank',
#  'notary come',
#  'best service',
#  'entire process',
#  'byzantine process',
#  'local notary',
#  'interested mortgage',
#  'best refi']

# %%
freq_count = {}
for key in all_keyword:
    if key in freq_count:
        freq_count[key] +=1
    else:
        freq_count[key] = 1

# %%
len(freq_count)
# Out:
# 751

# %%
freq_count
# Out:
# {'great experience': 10,
#  'previous loan': 1,
#  'left company': 1,
#  'excellent service': 9,
#  'whole process': 19,
#  'whole progress': 1,
#  'knowledgeable job': 1,
#  'online home': 1,
#  'nervous process': 1,
#  'technical skill': 1,
#  'patient question': 1,
#  'best way': 1,
#  'entire process': 15,
#  'hard team': 1,
#  'stressful side': 1,
#  'quick process': 1,
#  'many year': 3,
#  'married home': 1,
#  'quick mortgage': 1,
#  'close contact': 1,
#  'great guy': 3,
#  'recommend service': 1,
#  'crazy money': 1,
#  'top notch': 3,
#  'long relationship': 1,
#  'front line': 1,
#  'best network': 1,
#  'overall experience': 3,
#  'much norm': 1,
#  'appraiser return': 1,
#  'round trip': 1,
#  'expensive amount': 1,
#  'original visit': 1,
#  'great word': 1,
#  'due way': 1,
#  'available answer': 2,
#  'upbeat attitude': 1,
#  'pleasing voice': 1,
#  'best knowledge': 1,
#  'great human': 1,
#  'nice lady': 1,
#  'final process': 1,
#  'future assistance': 1,
#  'shortest time': 1,
#  'best outcome': 1,
#  'accurate information': 1,
#  'good work': 2,
#  'new property': 1,
#  'whole package': 1,
#  'fantastic work': 3,
#  'much leg': 1,
#  'indispensable process': 1,
#  'great rate': 6,
#  'courteous deliver': 1,
#  'courteous professional': 1,
#  'full detail': 1,
#  'right angel': 1,
#  'whole time': 1,
#  'awesome company': 1,
#  'conditional approval': 1,
#  'ryan barrientos': 2,
#  'helpful question': 1,
#  'satisfied result': 1,
#  'separate people': 1,
#  'great job': 9,
#  'numerous obstacle': 1,
#  'good thing': 4,
#  'many lender': 1,
#  'wonderful experience': 5,
#  'past year': 2,
#  'net capital': 1,
#  'alexa love': 1,
#  'informed process': 1,
#  'stressful knowing': 1,
#  'helpful hurdle': 1,
#  'great work': 6,
#  'anytime question': 2,
#  'first time': 6,
#  'nice patient': 1,
#  'dumb question': 1,
#  'critical time': 2,
#  'excellent experience': 2,
#  'thankful way': 1,
#  'several hurdle': 1,
#  'easy thank': 2,
#  'timely fashion': 1,
#  'facilitated processing': 1,
#  'smooth look': 1,
#  'informative understanding': 1,
#  'melissa title': 1,
#  'disappointed lack': 1,
#  'expeditious processing': 1,
#  'financial crunch': 1,
#  'industrious execution': 1,
#  'bureaucratic process': 1,
#  'excellent customer': 5,
#  'qualified loan': 1,
#  'extreme patience': 1,
#  'several occasion': 1,
#  'current experience': 1,
#  'great customer': 2,
#  'adrian fernandez': 1,
#  'current refinance': 1,
#  'great team': 4,
#  'future mortgage': 1,
#  'ethic appreciate': 1,
#  'much company': 1,
#  'high quality': 1,
#  'necessary paper': 1,
#  'recommend network': 4,
#  'knowledgeable spencer': 1,
#  'able match': 1,
#  'bad company': 1,
#  'easiest refi': 2,
#  'financial paper': 1,
#  'great interest': 1,
#  'netcap team': 1,
#  'finish line': 1,
#  'quick response': 1,
#  'true word': 1,
#  'many detour': 1,
#  'satisfied communication': 1,
#  'satisfied service': 3,
#  'good rate': 1,
#  'high interest': 1,
#  'minimal work': 1,
#  'high praise': 1,
#  'diligent work': 1,
#  'satisfied network': 1,
#  'much jenifer': 1,
#  'closed week': 2,
#  'best refinance': 1,
#  'bad mailing': 1,
#  'good information': 1,
#  'senior loan': 2,
#  'different department': 1,
#  'several message': 1,
#  'notary call': 1,
#  'personal service': 1,
#  'professional network': 1,
#  'human asset': 1,
#  'rough lady': 1,
#  'administrative staff': 1,
#  'close begin': 1,
#  'best work': 1,
#  'grateful loan': 1,
#  'amazing help': 1,
#  'flexible waste': 1,
#  'professional job': 1,
#  'good listener': 1,
#  'hard work': 5,
#  'closed loan': 1,
#  'large debt': 1,
#  'great part': 1,
#  'next mortgage': 1,
#  'zachary team': 1,
#  'great year': 1,
#  'ramos talk': 1,
#  'willing help': 1,
#  'great birthday': 1,
#  'easy company': 1,
#  'human help': 1,
#  'awesome thanks': 1,
#  'personal attention': 1,
#  'helpful process': 2,
#  'great company': 5,
#  'individual case': 1,
#  'best thanksnoushin': 1,
#  'long order': 1,
#  'sure team': 1,
#  'easy need': 1,
#  'glad today': 1,
#  'marvelous job': 1,
#  'best experience': 3,
#  'best job': 2,
#  'helpful completing': 1,
#  'able use': 1,
#  'big raise': 1,
#  'entire refinance': 1,
#  'helpful company': 1,
#  'limited insight': 1,
#  'exceptional employee': 1,
#  'thorough attention': 1,
#  'comfortable staff': 1,
#  'available patience': 1,
#  'outstanding work': 2,
#  'first phone': 1,
#  'several day': 1,
#  'favorable need': 1,
#  'best product': 1,
#  'major freak': 1,
#  'bureaucratic nightmare': 1,
#  'humorous presence': 1,
#  'prime shipping': 1,
#  'samuel louellens': 1,
#  'different company': 2,
#  'invaluable wife': 1,
#  'best loan': 4,
#  'many mortgage': 1,
#  'immediate grasp': 1,
#  'extensive request': 1,
#  'multiple option': 1,
#  'perfect loan': 1,
#  'many friend': 1,
#  'relative contact': 1,
#  'first choice': 1,
#  'extended family': 1,
#  'helpful making': 1,
#  'real life': 1,
#  'extraordinary experience': 1,
#  'committed schedule': 1,
#  'urgent need': 1,
#  'close refinancing': 1,
#  'effective planning': 1,
#  'unbelievable achievement': 1,
#  'successful financing': 1,
#  'first place': 1,
#  'sincere person': 1,
#  'patient folk': 1,
#  'sure information': 1,
#  'confident friend': 1,
#  'incredible job': 1,
#  'amazing team': 1,
#  'professional enjoy': 1,
#  'perfect pair': 1,
#  'knowledgeable area': 1,
#  'current mortgage': 1,
#  'overall rating': 1,
#  'easy process': 5,
#  'professional prompt': 1,
#  'explained process': 1,
#  'close week': 1,
#  'great service': 4,
#  'empathic situation': 1,
#  'difficult process': 1,
#  'amazing friend': 1,
#  'new family': 1,
#  'enjoyable work': 1,
#  'best addition': 1,
#  'easy work': 3,
#  'testy moment': 1,
#  'pleased interaction': 1,
#  'total loan': 1,
#  'personal touch': 2,
#  'several experience': 1,
#  'financial institution': 1,
#  'outstanding teamwork': 1,
#  'efficient help': 1,
#  'complete task': 1,
#  'financial assistance': 1,
#  'future thing': 1,
#  'personal nature': 1,
#  'good job': 4,
#  'necessary feedback': 1,
#  'ongoing process': 1,
#  'excellent work': 2,
#  'excellent team': 1,
#  'helpful guy': 1,
#  'able answer': 2,
#  'good credit': 2,
#  'good bonus': 1,
#  'attractive user': 1,
#  'friendly site': 1,
#  'regular customer': 1,
#  'amazing app': 1,
#  'transparent thoughtful': 1,
#  'best rate': 1,
#  'huge thank': 1,
#  'stressful team': 1,
#  'right thank': 1,
#  'different property': 1,
#  'complete mortgage': 1,
#  'longer network': 1,
#  'first date': 1,
#  'initial call': 1,
#  'positive experience': 2,
#  'pleasant manner': 1,
#  'available help': 2,
#  'extra effort': 1,
#  'sarah franc': 1,
#  'future thank': 2,
#  'unorganized loan': 1,
#  'awesome experience': 1,
#  'good rush': 1,
#  'good attitude': 1,
#  'responsive question': 1,
#  'sure process': 1,
#  'scan document': 1,
#  'usual thinking': 1,
#  'outside job': 1,
#  'complete loan': 1,
#  'dedicated people': 1,
#  'much zach': 1,
#  'great people': 4,
#  'thankful team': 1,
#  'good company': 2,
#  'professional staff': 1,
#  'pleasant work': 2,
#  'great employee': 1,
#  'final stage': 1,
#  'quick claim': 1,
#  'wonderful job': 2,
#  'truthful talking': 1,
#  'sabeastian aviles': 1,
#  'wonderful company': 1,
#  'primary residence': 1,
#  'bandaid loan': 1,
#  'best understanding': 1,
#  'many suggestion': 1,
#  'necessary document': 1,
#  'professional trouble': 1,
#  'gracious appreciate': 1,
#  'able help': 1,
#  'fast service': 3,
#  'happy service': 2,
#  'second business': 1,
#  'pleased process': 1,
#  'happy outcome': 1,
#  'excellent attention': 1,
#  'motivated way': 1,
#  'past week': 1,
#  'great recommendation': 1,
#  'great friend': 1,
#  'high school': 1,
#  'best lot': 1,
#  'good loan': 1,
#  'genuine person': 1,
#  'great attribute': 1,
#  'many step': 1,
#  'amazed pace': 1,
#  'amazing people': 2,
#  'beautiful thank': 1,
#  'available question': 1,
#  'difficult circumstance': 1,
#  'difficult set': 1,
#  'creative follow': 1,
#  'divorced woman': 1,
#  'financial situation': 1,
#  'many time': 1,
#  'amazing mortgage': 1,
#  'bad joke': 1,
#  'professional demeaner': 1,
#  'rocky journey': 1,
#  'ethic patience': 1,
#  'honesty drive': 1,
#  'reliable transaction': 1,
#  'best place': 1,
#  'several time': 1,
#  'great result': 1,
#  'new sale': 1,
#  'quick turn': 1,
#  'responsive help': 1,
#  'professional style': 1,
#  'priceless paul': 1,
#  'nayeli processing': 1,
#  'stressful moment': 1,
#  'awful deal': 1,
#  'deserved review': 1,
#  'stressful period': 1,
#  'honest company': 2,
#  'fantastic advice': 1,
#  'corporate ethic': 1,
#  'happy coustmer': 1,
#  'great thanks': 1,
#  'better rate': 1,
#  'new purchase': 2,
#  'different lender': 1,
#  'sure loan': 1,
#  'excellent job': 1,
#  'fantastic experience': 1,
#  'friendly service': 1,
#  'good communication': 3,
#  'best customer': 1,
#  'trustworthy employee': 1,
#  'good service': 1,
#  'exceptional service': 2,
#  'top account': 1,
#  'substantial saving': 1,
#  'third party': 1,
#  'unbiased lending': 1,
#  'normal debt': 1,
#  'wonderful staff': 1,
#  'great attitude': 1,
#  'fast action': 1,
#  'good team': 1,
#  'multiple call': 1,
#  'nebulous answer': 1,
#  'next step': 1,
#  'old survey': 1,
#  'least pocket': 1,
#  'reduced income': 1,
#  'national capital': 1,
#  'initial quote': 1,
#  'free process': 1,
#  'lower others': 1,
#  'least people': 1,
#  'expensive way': 1,
#  'quick professional': 1,
#  'whole team': 1,
#  'great alot': 1,
#  'great communication': 1,
#  'easy talk': 1,
#  'thankful speed': 1,
#  'different people': 1,
#  'lower rate': 2,
#  'certain thing': 1,
#  'correct path': 1,
#  'close mortgage': 1,
#  'main goal': 2,
#  'satisfied thank': 1,
#  'hesitate refer': 1,
#  'higher ups': 1,
#  'personal conversation': 1,
#  'personal phone': 1,
#  'exceptional salesman': 1,
#  'lucky team': 1,
#  'smoothest transaction': 1,
#  'awesome deal': 1,
#  'refi simple': 1,
#  'informed requirement': 1,
#  'answered question': 1,
#  'financial scenario': 1,
#  'current information': 1,
#  'accessible attentive': 1,
#  'outstanding tyler': 1,
#  'professional tyler': 1,
#  'closed time': 1,
#  'reassured process': 2,
#  'smooth sailing': 1,
#  'big thank': 1,
#  'whole way': 2,
#  'great asset': 1,
#  'proper expectation': 1,
#  'amazing experience': 2,
#  'edgar guide': 1,
#  'insurmountable obstacle': 1,
#  'initial conversation': 2,
#  'tremendous network': 1,
#  'excellent loan': 1,
#  'excellent term': 1,
#  'pleased company': 1,
#  'terrible chose': 1,
#  'afraid process': 1,
#  'much money': 1,
#  'due debt': 1,
#  'stellar credit': 1,
#  'advantageous refinance': 1,
#  'financial shape': 1,
#  'monthly bill': 1,
#  'respectful professionalism': 1,
#  'much people': 1,
#  'happen network': 2,
#  'financial transaction': 1,
#  'well professionalism': 1,
#  'small hoop': 1,
#  'professional polite': 1,
#  'close loan': 1,
#  'first language': 1,
#  'sure wife': 1,
#  'new goto': 1,
#  'many deal': 1,
#  'twice refinance': 1,
#  'necessary loan': 1,
#  'ready purchase': 1,
#  'pleasant experience': 4,
#  'senior mortgage': 1,
#  'many question': 2,
#  'matter hour': 1,
#  'least day': 1,
#  'second time': 2,
#  'highest review': 1,
#  'possible paperwork': 1,
#  'great thing': 1,
#  'whole procedure': 1,
#  'first contact': 1,
#  'total understanding': 1,
#  'important person': 1,
#  'little question': 1,
#  'satisfied refi': 1,
#  'awesome percent': 1,
#  'great transaction': 1,
#  'helpful agent': 1,
#  'pleased report': 1,
#  'interested loan': 1,
#  'competitive offer': 1,
#  'key point': 1,
#  'competitive rate': 1,
#  'closer textbook': 1,
#  'fantastic company': 1,
#  'easy loan': 1,
#  'professional mortgage': 1,
#  'close home': 1,
#  'higher promotion': 1,
#  'quickest mortgage': 1,
#  'financial document': 1,
#  'right discount': 1,
#  'aware discount': 1,
#  'necessary correction': 1,
#  'new proposal': 2,
#  'ready close': 1,
#  'new loan': 2,
#  'monthly mortgage': 1,
#  'innumerable hour': 1,
#  'long story': 1,
#  'several month': 1,
#  'sorry tax': 1,
#  'real estate': 1,
#  'frustrating refi': 1,
#  'nice guy': 1,
#  'professional issue': 1,
#  'financial future': 1,
#  'entire experience': 1,
#  'helpful experience': 1,
#  'nice people': 2,
#  'recommend company': 2,
#  'reasonable expense': 1,
#  'major disappointment': 1,
#  'prior appraisal': 1,
#  'excessive insult': 1,
#  'good condition': 1,
#  'excessive opinion': 1,
#  'new home': 1,
#  'competitive interest': 1,
#  'double cash': 1,
#  'abreast loan': 1,
#  'comfortable retirement': 1,
#  'several option': 1,
#  'net closing': 1,
#  'third company': 1,
#  'certain question': 1,
#  'previous lender': 1,
#  'quickly loan': 1,
#  'direct lending': 1,
#  'exceptional customer': 1,
#  'knowledgeable process': 2,
#  'friendly customer': 1,
#  'difficult task': 1,
#  'easy pleasure': 1,
#  'many thanks': 2,
#  'safe company': 1,
#  'right path': 1,
#  'servicing lead': 1,
#  'smooth stress': 1,
#  'free thank': 1,
#  'right decision': 1,
#  'associate ericka': 1,
#  'matter thanks': 1,
#  'amazing joy': 1,
#  'professional process': 1,
#  'fast thank': 1,
#  'professional work': 1,
#  'relative thank': 1,
#  'rough time': 1,
#  'sole income': 1,
#  'regular basis': 1,
#  'timely manner': 2,
#  'honest refinance': 1,
#  'enough professionalism': 1,
#  'much guy': 1,
#  'excellent result': 1,
#  'streamlined communication': 1,
#  'professional manner': 1,
#  'satisfied star': 1,
#  'helpful refinancing': 1,
#  'personable thinking': 1,
#  'rite lady': 1,
#  'helpful time': 2,
#  'top paper': 1,
#  'last week': 2,
#  'large part': 1,
#  'awesome part': 1,
#  'normal work': 1,
#  'many instance': 1,
#  'single email': 1,
#  'entire email': 1,
#  'separate email': 1,
#  'common practice': 1,
#  'new thread': 1,
#  'original agreement': 1,
#  'several house': 1,
#  'free concern': 1,
#  'final word': 1,
#  'good person': 1,
#  'matter time': 1,
#  'easy experience': 1,
#  'weekly update': 1,
#  'perfect credit': 1,
#  'past working': 1,
#  'top process': 1,
#  'smooth process': 2,
#  'fantastic member': 1,
#  'informative encouraging': 1,
#  'wonderful woman': 1,
#  'bigger house': 1,
#  'tight spot': 1,
#  'single family': 1,
#  'little hand': 1,
#  'top mother': 1,
#  'little unsure': 1,
#  'knowledgeable line': 1,
#  'little life': 1,
#  'open heart': 1,
#  'old hospital': 1,
#  'great hope': 1,
#  'separate occasion': 1,
#  'compassionate life': 1,
#  'serious surgery': 1,
#  'concerned son': 1,
#  'awesome job': 1,
#  'professional service': 1,
#  'fastest refi': 1,
#  'trustworthy work': 1,
#  'consolidated mortgage': 1,
#  'better term': 1,
#  'higher star': 1,
#  'successful experience': 2,
#  'first house': 1,
#  'right mortgage': 1,
#  'stressful process': 2,
#  'repetitive sincerity': 1,
#  'fast time': 1,
#  'better broker': 1,
#  'recommend people': 1,
#  'able refin': 1,
#  'current lender': 1,
#  'good experience': 4,
#  'effective thought': 1,
#  'first situation': 1,
#  'effortlessly execution': 1,
#  'painless process': 1,
#  'nice work': 1,
#  'standard practice': 1,
#  'monthly payment': 3,
#  'due change': 1,
#  'actual payment': 1,
#  'huge difference': 1,
#  'criminal practice': 1,
#  'close attention': 1,
#  'reputable company': 1,
#  'financial need': 1,
#  'courteous agent': 1,
#  'fortunate agent': 1,
#  'best interest': 2,
#  'thankful feel': 1,
#  'informed case': 1,
#  'simple thanks': 1,
#  'respectful time': 1,
#  'next thing': 1,
#  'best remortgage': 1,
#  'happy way': 1,
#  'previous network': 1,
#  'smoother loan': 1,
#  'excellent deal': 1,
#  'best company': 1,
#  'random call': 1,
#  'explicit company': 1,
#  'absolute professionalism': 1,
#  'helpful polite': 1,
#  'back question': 1,
#  'complicated mortgage': 1,
#  'top thing': 1,
#  'phenomenal timing': 1,
#  'special thanks': 1,
#  'timely pain': 1,
#  'developed rely': 1,
#  'kind information': 1,
#  'representative company': 3,
#  'leery scam': 1,
#  'serious consequence': 1,
#  'able research': 1,
#  'real company': 1,
#  'several ups': 1,
#  'due requirement': 1,
#  'previous refinance': 1,
#  'new load': 1,
#  'first refi': 1,
#  'initial refi': 1,
#  'fantastic job': 1,
#  'closer underwriting': 1,
#  'wrong check': 1,
#  'wonderful work': 1,
#  'seamless process': 1,
#  'professional kind': 1,
#  'professional refi': 1,
#  'multiple fi': 1,
#  'last minute': 1,
#  'positive attitude': 1,
#  'glad wife': 1,
#  'informed loan': 1,
#  'constant communication': 1,
#  'exemplary employee': 1,
#  'high tech': 1,
#  'highest rate': 1,
#  'bottom heart': 1,
#  'second refinance': 1,
#  'complete transaction': 1,
#  'correct paper': 1,
#  'much anouk': 1,
#  'many people': 1,
#  'beat competitor': 1,
#  'reliable service': 1,
#  'entire way': 1,
#  'reassuring time': 1,
#  'great advice': 1,
#  'smooth silk': 1,
#  'understandable employee': 1,
#  'speak finance': 1,
#  'single time': 1,
#  'best example': 1,
#  'amazing thank': 1,
#  'third home': 1,
#  'able lock': 1,
#  'happy result': 1,
#  'online tool': 1,
#  'several refi': 1,
#  'last year': 1,
#  'friendly lender': 1,
#  'lowest cost': 1,
#  'quick respond': 1,
#  'possible time': 1,
#  'easiest process': 1,
#  'exceptional help': 1,
#  'knowledgeable loan': 1,
#  'conventional loan': 1,
#  'genuine experience': 1,
#  'pleased w': 1,
#  'firm network': 1,
#  'great interaction': 1,
#  'much information': 1,
#  'previous mortgage': 1,
#  'smooth transition': 1,
#  'unsolicited robo': 1,
#  'first instinct': 1,
#  'closed day': 1,
#  'able reach': 1,
#  'well expedience': 1,
#  'main reason': 1,
#  'extreme pleasure': 1,
#  'first mortgage': 1,
#  'previous home': 1,
#  'close professionalism': 1,
#  'excellent procurement': 1,
#  'full time': 1,
#  'personal note': 1,
#  'traditional bank': 1,
#  'notary come': 1,
#  'best service': 1,
#  'byzantine process': 1,
#  'local notary': 1,
#  'interested mortgage': 1,
#  'best refi': 1}

# %%
unique_keywords = freq_count.keys()
unique_keywords
# Out:
# dict_keys(['great experience', 'previous loan', 'left company', 'excellent service', 'whole process', 'whole progress', 'knowledgeable job', 'online home', 'nervous process', 'technical skill', 'patient question', 'best way', 'entire process', 'hard team', 'stressful side', 'quick process', 'many year', 'married home', 'quick mortgage', 'close contact', 'great guy', 'recommend service', 'crazy money', 'top notch', 'long relationship', 'front line', 'best network', 'overall experience', 'much norm', 'appraiser return', 'round trip', 'expensive amount', 'original visit', 'great word', 'due way', 'available answer', 'upbeat attitude', 'pleasing voice', 'best knowledge', 'great human', 'nice lady', 'final process', 'future assistance', 'shortest time', 'best outcome', 'accurate information', 'good work', 'new property', 'whole package', 'fantastic work', 'much leg', 'indispensable process', 'great rate', 'courteous deliver', 'courteous professional', 'full detail', 'right angel', 'whole time', 'awesome company', 'conditional approval', 'ryan barrientos', 'helpful question', 'satisfied result', 'separate people', 'great job', 'numerous obstacle', 'good thing', 'many lender', 'wonderful experience', 'past year', 'net capital', 'alexa love', 'informed process', 'stressful knowing', 'helpful hurdle', 'great work', 'anytime question', 'first time', 'nice patient', 'dumb question', 'critical time', 'excellent experience', 'thankful way', 'several hurdle', 'easy thank', 'timely fashion', 'facilitated processing', 'smooth look', 'informative understanding', 'melissa title', 'disappointed lack', 'expeditious processing', 'financial crunch', 'industrious execution', 'bureaucratic process', 'excellent customer', 'qualified loan', 'extreme patience', 'several occasion', 'current experience', 'great customer', 'adrian fernandez', 'current refinance', 'great team', 'future mortgage', 'ethic appreciate', 'much company', 'high quality', 'necessary paper', 'recommend network', 'knowledgeable spencer', 'able match', 'bad company', 'easiest refi', 'financial paper', 'great interest', 'netcap team', 'finish line', 'quick response', 'true word', 'many detour', 'satisfied communication', 'satisfied service', 'good rate', 'high interest', 'minimal work', 'high praise', 'diligent work', 'satisfied network', 'much jenifer', 'closed week', 'best refinance', 'bad mailing', 'good information', 'senior loan', 'different department', 'several message', 'notary call', 'personal service', 'professional network', 'human asset', 'rough lady', 'administrative staff', 'close begin', 'best work', 'grateful loan', 'amazing help', 'flexible waste', 'professional job', 'good listener', 'hard work', 'closed loan', 'large debt', 'great part', 'next mortgage', 'zachary team', 'great year', 'ramos talk', 'willing help', 'great birthday', 'easy company', 'human help', 'awesome thanks', 'personal attention', 'helpful process', 'great company', 'individual case', 'best thanksnoushin', 'long order', 'sure team', 'easy need', 'glad today', 'marvelous job', 'best experience', 'best job', 'helpful completing', 'able use', 'big raise', 'entire refinance', 'helpful company', 'limited insight', 'exceptional employee', 'thorough attention', 'comfortable staff', 'available patience', 'outstanding work', 'first phone', 'several day', 'favorable need', 'best product', 'major freak', 'bureaucratic nightmare', 'humorous presence', 'prime shipping', 'samuel louellens', 'different company', 'invaluable wife', 'best loan', 'many mortgage', 'immediate grasp', 'extensive request', 'multiple option', 'perfect loan', 'many friend', 'relative contact', 'first choice', 'extended family', 'helpful making', 'real life', 'extraordinary experience', 'committed schedule', 'urgent need', 'close refinancing', 'effective planning', 'unbelievable achievement', 'successful financing', 'first place', 'sincere person', 'patient folk', 'sure information', 'confident friend', 'incredible job', 'amazing team', 'p ...

# %%
clustures = []

used_keywords = []

for i in tqdm(unique_keywords):
    current_custer = [i]
    
    if (i in used_keywords):
        continue
    
    used_keywords.append(i)
    
    
    for j in unique_keywords:
        if  (j in used_keywords):
            continue
    
        current_score = similarity_calc(i,j)
        if current_score>0.7:
            current_custer.append(j)
            used_keywords.append(j)
            
    
    clustures.append(current_custer)
        
#     break
# Out:
# 100%|█████████████████████████████████████████| 751/751 [46:03<00:00,  3.68s/it]

# %%
len(clustures)
# Out:
# 384

# %%
clustures[:10]
# Out:
# [['great experience',
#   'overall experience',
#   'great job',
#   'wonderful experience',
#   'excellent experience',
#   'current experience',
#   'marvelous job',
#   'best experience',
#   'extraordinary experience',
#   'incredible job',
#   'great service',
#   'several experience',
#   'positive experience',
#   'awesome experience',
#   'wonderful job',
#   'great result',
#   'excellent job',
#   'fantastic experience',
#   'amazing experience',
#   'pleasant experience',
#   'great thing',
#   'entire experience',
#   'helpful experience',
#   'awesome job',
#   'successful experience',
#   'good experience',
#   'fantastic job',
#   'genuine experience'],
#  ['previous loan',
#   'qualified loan',
#   'senior loan',
#   'best loan',
#   'perfect loan',
#   'total loan',
#   'unorganized loan',
#   'complete loan',
#   'sure loan',
#   'necessary loan',
#   'interested loan',
#   'new loan',
#   'abreast loan',
#   'previous lender',
#   'current lender',
#   'previous refinance',
#   'informed loan',
#   'conventional loan',
#   'previous mortgage'],
#  ['left company'],
#  ['excellent service',
#   'recommend service',
#   'excellent customer',
#   'satisfied service',
#   'happy service',
#   'friendly service',
#   'good service',
#   'exceptional service',
#   'exceptional customer',
#   'professional service',
#   'reliable service',
#   'best service'],
#  ['whole process',
#   'entire process',
#   'indispensable process',
#   'easy process',
#   'explained process',
#   'ongoing process',
#   'sure process',
#   'whole procedure',
#   'top process',
#   'smooth process',
#   'seamless process',
#   'easiest process'],
#  ['whole progress'],
#  ['knowledgeable job',
#   'knowledgeable spencer',
#   'knowledgeable area',
#   'good job',
#   'knowledgeable process'],
#  ['online home'],
#  ['nervous process'],
#  ['technical skill']]

# %%
final_result = []
for cp in clustures:
    cluster_key_count = {}
    for key_c in cp:
        cluster_key_count[key_c] = freq_count[key_c]
    
    items = []
    for i in list(tuple(cluster_key_count.keys())):
        items.append(i.split()[0])
    dict1 = {}
    for item in items:
        if not item in dict1:
            dict1[item] = items.count(item)
    dict1 = sorted(dict1.keys(), reverse=True)[0]

    curr_cul_keys = list(cluster_key_count.keys())
    curr_cul_values = list(cluster_key_count.values())
    sum_of_similar_words = np.sum(curr_cul_values)
    highest_count_key = curr_cul_keys[np.argmax(curr_cul_values)]
    highest_count_value = np.max(curr_cul_values)
    final_result.append([cluster_key_count,sum_of_similar_words,highest_count_key,len(cluster_key_count), dict1])
    
#     break

# %%
final_result
# Out:
# [[{'great experience': 10,
#    'overall experience': 3,
#    'great job': 9,
#    'wonderful experience': 5,
#    'excellent experience': 2,
#    'current experience': 1,
#    'marvelous job': 1,
#    'best experience': 3,
#    'extraordinary experience': 1,
#    'incredible job': 1,
#    'great service': 4,
#    'several experience': 1,
#    'positive experience': 2,
#    'awesome experience': 1,
#    'wonderful job': 2,
#    'great result': 1,
#    'excellent job': 1,
#    'fantastic experience': 1,
#    'amazing experience': 2,
#    'pleasant experience': 4,
#    'great thing': 1,
#    'entire experience': 1,
#    'helpful experience': 1,
#    'awesome job': 1,
#    'successful experience': 2,
#    'good experience': 4,
#    'fantastic job': 1,
#    'genuine experience': 1},
#   67,
#   'great experience',
#   28,
#   'wonderful'],
#  [{'previous loan': 1,
#    'qualified loan': 1,
#    'senior loan': 2,
#    'best loan': 4,
#    'perfect loan': 1,
#    'total loan': 1,
#    'unorganized loan': 1,
#    'complete loan': 1,
#    'sure loan': 1,
#    'necessary loan': 1,
#    'interested loan': 1,
#    'new loan': 2,
#    'abreast loan': 1,
#    'previous lender': 1,
#    'current lender': 1,
#    'previous refinance': 1,
#    'informed loan': 1,
#    'conventional loan': 1,
#    'previous mortgage': 1},
#   24,
#   'best loan',
#   19,
#   'unorganized'],
#  [{'left company': 1}, 1, 'left company', 1, 'left'],
#  [{'excellent service': 9,
#    'recommend service': 1,
#    'excellent customer': 5,
#    'satisfied service': 3,
#    'happy service': 2,
#    'friendly service': 1,
#    'good service': 1,
#    'exceptional service': 2,
#    'exceptional customer': 1,
#    'professional service': 1,
#    'reliable service': 1,
#    'best service': 1},
#   28,
#   'excellent service',
#   12,
#   'satisfied'],
#  [{'whole process': 19,
#    'entire process': 15,
#    'indispensable process': 1,
#    'easy process': 5,
#    'explained process': 1,
#    'ongoing process': 1,
#    'sure process': 1,
#    'whole procedure': 1,
#    'top process': 1,
#    'smooth process': 2,
#    'seamless process': 1,
#    'easiest process': 1},
#   49,
#   'whole process',
#   12,
#   'whole'],
#  [{'whole progress': 1}, 1, 'whole progress', 1, 'whole'],
#  [{'knowledgeable job': 1,
#    'knowledgeable spencer': 1,
#    'knowledgeable area': 1,
#    'good job': 4,
#    'knowledgeable process': 2},
#   9,
#   'good job',
#   5,
#   'knowledgeable'],
#  [{'online home': 1}, 1, 'online home', 1, 'online'],
#  [{'nervous process': 1}, 1, 'nervous process', 1, 'nervous'],
#  [{'technical skill': 1}, 1, 'technical skill', 1, 'technical'],
#  [{'patient question': 1, 'nice patient': 1, 'patient folk': 1},
#   3,
#   'patient question',
#   3,
#   'patient'],
#  [{'best way': 1}, 1, 'best way', 1, 'best'],
#  [{'hard team': 1,
#    'great team': 4,
#    'sure team': 1,
#    'amazing team': 1,
#    'outstanding teamwork': 1,
#    'excellent team': 1,
#    'stressful team': 1,
#    'good team': 1,
#    'whole team': 1},
#   12,
#   'great team',
#   9,
#   'whole'],
#  [{'stressful side': 1,
#    'stressful knowing': 1,
#    'stressful moment': 1,
#    'stressful period': 1,
#    'smooth stress': 1,
#    'stressful process': 2},
#   7,
#   'stressful process',
#   6,
#   'stressful'],
#  [{'quick process': 1, 'quick professional': 1},
#   2,
#   'quick process',
#   2,
#   'quick'],
#  [{'many year': 3, 'past year': 2, 'many time': 1, 'several time': 1},
#   7,
#   'many year',
#   4,
#   'several'],
#  [{'married home': 1}, 1, 'married home', 1, 'married'],
#  [{'quick mortgage': 1,
#    'future mortgage': 1,
#    'next mortgage': 1,
#    'many mortgage': 1,
#    'current mortgage': 1,
#    'complete mortgage': 1,
#    'amazing mortgage': 1,
#    'professional mortgage': 1,
#    'quickest mortgage': 1,
#    'monthly mortgage': 1,
#    'quickly loan': 1,
#    'consolidated mortgage': 1,
#    'right mortgage': 1,
#    'complicated mortgage': 1,
#    'first mortgage': 1,
#    'interested mortgage': 1},
#   16,
#   'quick mortgage',
#   16,
#   'right'],
#  [{'close contact': 1, 'close attention': 1}, 2, 'close contact', 2, 'close'],
#  [{'great guy': 3, 'great human': 1, 'nice guy': 1, 'much guy': 1},
#   6,
#   'great guy',
#   4,
#   'nice'],
#  [{'crazy money': 1,
#    'expensive amount': 1,
#    'expensive way': 1,
#    'much money': 1},
#   4,
#   'crazy money',
#   4,
#   'much'],
#  [{'top notch': 3, 'top thing': 1}, 4, 'top notch', 2, 'top'],
#  [{'long relationship': 1, 'long story': 1},
#   2,
#   'long relationship',
#   2,
#   'long'],
#  [{'front line': 1}, 1, 'front line', 1, 'front'],
#  [{'best network': 1,
#    'recommend network': 4,
#    'satisfied network': 1,
#    'longer network': 1,
#    'tremendous network': 1,
#    'previous network': 1},
#   9,
#   'recommend network',
#   6,
#   'tremendous'],
#  [{'much norm': 1}, 1, 'much norm', 1, 'much'],
#  [{'appraiser return': 1}, 1, 'appraiser return', 1, 'appraiser'],
#  [{'round trip': 1}, 1, 'round trip', 1, 'round'],
#  [{'original visit': 1}, 1, 'original visit', 1, 'original'],
#  [{'great word': 1, 'true word': 1, 'excellent term': 1},
#   3,
#   'great word',
#   3,
#   'true'],
#  [{'due way': 1}, 1, 'due way', 1, 'due'],
#  [{'available answer': 2,
#    'able answer': 2,
#    'available question': 1,
#    'nebulous answer': 1,
#    'certain question': 1},
#   7,
#   'available answer',
#   5,
#   'nebulous'],
#  [{'upbeat attitude': 1,
#    'good attitude': 1,
#    'great attitude': 1,
#    'positive attitude': 1},
#   4,
#   'upbeat attitude',
#   4,
#   'upbeat'],
#  [{'pleasing voice': 1}, 1, 'pleasing voice', 1, 'pleasing'],
#  [{'best knowledge': 1,
#    'informative understanding': 1,
#    'good information': 1,
#    'sure information': 1,
#    'best understanding': 1},
#   5,
#   'best knowledge',
#   5,
#   'sure'],
#  [{'nice lady': 1,
#    'pleasant manner': 1,
#    'nice people': 2,
#    'wonderful woman': 1},
#   5,
#   'nice people',
#   4,
#   'wonderful'],
#  [{'final process': 1, 'final stage': 1, 'final word': 1},
#   3,
#   'final process',
#   3,
#   'final'],
#  [{'future assistance': 1, 'financial assistance': 1, 'future thank': 2},
#   4,
#   'future thank',
#   3,
#   'future'],
#  [{'shortest time': 1}, 1, 'shortest time', 1, 'shortest'],
#  [{'best outcome': 1, 'happy outcome': 1, 'excellent result': 1},
#   3,
#   'best outcome',
#   3,
#   'happy'],
#  [{'accurate information': 1, 'kind information': 1, 'much information': 1},
#   3,
#   'accurate information',
#   3,
#   'much'],
#  [{'good work': 2,
#    'fantastic work': 3,
#    'good thing': 4,
#    'great work': 6,
#    'diligent work': 1,
#    'best work': 1,
#    'hard work': 5,
#    'great part': 1,
#    'outstanding work': 2,
#    'enjoyable work': 1,
#    'easy work': 3,
#    'excellent work': 2,
#    'pleasant work': 2,
#    'nice work': 1,
#    'wonderful work': 1},
#   35,
#   'great work',
#   15,
#   'wonderful'],
#  [{'new property': 1, 'different property': 1}, 2, 'new property', 2, 'new'],
#  [{'whole package': 1}, 1, 'whole package', 1, 'whole'],
#  [{'much leg': 1}, 1, 'much leg', 1, 'much'],
#  [{'great rate': 6,
#    'good rate': 1,
#    'best rate': 1,
#    'better rate': 1,
#    'awesome percent': 1,
#    'highest rate': 1},
#   11,
#   'great rate',
#   6,
#   'highest'],
#  [{'courteous deliver': 1,
#    'courteous professional': 1,
#    'sincere person': 1,
#    'gracious appreciate': 1,
#    'professional polite': 1,
#    'courteous agent': 1,
#    'helpful polite': 1},
#   7,
#   'courteous deliver',
#   7,
#   'sincere'],
#  [{'full detail': 1}, 1, 'full detail', 1, 'full'],
#  [{'right angel': 1}, 1, 'right angel', 1, 'right'],
#  [{'whole time': 1, 'whole way': 2, 'entire way': 1},
#   4,
#   'whole way',
#   3,
#   'whole'],
#  [{'awesome company': 1,
#    'great customer': 2,
#    'much company': 1,
#    'great company': 5,
#    'different company': 2,
#    'good company': 2,
#    'wonderful company': 1,
#    'pleased company': 1,
#    'fantastic company': 1,
#    'reputable company': 1,
#    'best company': 1},
#   18,
#   'great company',
#   11,
#   'wonderful'],
#  [{'conditional approval': 1}, 1, 'conditional approval', 1, 'conditional'],
#  [{'ryan barrientos': 2}, 2, 'ryan barrientos', 1, 'ryan'],
#  [{'helpful question': 1, 'helpful process': 2, 'available help': 2},
#   5,
#   'helpful process',
#   3,
#   'helpful'],
#  [{'satisfied result': 1,
#    'pleased process': 1,
#    'satisfied thank': 1,
#    'satisfied refi': 1,
#    'happy result': 1},
#   5,
#   'satisfied result',
#   5,
#   'satisfied'],
#  [{'separate people': 1, 'different people': 1},
#   2,
#   'separate people',
#   2,
#   'separate'],
#  [{'numerous obstacle': 1, 'several hurdle': 1, 'insurmountable obstacle': 1},
#   3,
#   'numerous obstacle',
#   3,
#   'several'],
#  [{'many lender': 1, 'different lender': 1, 'friendly lender': 1},
#   3,
#   'many lender',
#   3,
#   'many'],
#  [{'net capital': 1, 'national capital': 1}, 2, 'net capital', 2, 'net'],
#  [{'alexa love': 1}, 1, 'alexa love', 1, 'alexa'],
#  [{'informed process': 1}, 1, 'informed process', 1, 'informed'],
#  [{'helpful hurdle': 1, 'able help': 1, 'difficult task': 1},
#   3,
#   'helpful hurdle',
#   3,
#   'helpful'],
#  [{'anytime question': 2}, 2, 'anytime question', 1, 'anytime'],
#  [{'first time': 6, 'first place': 1, 'first date': 1, 'first situation': 1},
#   9,
#   'first time',
#   4,
#   'first'],
#  [{'dumb question': 1}, 1, 'dumb question', 1, 'dumb'],
#  [{'critical time': 2,
#    'helpful time': 2,
#    'matter time': 1,
#    'possible time': 1},
#   6,
#   'critical time',
#   4,
#   'possible'],
#  [{'thankful way': 1,
#    'glad today': 1,
#    'huge thank': 1,
#    'thankful team': 1,
#    'beautiful thank': 1,
#    'thankful speed': 1,
#    'big thank': 1,
#    'thankful feel': 1,
#    'happy way': 1},
#   9,
#   'thankful way',
#   9,
#   'thankful'],
#  [{'easy thank': 2,
#    'awesome thanks': 1,
#    'easy need': 1,
#    'right thank': 1,
#    'great thanks': 1,
#    'many thanks': 2,
#    'free thank': 1,
#    'matter thanks': 1,
#    'fast thank': 1,
#    'simple thanks': 1,
#    'special thanks': 1,
#    'amazing thank': 1},
#   14,
#   'easy thank',
#   12,
#   'special'],
#  [{'timely fashion': 1, 'timely manner': 2}, 3, 'timely manner', 2, 'timely'],
#  [{'facilitated processing': 1,
#    'expeditious processing': 1,
#    'nayeli processing': 1},
#   3,
#   'facilitated processing',
#   3,
#   'nayeli'],
#  [{'smooth look': 1}, 1, 'smooth look', 1, 'smooth'],
#  [{'melissa title': 1}, 1, 'melissa title', 1, 'melissa'],
#  [{'disappointed lack': 1, 'major disappointment': 1},
#   2,
#   'disappointed lack',
#   2,
#   'major'],
#  [{'financial crunch': 1, 'financial situation': 1},
#   2,
#   'financial crunch',
#   2,
#   'financial'],
#  [{'industrious execution': 1, 'effortlessly execution': 1},
#   2,
#   'industrious execution',
#   2,
#   'industrious'],
#  [{'bureaucratic process': 1, 'bureaucratic nightmare': 1},
#   2,
#   'bureaucratic process',
#   2,
#   'bureaucratic'],
#  [{'extreme patience': 1, 'available patience': 1, 'ethic patience': 1},
#   3,
#   'extreme patience',
#   3,
#   'extreme'],
#  [{'several occasion': 1, 'separate occasion': 1},
#   2,
#   'several occasion',
#   2,
#   'several'],
#  [{'adrian fernandez': 1}, 1, 'adrian fernandez', 1, 'adrian'],
#  [{'current refinance': 1,
#    'best refinance': 1,
#    'entire refinance': 1,
#    'close refinancing': 1,
#    'advantageous refinance': 1,
#    'twice refinance': 1,
#    'honest refinance': 1,
#    'helpful refinancing': 1,
#    'second refinance': 1},
#   9,
#   'current refinance',
#   9,
#   'twice'],
#  [{'ethic appreciate': 1}, 1, 'ethic appreciate', 1, 'ethic'],
#  [{'high quality': 1}, 1, 'high quality', 1, 'high'],
#  [{'necessary paper': 1,
#    'necessary document': 1,
#    'possible paperwork': 1,
#    'top paper': 1,
#    'correct paper': 1},
#   5,
#   'necessary paper',
#   5,
#   'top'],
#  [{'able match': 1}, 1, 'able match', 1, 'able'],
#  [{'bad company': 1}, 1, 'bad company', 1, 'bad'],
#  [{'easiest refi': 2,
#    'refi simple': 1,
#    'fastest refi': 1,
#    'able refin': 1,
#    'first refi': 1,
#    'initial refi': 1,
#    'several refi': 1,
#    'best refi': 1},
#   9,
#   'easiest refi',
#   8,
#   'several'],
#  [{'financial paper': 1,
#    'financial institution': 1,
#    'financial transaction': 1,
#    'financial document': 1},
#   4,
#   'financial paper',
#   4,
#   'financial'],
#  [{'great interest': 1,
#    'high interest': 1,
#    'excellent attention': 1,
#    'best interest': 2},
#   5,
#   'best interest',
#   4,
#   'high'],
#  [{'netcap team': 1}, 1, 'netcap team', 1, 'netcap'],
#  [{'finish line': 1}, 1, 'finish line', 1, 'finish'],
#  [{'quick response': 1, 'quick claim': 1, 'quick respond': 1},
#   3,
#   'quick response',
#   3,
#   'quick'],
#  [{'many detour': 1}, 1, 'many detour', 1, 'many'],
#  [{'satisfied communication': 1,
#    'pleased interaction': 1,
#    'good communication': 3,
#    'great communication': 1,
#    'streamlined communication': 1,
#    'constant communication': 1},
#   8,
#   'good communication',
#   6,
#   'streamlined'],
#  [{'minimal work': 1}, 1, 'minimal work', 1, 'minimal'],
#  [{'high praise': 1, 'pleased w': 1}, 2, 'high praise', 2, 'pleased'],
#  [{'much jenifer': 1,
#    'much zach': 1,
#    'many deal': 1,
#    'large part': 1,
#    'much anouk': 1},
#   5,
#   'much jenifer',
#   5,
#   'much'],
#  [{'closed week': 2, 'close week': 1, 'closed day': 1},
#   4,
#   'closed week',
#   3,
#   'closed'],
#  [{'bad mailing': 1}, 1, 'bad mailing', 1, 'bad'],
#  [{'different department': 1}, 1, 'different department', 1, 'different'],
#  [{'several message': 1}, 1, 'several message', 1, 'several'],
#  [{'notary call': 1, 'notary come': 1, 'local notary': 1},
#   3,
#   'notary call',
#   3,
#   'notary'],
#  [{'personal service': 1}, 1, 'personal service', 1, 'personal'],
#  [{'professional network': 1, 'firm network': 1},
#   2,
#   'professional network',
#   2,
#   'professional'],
#  [{'human asset': 1}, 1, 'human asset', 1, 'human'],
#  [{'rough lady': 1}, 1, 'rough lady', 1, 'rough'],
#  [{'administrative staff': 1, 'professional staff': 1},
#   2,
#   'administrative staff',
#   2,
#   'professional'],
#  [{'close begin': 1, 'ready close': 1}, 2, 'close begin', 2, 'ready'],
#  [{'grateful loan': 1, 'good loan': 1, 'excellent loan': 1, 'easy loan': 1},
#   4,
#   'grateful loan',
#   4,
#   'grateful'],
#  [{'amazing help': 1, 'efficient help': 1, 'exceptional help': 1},
#   3,
#   'amazing help',
#   3,
#   'exceptional'],
#  [{'flexible waste': 1}, 1, 'flexible waste', 1, 'flexible'],
#  [{'professional job': 1,
#    'best job': 2,
#    'professional enjoy': 1,
#    'professional trouble': 1,
#    'professional demeaner': 1,
#    'professional style': 1,
#    'professional tyler': 1,
#    'well professionalism': 1,
#    'professional issue': 1,
#    'professional process': 1,
#    'professional work': 1,
#    'professional manner': 1,
#    'absolute professionalism': 1,
#    'professional kind': 1,
#    'professional refi': 1},
#   16,
#   'best job',
#   15,
#   'well'],
#  [{'good listener': 1}, 1, 'good listener', 1, 'good'],
#  [{'closed loan': 1, 'close mortgage': 1, 'close loan': 1},
#   3,
#   'closed loan',
#   3,
#   'closed'],
#  [{'large debt': 1, 'normal debt': 1, 'due debt': 1},
#   3,
#   'large debt',
#   3,
#   'normal'],
#  [{'zachary team': 1}, 1, 'zachary team', 1, 'zachary'],
#  [{'great year': 1, 'last year': 1}, 2, 'great year', 2, 'last'],
#  [{'ramos talk': 1,
#    'easy talk': 1,
#    'personal conversation': 1,
#    'initial conversation': 2},
#   5,
#   'initial conversation',
#   4,
#   'ramos'],
#  [{'willing help': 1, 'helpful guy': 1}, 2, 'willing help', 2, 'willing'],
#  [{'great birthday': 1}, 1, 'great birthday', 1, 'great'],
#  [{'easy company': 1, 'explicit company': 1},
#   2,
#   'easy company',
#   2,
#   'explicit'],
#  [{'human help': 1}, 1, 'human help', 1, 'human'],
#  [{'personal attention': 1, 'thorough attention': 1, 'personal note': 1},
#   3,
#   'personal attention',
#   3,
#   'thorough'],
#  [{'individual case': 1, 'informed case': 1},
#   2,
#   'individual case',
#   2,
#   'informed'],
#  [{'best thanksnoushin': 1}, 1, 'best thanksnoushin', 1, 'best'],
#  [{'long order': 1}, 1, 'long order', 1, 'long'],
#  [{'helpful completing': 1, 'helpful making': 1, 'complete task': 1},
#   3,
#   'helpful completing',
#   3,
#   'helpful'],
#  [{'able use': 1}, 1, 'able use', 1, 'able'],
#  [{'big raise': 1, 'higher ups': 1}, 2, 'big raise', 2, 'higher'],
#  [{'helpful company': 1, 'recommend company': 2},
#   3,
#   'recommend company',
#   2,
#   'recommend'],
#  [{'limited insight': 1, 'little unsure': 1},
#   2,
#   'limited insight',
#   2,
#   'little'],
#  [{'exceptional employee': 1,
#    'great employee': 1,
#    'exemplary employee': 1,
#    'understandable employee': 1},
#   4,
#   'exceptional employee',
#   4,
#   'understandable'],
#  [{'comfortable staff': 1}, 1, 'comfortable staff', 1, 'comfortable'],
#  [{'first phone': 1, 'personal phone': 1, 'first contact': 1},
#   3,
#   'first phone',
#   3,
#   'personal'],
#  [{'several day': 1, 'several month': 1}, 2, 'several day', 2, 'several'],
#  [{'favorable need': 1, 'due requirement': 1},
#   2,
#   'favorable need',
#   2,
#   'favorable'],
#  [{'best product': 1}, 1, 'best product', 1, 'best'],
#  [{'major freak': 1}, 1, 'major freak', 1, 'major'],
#  [{'humorous presence': 1}, 1, 'humorous presence', 1, 'humorous'],
#  [{'prime shipping': 1}, 1, 'prime shipping', 1, 'prime'],
#  [{'samuel louellens': 1}, 1, 'samuel louellens', 1, 'samuel'],
#  [{'invaluable wife': 1, 'sure wife': 1, 'glad wife': 1},
#   3,
#   'invaluable wife',
#   3,
#   'sure'],
#  [{'immediate grasp': 1}, 1, 'immediate grasp', 1, 'immediate'],
#  [{'extensive request': 1, 'urgent need': 1},
#   2,
#   'extensive request',
#   2,
#   'urgent'],
#  [{'multiple option': 1, 'several option': 1},
#   2,
#   'multiple option',
#   2,
#   'several'],
#  [{'many friend': 1, 'amazing friend': 1, 'great friend': 1},
#   3,
#   'many friend',
#   3,
#   'many'],
#  [{'relative contact': 1}, 1, 'relative contact', 1, 'relative'],
#  [{'first choice': 1}, 1, 'first choice', 1, 'first'],
#  [{'extended family': 1, 'new family': 1, 'single family': 1},
#   3,
#   'extended family',
#   3,
#   'single'],
#  [{'real life': 1}, 1, 'real life', 1, 'real'],
#  [{'committed schedule': 1}, 1, 'committed schedule', 1, 'committed'],
#  [{'effective planning': 1}, 1, 'effective planning', 1, 'effective'],
#  [{'unbelievable achievement': 1},
#   1,
#   'unbelievable achievement',
#   1,
#   'unbelievable'],
#  [{'successful financing': 1}, 1, 'successful financing', 1, 'successful'],
#  [{'confident friend': 1}, 1, 'confident friend', 1, 'confident'],
#  [{'perfect pair': 1}, 1, 'perfect pair', 1, 'perfect'],
#  [{'overall rating': 1}, 1, 'overall rating', 1, 'overall'],
#  [{'professional prompt': 1}, 1, 'professional prompt', 1, 'professional'],
#  [{'empathic situation': 1}, 1, 'empathic situation', 1, 'empathic'],
#  [{'difficult process': 1}, 1, 'difficult process', 1, 'difficult'],
#  [{'best addition': 1}, 1, 'best addition', 1, 'best'],
#  [{'testy moment': 1}, 1, 'testy moment', 1, 'testy'],
#  [{'personal touch': 2}, 2, 'personal touch', 1, 'personal'],
#  [{'future thing': 1, 'financial future': 1, 'next thing': 1},
#   3,
#   'future thing',
#   3,
#   'next'],
#  [{'personal nature': 1}, 1, 'personal nature', 1, 'personal'],
#  [{'necessary feedback': 1, 'responsive question': 1},
#   2,
#   'necessary feedback',
#   2,
#   'responsive'],
#  [{'good credit': 2, 'perfect credit': 1}, 3, 'good credit', 2, 'perfect'],
#  [{'good bonus': 1}, 1, 'good bonus', 1, 'good'],
#  [{'attractive user': 1}, 1, 'attractive user', 1, 'attractive'],
#  [{'friendly site': 1}, 1, 'friendly site', 1, 'friendly'],
#  [{'regular customer': 1}, 1, 'regular customer', 1, 'regular'],
#  [{'amazing app': 1}, 1, 'amazing app', 1, 'amazing'],
#  [{'transparent thoughtful': 1},
#   1,
#   'transparent thoughtful',
#   1,
#   'transparent'],
#  [{'initial call': 1}, 1, 'initial call', 1, 'initial'],
#  [{'extra effort': 1}, 1, 'extra effort', 1, 'extra'],
#  [{'sarah franc': 1}, 1, 'sarah franc', 1, 'sarah'],
#  [{'good rush': 1}, 1, 'good rush', 1, 'good'],
#  [{'scan document': 1}, 1, 'scan document', 1, 'scan'],
#  [{'usual thinking': 1, 'effective thought': 1},
#   2,
#   'usual thinking',
#   2,
#   'usual'],
#  [{'outside job': 1}, 1, 'outside job', 1, 'outside'],
#  [{'dedicated people': 1, 'great people': 4}, 5, 'great people', 2, 'great'],
#  [{'truthful talking': 1}, 1, 'truthful talking', 1, 'truthful'],
#  [{'sabeastian aviles': 1}, 1, 'sabeastian aviles', 1, 'sabeastian'],
#  [{'primary residence': 1}, 1, 'primary residence', 1, 'primary'],
#  [{'bandaid loan': 1}, 1, 'bandaid loan', 1, 'bandaid'],
#  [{'many suggestion': 1}, 1, 'many suggestion', 1, 'many'],
#  [{'fast service': 3}, 3, 'fast service', 1, 'fast'],
#  [{'second business': 1}, 1, 'second business', 1, 'second'],
#  [{'motivated way': 1}, 1, 'motivated way', 1, 'motivated'],
#  [{'past week': 1, 'last week': 2}, 3, 'last week', 2, 'past'],
#  [{'great recommendation': 1, 'recommend people': 1},
#   2,
#   'great recommendation',
#   2,
#   'recommend'],
#  [{'high school': 1}, 1, 'high school', 1, 'high'],
#  [{'best lot': 1}, 1, 'best lot', 1, 'best'],
#  [{'genuine person': 1}, 1, 'genuine person', 1, 'genuine'],
#  [{'great attribute': 1, 'great asset': 1}, 2, 'great attribute', 2, 'great'],
#  [{'many step': 1, 'next step': 1}, 2, 'many step', 2, 'next'],
#  [{'amazed pace': 1, 'fast action': 1, 'fast time': 1},
#   3,
#   'amazed pace',
#   3,
#   'fast'],
#  [{'amazing people': 2}, 2, 'amazing people', 1, 'amazing'],
#  [{'difficult circumstance': 1}, 1, 'difficult circumstance', 1, 'difficult'],
#  [{'difficult set': 1}, 1, 'difficult set', 1, 'difficult'],
#  [{'creative follow': 1}, 1, 'creative follow', 1, 'creative'],
#  [{'divorced woman': 1}, 1, 'divorced woman', 1, 'divorced'],
#  [{'bad joke': 1}, 1, 'bad joke', 1, 'bad'],
#  [{'rocky journey': 1}, 1, 'rocky journey', 1, 'rocky'],
#  [{'honesty drive': 1}, 1, 'honesty drive', 1, 'honesty'],
#  [{'reliable transaction': 1,
#    'smoothest transaction': 1,
#    'great transaction': 1,
#    'complete transaction': 1},
#   4,
#   'reliable transaction',
#   4,
#   'smoothest'],
#  [{'best place': 1}, 1, 'best place', 1, 'best'],
#  [{'new sale': 1, 'new purchase': 2}, 3, 'new purchase', 2, 'new'],
#  [{'quick turn': 1}, 1, 'quick turn', 1, 'quick'],
#  [{'responsive help': 1}, 1, 'responsive help', 1, 'responsive'],
#  [{'priceless paul': 1}, 1, 'priceless paul', 1, 'priceless'],
#  [{'awful deal': 1, 'terrible chose': 1}, 2, 'awful deal', 2, 'terrible'],
#  [{'deserved review': 1}, 1, 'deserved review', 1, 'deserved'],
#  [{'honest company': 2, 'real company': 1}, 3, 'honest company', 2, 'real'],
#  [{'fantastic advice': 1, 'great advice': 1},
#   2,
#   'fantastic advice',
#   2,
#   'great'],
#  [{'corporate ethic': 1}, 1, 'corporate ethic', 1, 'corporate'],
#  [{'happy coustmer': 1}, 1, 'happy coustmer', 1, 'happy'],
#  [{'best customer': 1}, 1, 'best customer', 1, 'best'],
#  [{'trustworthy employee': 1, 'trustworthy work': 1},
#   2,
#   'trustworthy employee',
#   2,
#   'trustworthy'],
#  [{'top account': 1}, 1, 'top account', 1, 'top'],
#  [{'substantial saving': 1}, 1, 'substantial saving', 1, 'substantial'],
#  [{'third party': 1}, 1, 'third party', 1, 'third'],
#  [{'unbiased lending': 1}, 1, 'unbiased lending', 1, 'unbiased'],
#  [{'wonderful staff': 1}, 1, 'wonderful staff', 1, 'wonderful'],
#  [{'multiple call': 1}, 1, 'multiple call', 1, 'multiple'],
#  [{'old survey': 1}, 1, 'old survey', 1, 'old'],
#  [{'least pocket': 1}, 1, 'least pocket', 1, 'least'],
#  [{'reduced income': 1}, 1, 'reduced income', 1, 'reduced'],
#  [{'initial quote': 1}, 1, 'initial quote', 1, 'initial'],
#  [{'free process': 1}, 1, 'free process', 1, 'free'],
#  [{'lower others': 1}, 1, 'lower others', 1, 'lower'],
#  [{'least people': 1}, 1, 'least people', 1, 'least'],
#  [{'great alot': 1, 'awesome part': 1}, 2, 'great alot', 2, 'great'],
#  [{'lower rate': 2}, 2, 'lower rate', 1, 'lower'],
#  [{'certain thing': 1}, 1, 'certain thing', 1, 'certain'],
#  [{'correct path': 1, 'right path': 1}, 2, 'correct path', 2, 'right'],
#  [{'main goal': 2}, 2, 'main goal', 1, 'main'],
#  [{'hesitate refer': 1}, 1, 'hesitate refer', 1, 'hesitate'],
#  [{'exceptional salesman': 1}, 1, 'exceptional salesman', 1, 'exceptional'],
#  [{'lucky team': 1}, 1, 'lucky team', 1, 'lucky'],
#  [{'awesome deal': 1, 'excellent deal': 1}, 2, 'awesome deal', 2, 'excellent'],
#  [{'informed requirement': 1}, 1, 'informed requirement', 1, 'informed'],
#  [{'answered question': 1}, 1, 'answered question', 1, 'answered'],
#  [{'financial scenario': 1, 'financial shape': 1, 'financial need': 1},
#   3,
#   'financial scenario',
#   3,
#   'financial'],
#  [{'current information': 1}, 1, 'current information', 1, 'current'],
#  [{'accessible attentive': 1}, 1, 'accessible attentive', 1, 'accessible'],
#  [{'outstanding tyler': 1}, 1, 'outstanding tyler', 1, 'outstanding'],
#  [{'closed time': 1}, 1, 'closed time', 1, 'closed'],
#  [{'reassured process': 2, 'reassuring time': 1},
#   3,
#   'reassured process',
#   2,
#   'reassuring'],
#  [{'smooth sailing': 1}, 1, 'smooth sailing', 1, 'smooth'],
#  [{'proper expectation': 1}, 1, 'proper expectation', 1, 'proper'],
#  [{'edgar guide': 1}, 1, 'edgar guide', 1, 'edgar'],
#  [{'afraid process': 1}, 1, 'afraid process', 1, 'afraid'],
#  [{'stellar credit': 1}, 1, 'stellar credit', 1, 'stellar'],
#  [{'monthly bill': 1, 'monthly payment': 3},
#   4,
#   'monthly payment',
#   2,
#   'monthly'],
#  [{'respectful professionalism': 1,
#    'enough professionalism': 1,
#    'close professionalism': 1},
#   3,
#   'respectful professionalism',
#   3,
#   'respectful'],
#  [{'much people': 1, 'many people': 1}, 2, 'much people', 2, 'much'],
#  [{'happen network': 2}, 2, 'happen network', 1, 'happen'],
#  [{'small hoop': 1}, 1, 'small hoop', 1, 'small'],
#  [{'first language': 1}, 1, 'first language', 1, 'first'],
#  [{'new goto': 1}, 1, 'new goto', 1, 'new'],
#  [{'ready purchase': 1}, 1, 'ready purchase', 1, 'ready'],
#  [{'senior mortgage': 1}, 1, 'senior mortgage', 1, 'senior'],
#  [{'many question': 2}, 2, 'many question', 1, 'many'],
#  [{'matter hour': 1}, 1, 'matter hour', 1, 'matter'],
#  [{'least day': 1}, 1, 'least day', 1, 'least'],
#  [{'second time': 2}, 2, 'second time', 1, 'second'],
#  [{'highest review': 1}, 1, 'highest review', 1, 'highest'],
#  [{'total understanding': 1}, 1, 'total understanding', 1, 'total'],
#  [{'important person': 1, 'good person': 1},
#   2,
#   'important person',
#   2,
#   'important'],
#  [{'little question': 1}, 1, 'little question', 1, 'little'],
#  [{'helpful agent': 1, 'fortunate agent': 1},
#   2,
#   'helpful agent',
#   2,
#   'helpful'],
#  [{'pleased report': 1}, 1, 'pleased report', 1, 'pleased'],
#  [{'competitive offer': 1, 'competitive interest': 1},
#   2,
#   'competitive offer',
#   2,
#   'competitive'],
#  [{'key point': 1}, 1, 'key point', 1, 'key'],
#  [{'competitive rate': 1}, 1, 'competitive rate', 1, 'competitive'],
#  [{'closer textbook': 1}, 1, 'closer textbook', 1, 'closer'],
#  [{'close home': 1}, 1, 'close home', 1, 'close'],
#  [{'higher promotion': 1}, 1, 'higher promotion', 1, 'higher'],
#  [{'right discount': 1, 'aware discount': 1}, 2, 'right discount', 2, 'right'],
#  [{'necessary correction': 1}, 1, 'necessary correction', 1, 'necessary'],
#  [{'new proposal': 2}, 2, 'new proposal', 1, 'new'],
#  [{'innumerable hour': 1}, 1, 'innumerable hour', 1, 'innumerable'],
#  [{'sorry tax': 1}, 1, 'sorry tax', 1, 'sorry'],
#  [{'real estate': 1}, 1, 'real estate', 1, 'real'],
#  [{'frustrating refi': 1}, 1, 'frustrating refi', 1, 'frustrating'],
#  [{'reasonable expense': 1}, 1, 'reasonable expense', 1, 'reasonable'],
#  [{'prior appraisal': 1}, 1, 'prior appraisal', 1, 'prior'],
#  [{'excessive insult': 1}, 1, 'excessive insult', 1, 'excessive'],
#  [{'good condition': 1}, 1, 'good condition', 1, 'good'],
#  [{'excessive opinion': 1}, 1, 'excessive opinion', 1, 'excessive'],
#  [{'new home': 1, 'third home': 1, 'previous home': 1},
#   3,
#   'new home',
#   3,
#   'third'],
#  [{'double cash': 1}, 1, 'double cash', 1, 'double'],
#  [{'comfortable retirement': 1},
#   1,
#   'comfortable retirement',
#   1,
#   'comfortable'],
#  [{'net closing': 1}, 1, 'net closing', 1, 'net'],
#  [{'third company': 1}, 1, 'third company', 1, 'third'],
#  [{'direct lending': 1}, 1, 'direct lending', 1, 'direct'],
#  [{'friendly customer': 1}, 1, 'friendly customer', 1, 'friendly'],
#  [{'easy pleasure': 1, 'extreme pleasure': 1},
#   2,
#   'easy pleasure',
#   2,
#   'extreme'],
#  [{'safe company': 1}, 1, 'safe company', 1, 'safe'],
#  [{'servicing lead': 1}, 1, 'servicing lead', 1, 'servicing'],
#  [{'right decision': 1}, 1, 'right decision', 1, 'right'],
#  [{'associate ericka': 1}, 1, 'associate ericka', 1, 'associate'],
#  [{'amazing joy': 1}, 1, 'amazing joy', 1, 'amazing'],
#  [{'relative thank': 1}, 1, 'relative thank', 1, 'relative'],
#  [{'rough time': 1}, 1, 'rough time', 1, 'rough'],
#  [{'sole income': 1}, 1, 'sole income', 1, 'sole'],
#  [{'regular basis': 1}, 1, 'regular basis', 1, 'regular'],
#  [{'satisfied star': 1}, 1, 'satisfied star', 1, 'satisfied'],
#  [{'personable thinking': 1}, 1, 'personable thinking', 1, 'personable'],
#  [{'rite lady': 1}, 1, 'rite lady', 1, 'rite'],
#  [{'normal work': 1}, 1, 'normal work', 1, 'normal'],
#  [{'many instance': 1}, 1, 'many instance', 1, 'many'],
#  [{'single email': 1, 'entire email': 1, 'separate email': 1},
#   3,
#   'single email',
#   3,
#   'single'],
#  [{'common practice': 1, 'standard practice': 1},
#   2,
#   'common practice',
#   2,
#   'standard'],
#  [{'new thread': 1}, 1, 'new thread', 1, 'new'],
#  [{'original agreement': 1}, 1, 'original agreement', 1, 'original'],
#  [{'several house': 1, 'bigger house': 1}, 2, 'several house', 2, 'several'],
#  [{'free concern': 1}, 1, 'free concern', 1, 'free'],
#  [{'easy experience': 1}, 1, 'easy experience', 1, 'easy'],
#  [{'weekly update': 1}, 1, 'weekly update', 1, 'weekly'],
#  [{'past working': 1}, 1, 'past working', 1, 'past'],
#  [{'fantastic member': 1}, 1, 'fantastic member', 1, 'fantastic'],
#  [{'informative encouraging': 1},
#   1,
#   'informative encouraging',
#   1,
#   'informative'],
#  [{'tight spot': 1}, 1, 'tight spot', 1, 'tight'],
#  [{'little hand': 1}, 1, 'little hand', 1, 'little'],
#  [{'top mother': 1}, 1, 'top mother', 1, 'top'],
#  [{'knowledgeable line': 1}, 1, 'knowledgeable line', 1, 'knowledgeable'],
#  [{'little life': 1}, 1, 'little life', 1, 'little'],
#  [{'open heart': 1}, 1, 'open heart', 1, 'open'],
#  [{'old hospital': 1}, 1, 'old hospital', 1, 'old'],
#  [{'great hope': 1}, 1, 'great hope', 1, 'great'],
#  [{'compassionate life': 1}, 1, 'compassionate life', 1, 'compassionate'],
#  [{'serious surgery': 1}, 1, 'serious surgery', 1, 'serious'],
#  [{'concerned son': 1}, 1, 'concerned son', 1, 'concerned'],
#  [{'better term': 1}, 1, 'better term', 1, 'better'],
#  [{'higher star': 1}, 1, 'higher star', 1, 'higher'],
#  [{'first house': 1}, 1, 'first house', 1, 'first'],
#  [{'repetitive sincerity': 1}, 1, 'repetitive sincerity', 1, 'repetitive'],
#  [{'better broker': 1}, 1, 'better broker', 1, 'better'],
#  [{'painless process': 1}, 1, 'painless process', 1, 'painless'],
#  [{'due change': 1}, 1, 'due change', 1, 'due'],
#  [{'actual payment': 1}, 1, 'actual payment', 1, 'actual'],
#  [{'huge difference': 1}, 1, 'huge difference', 1, 'huge'],
#  [{'criminal practice': 1}, 1, 'criminal practice', 1, 'criminal'],
#  [{'respectful time': 1}, 1, 'respectful time', 1, 'respectful'],
#  [{'best remortgage': 1}, 1, 'best remortgage', 1, 'best'],
#  [{'smoother loan': 1}, 1, 'smoother loan', 1, 'smoother'],
#  [{'random call': 1}, 1, 'random call', 1, 'random'],
#  [{'back question': 1}, 1, 'back question', 1, 'back'],
#  [{'phenomenal timing': 1}, 1, 'phenomenal timing', 1, 'phenomenal'],
#  [{'timely pain': 1}, 1, 'timely pain', 1, 'timely'],
#  [{'developed rely': 1}, 1, 'developed rely', 1, 'developed'],
#  [{'representative company': 3},
#   3,
#   'representative company',
#   1,
#   'representative'],
#  [{'leery scam': 1}, 1, 'leery scam', 1, 'leery'],
#  [{'serious consequence': 1}, 1, 'serious consequence', 1, 'serious'],
#  [{'able research': 1}, 1, 'able research', 1, 'able'],
#  [{'several ups': 1}, 1, 'several ups', 1, 'several'],
#  [{'new load': 1}, 1, 'new load', 1, 'new'],
#  [{'closer underwriting': 1}, 1, 'closer underwriting', 1, 'closer'],
#  [{'wrong check': 1}, 1, 'wrong check', 1, 'wrong'],
#  [{'multiple fi': 1}, 1, 'multiple fi', 1, 'multiple'],
#  [{'last minute': 1}, 1, 'last minute', 1, 'last'],
#  [{'high tech': 1}, 1, 'high tech', 1, 'high'],
#  [{'bottom heart': 1}, 1, 'bottom heart', 1, 'bottom'],
#  [{'beat competitor': 1}, 1, 'beat competitor', 1, 'beat'],
#  [{'smooth silk': 1}, 1, 'smooth silk', 1, 'smooth'],
#  [{'speak finance': 1}, 1, 'speak finance', 1, 'speak'],
#  [{'single time': 1}, 1, 'single time', 1, 'single'],
#  [{'best example': 1}, 1, 'best example', 1, 'best'],
#  [{'able lock': 1}, 1, 'able lock', 1, 'able'],
#  [{'online tool': 1}, 1, 'online tool', 1, 'online'],
#  [{'lowest cost': 1}, 1, 'lowest cost', 1, 'lowest'],
#  [{'knowledgeable loan': 1}, 1, 'knowledgeable loan', 1, 'knowledgeable'],
#  [{'great interaction': 1}, 1, 'great interaction', 1, 'great'],
#  [{'smooth transition': 1}, 1, 'smooth transition', 1, 'smooth'],
#  [{'unsolicited robo': 1}, 1, 'unsolicited robo', 1, 'unsolicited'],
#  [{'first instinct': 1}, 1, 'first instinct', 1, 'first'],
#  [{'able reach': 1}, 1, 'able reach', 1, 'able'],
#  [{'well expedience': 1}, 1, 'well expedience', 1, 'well'],
#  [{'main reason': 1}, 1, 'main reason', 1, 'main'],
#  [{'excellent procurement': 1}, 1, 'excellent procurement', 1, 'excellent'],
#  [{'full time': 1}, 1, 'full time', 1, 'full'],
#  [{'traditional bank': 1}, 1, 'traditional bank', 1, 'traditional'],
#  [{'byzantine process': 1}, 1, 'byzantine process', 1, 'byzantine']]

# %%
df = pd.DataFrame(final_result,columns=["similar_words_and_count","count_of_similar_words","most_used_similar_word","total_similar_words", "associated_words"])

# %%
sorted_df = df.sort_values('total_similar_words',ascending=False).reset_index(drop=True)

# %%
sorted_df
# Out:
#                                similar_words_and_count  \
# 0    {'great experience': 10, 'overall experience':...
# 1    {'previous loan': 1, 'qualified loan': 1, 'sen...
# 2    {'quick mortgage': 1, 'future mortgage': 1, 'n...
# 3    {'professional job': 1, 'best job': 2, 'profes...
# 4    {'good work': 2, 'fantastic work': 3, 'good th...
# ..                                                 ...
# 379                                    {'best lot': 1}
# 380                              {'amazing people': 2}
# 381                      {'difficult circumstance': 1}
# 382                               {'difficult set': 1}
# 383                           {'byzantine process': 1}
#
#      count_of_similar_words  most_used_similar_word  total_similar_words  \
# 0                        67        great experience                   28
# 1                        24               best loan                   19
# 2                        16          quick mortgage                   16
# 3                        16                best job                   15
# 4                        35              great work                   15
# ..                      ...                     ...                  ...
# 379                       1                best lot                    1
# 380                       2          amazing people                    1
# 381                       1  difficult circumstance                    1
# 382                       1           difficult set                    1
# 383                       1       byzantine process                    1
#
#     associated_words
# 0          wonderful
# 1        unorganized
# 2              right
# 3               well
# 4          wonderful
# ..               ...
# 379             best
# 380          amazing
# 381        difficult
# 382        difficult
# 383        byzantine
#
# [384 rows x 5 columns]

# %%
sorted_df.to_csv("/home/heptagon/Desktop/nps_review_analysis/dataset/network_capital_funding_detail_review_words.csv", index=False)

# %%
print((sorted_df.most_used_similar_word).to_list()[:20])
# Out:
# ['great experience', 'best loan', 'quick mortgage', 'best job', 'great work', 'excellent service', 'whole process', 'easy thank', 'great company', 'great team', 'thankful way', 'current refinance', 'easiest refi', 'courteous deliver', 'stressful process', 'great rate', 'recommend network', 'good communication', 'best knowledge', 'good job']

# %%
print((sorted_df.associated_words).to_list()[:20])
# Out:
# ['wonderful', 'unorganized', 'right', 'well', 'wonderful', 'satisfied', 'whole', 'special', 'wonderful', 'whole', 'thankful', 'twice', 'several', 'sincere', 'stressful', 'highest', 'tremendous', 'streamlined', 'sure', 'knowledgeable']

# %%
# Problem Statement : Now can you find out the keywords or expressions related to these keywords
#   Ex: Battery: Good, bad, slow charging etc, for wach keyword

# we are getting list of keywords so
# 1. currently taking 1st most word from the keywords
# 2. Thinking : To apply a specific Algo on entire datasets
# 3. Also thinking the pattern matching but, it will return entire sentence not a specific words.


#  https://www.analyticsvidhya.com/blog/2020/06/nlp-project-information-extraction/#h2_11

# %% [markdown]
# ###  Associated words using patterns

# %%
import spacy

# %%
def rule3(text): 
    nlp = spacy.load('en_core_web_sm')
    doc = nlp(text)    
    sent = []
    for token in doc: 
#         print("Token : ",token)

        if token.pos_=='ADP':    # look for prepositions
            phrase = ''      
            
            if token.head.pos_=='NOUN':   # if its head word is a noun
                phrase += token.head.text    # append noun and preposition to phrase
                phrase += ' '+token.text

                for right_tok in token.rights:    # check the nodes to the right of the preposition
                    if (right_tok.pos_ in ['NOUN','PROPN']):    # append if it is a noun or proper noun
                        phrase += ' '+right_tok.text
                if len(phrase)>5:
                    sent.append(phrase)
                
    return sent

# %%
for text in df.comments:
    print(rule3(text))
# Out:
# []
# ['asset to operation']
# ['experience with Capital']
# ['refinance with Fundinding', 'step of way', 'questions about documents', 'employees of Funding']
# ['progress of refinance', 'side of things']
# ['transactions over years', 'contact with']
# []
# ['cost of Appraisal', 'amount of visit']
# []
# ['transactions over years']
# ['knowledge on']
# ['pleasure of', 'processing of loan']
# ['process for', 'refinance for property']
# ['efforts in', 'purchase of property', 'property in Beach', 'package of loans']
# []
# []
# ['dealings with']
# []
# ['approval for repairs', 'part of reason', 'capital of']
# ['results of refinance']
# ['spite of obstacles', 'bulls with bone', 'things about']
# []
# ['Experience with Lily', 'fault of']
# ['others behind scene', 'Thanks for Help']
# ['difference in lives']
# []
# []
# ['time in life']
# ['process of Capital', 'asset to company']
# ['processing of loan']
# ['lack of communication', 'calls from Melissa']
# ['processing with financer', 'execution of process']
# []
# ['need of services']
# []
# []
# ['things about']
# ['things about']
# []
# []
# []
# []
# ['pleasure of']
# ['response to questions']
# ['rate with market', 'detail of process', 'raise for work']
# ['problems with credit']
# ['weeks about']
# []
# ['refinance of home', 'refinance with', 'service along process']
# []
# []
# ['combination for', 'finish in', 'Refinancing of home', 'epitome of professionals']
# ['head of time']
# ['minutes of closing']
# []
# ['people for', 'loans in future']
# ['top of process', 'lot of work', 'seemless as']
# []
# []
# ['thanks in part', 'thanks to Louellen', 'team for mortgage', 'team at capital']
# ['bumps as team']
# ['pain of paperwork']
# ['couple of months', 'solution for']
# ['call of duty', 'call with loan', 'effort for', 'pat on back']
# ['job with refinance', 'step by step']
# []
# ['refinances of home']
# []
# ['relevance of review', 'level of service', 'element as quality']
# ['experience with network']
# ['experience with Barrientos', 'attention to details']
# ['aspects of process']
# ['interest in', 'fi with Funding', 'start to funding']
# ['cash out', 'misunderstandings on part', 'nightmares Through ups']
# ['problems with']
# []
# ['loan for', 'quest for loan', 'loan for', 'meeting with Austin', 'grasp of requests', 'attorneys with years', 'years than', 'years of experience', 'choice for needs', 'needs for family']
# []
# ['experience of', 'refinancing within weeks', 'achievement in']
# ['friends at keesler', 'winner in Ramos']
# []
# []
# ['areas of expertise', 'assistance with mortgage']
# ['rating of', 'process to results']
# []
# []
# ['assistance throughout process']
# ['decisions on']
# []
# ['attention from']
# []
# ['lot of']
# []
# ['assistance of Michael']
# []
# ['experiences with institutions', 'guidance with', 'step in process']
# ['feedback in process', 'process of loan']
# ['experience with capital']
# ['experience with capital']
# ['service of customers']
# []
# []
# ['team at Capital', 'rest of team', 'rest for work']
# ['loan with Capital', 'completion with Capital', 'date of call', 'lapses for', 'need of mortgage']
# []
# ['lot of effort']
# ['experience from start']
# []
# []
# []
# []
# ['contact with', 'saver for', 'documents at FedEx', 'call from Edwin']
# []
# ['experience with Teddy']
# []
# ['updates on progress']
# []
# []
# ['step of way']
# []
# ['part of Refinancing', 'home in Sarasota', 'step of', 'step on call', 'employee of Capital', 'stages of Refinance', 'job with Mother', 'part of Refinance']
# ['help as']
# ['step of way']
# []
# []
# []
# []
# []
# ['attention to detail']
# []
# ['recommendation from Gilbert', 'friend of mine', 'lots of reasons', 'experience with Gabriel', 'truth of', 'experience with Gabriel']
# ['set of circumstances', 'WOMAN WITH CHILDREN', 'BOTTOM OF TEDDY', 'WALKED WITH', 'RESPECT TO']
# []
# ['place for funding']
# ['surge in spring', 'spring of', 'need for turn', 'help during search', 'service at forefront', 'periods in life']
# []
# ['experience with persons']
# ['company with advice']
# ['go to ethics']
# []
# ['beginning to end']
# []
# []
# ['expense with service', 'service with office', 'lenders for properties', 'hold of']
# []
# ['service throughout process']
# []
# []
# []
# []
# ['top of account', 'aspect of banking', 'order for']
# []
# []
# ['calls about mortgage', 'Part of income']
# ['part in process', 'transmission of documents']
# []
# ['alot of patients']
# ['speed of team']
# []
# []
# ['lack of communication', 'refinance to Nguyen', 'star of ordeal']
# []
# []
# ['disclosure from competitor', 'competitor with rate']
# ['step of process']
# []
# ['refinance with Eraso', 'andstatus of departments']
# []
# ['bunch of scenarios']
# []
# []
# ['experience with Capitol', 'step of process', 'snap In trust', 'experience for']
# ['asset to company']
# []
# ['victim of theft', 'verge of']
# ['companies with Capital', 'weeks of conversation']
# ['opportunities for', 'interests at heart']
# []
# ['experience with Capital', 'team of Gill']
# ['ratings at Capital']
# ['peace of mind']
# []
# ['cash out']
# []
# []
# []
# []
# []
# []
# ['help of Bowler']
# ['call to Capital', 'applications with Capital']
# ['process of']
# []
# ['process for', 'help of Haddoumi']
# ['review for help', 'help with mortgage', 'help at Capital', 'Thanks to']
# []
# ['out of question']
# ['look for']
# []
# []
# []
# ['conversation with officer', 'case in']
# []
# ['RAISES TO INCOME']
# []
# []
# ['review of salesman', 'discount on fees', 'discount on fees', 'night of weekend', 'weekend before Monday', 'thanks After time', 'hours of', 'dollars per month', 'script to story', 'call from auditor', 'auditor at Capital', 'returns for audit', 'beginning of process', 'issues with firm']
# ['help with refinance', 'step of process', 'experience with Capital', 'experience of life']
# []
# ['alot of requests', 'need for reappraisal', 'reappraisal on property', 'copy of appraisal', 'insult to injury', 'wslk through', 'aspects of process']
# []
# []
# ['refinance of mortgage', 'options for lenders', 'thousands of dollars', 'thousands in costs', 'thousands than company']
# ['refinancing of property']
# ['service in future']
# []
# []
# ['beginning of process', 'decision out']
# []
# []
# ['income in household', 'process of', 'team at Capital', 'team at Capital']
# ['step of results']
# ['customer of', 'spot on', 'regards to']
# []
# []
# []
# ['friends with people']
# ['top of papers']
# ['part of transaction', 'transaction from beginning', 'practice of', 'concern on part', 'end of process', 'none of concerns', 'word about officer', 'people like']
# ['thanks to']
# ['team at Lane', 'updates on', 'top of process']
# ['problems with']
# ['process of', 'refinance with Capital', 'member of team']
# ['man to woman', 'top of', 'home for year', 'show about Funding', 'line of work', 'custody of', 'people on side', 'side of country', 'refinance to loan', 'top of finances']
# []
# []
# ['communication with questions', 'questions along way']
# ['problem with communication']
# ['diligence in', 'step of process']
# ['house like', 'lot of research', 'lot of questions']
# []
# ['thousands in debt']
# []
# ['Payment for Insurance']
# []
# []
# ['process with Capital']
# []
# ['start to finish']
# []
# ['experience with Funding', 'begining of process', 'changes between payment']
# ['process with issues']
# []
# ['processes with Capital', 'interest at heart']
# []
# []
# ['advertisement on radio']
# []
# ['ad for Capital', 'epitome of service', 'company Between Chemidlin', 'deal on loan']
# []
# []
# ['refi with capital', 'experience with']
# ['experience with Johnson', 'step of process']
# ['top of things', 'thanks to Peterson']
# []
# []
# ['kind of information']
# ['company of', 'rest of life', 'company with ratings', 'day About', 'ups over weeks', 'requirement for appraisal', 'Thanks to team']
# ['Part of', 'refi with Capital']
# []
# ['bills of']
# ['lots of patience', 'lots with', 'accent from language']
# []
# ['rate for family']
# []
# ['requirements at beginning', 'multiple Re process', 'process on properties', 'cash out', 'cash Re t']
# ['lot of confusion', 'lot with cancellations']
# []
# ['thanks to artists']
# ['response within hours', 'communication with customers']
# ['ups from employees', 'ups in world', 'employees like Teddy', 'bottom of heart', 'job in']
# []
# ['months of', 'catalyst for']
# []
# []
# []
# ['representative of company']
# []
# []
# []
# ['part of mortgage', 'courtesy of', 'calls to Anthony', 'misunderstanding on part', 'part about', 'contact with company', 'lack of calls']
# []
# []
# ['answers to questions']
# []
# ['tools for', 'weeks from start']
# []
# []
# []
# []
# []
# ['experience of refinance', 'refinance with Tracy', 'job in', 'underwriters With Peterson', 'choice for needs']
# ['services of capital', 'team of M', 'group of guys', 'firm of capital', 'thanks on behalf', 'behalf of Cassell']
# ['interactions with Zac']
# ['information With mortgages']
# ['transition in matter']
# ['interest as']
# []
# ['try with rating']
# []
# []
# ['none of companies', 'representative for company']
# ['experience for loan', 'place of work', 'hold of Stephan']
# ['process of']
# []
