# %%
from transformers import AutoTokenizer, AutoModel
import torch
import pandas as pd
import numpy as np
import re
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import warnings
from wordcloud import WordCloud, STOPWORDS

warnings.filterwarnings("ignore")

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
model = AutoModel.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0]  # First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min = 1e-9)


def embeding_calc(sentences):

    # tokenizing
    encoded_input = tokenizer(sentences, padding = True, truncation = True, return_tensors = 'pt')

    # passing though model
    with torch.no_grad():
        model_output = model(**encoded_input)

    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    return sentence_embeddings

# %%
result = embeding_calc(['balanced sound','good sound'])

# %%
len(result)
# Out:
# 2

# %%
score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))

# %%
score[0][0]
# Out:
# 0.7417778

# %%
def similarity_calc(input1,input2):
    result = embeding_calc([input1,input2])
    score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))
    return score[0][0]

# %%
similarity_calc('balanced sound','poor bose')
# Out:
# 0.16619003

# %% [markdown]
# # Data processing

# %%
df = pd.read_csv('/home/heptagon/Desktop/nps_review_analysis/key_phrases_new.csv')

# %%
df.shape
# Out:
# (93, 4)

# %%
df.head()
# Out:
#                                             comments  \
# 0  The one is very excellent I have used many Blu...
# 1  I have been using it from months extensivelyIt...
# 2  Review after a day of full usagea Bose seems t...
# 3  So the clarity is crisp you can hear the sound...
# 4  Costly but the best blutooth speaker You will ...
#
#                                                topic          type sentiment
# 0            balanced sound,poor bose,technical team  appreciation  POSITIVE
# 1  portable speaker,sound quality,high portabilit...   information  POSITIVE
# 2  full usagea,sweet spot,ii generation,heavy bas...   information  NEGATIVE
# 3                                      sound quality   information  POSITIVE
# 4                                      best blutooth  appreciation  POSITIVE

# %%
all_keyword = []
for key_str in tqdm(df.topic):
#     print(key_str)
    splited_str = key_str.split(',')
    if len(splited_str)>0:
        all_keyword += splited_str
#     break

all_keyword
# Out:
# 100%|███████████████████████████████████████| 93/93 [00:00<00:00, 237413.43it/s]
# ['balanced sound',
#  'poor bose',
#  'technical team',
#  'portable speaker',
#  'sound quality',
#  'high portability',
#  'sound quality',
#  'perfect trip',
#  'full volume',
#  'full week',
#  'daily music',
#  'worth money',
#  'perfect condition',
#  'full price',
#  'individual perception',
#  'full usagea',
#  'sweet spot',
#  'ii generation',
#  'heavy bass',
#  'equaliser source',
#  'sound punchyb',
#  'old song',
#  'bt connectivity',
#  'bt version',
#  'basic equilizer',
#  'timesoverall verdict',
#  'basic job',
#  'sound quality',
#  'best blutooth',
#  'much product',
#  'worth shipment',
#  'outer box',
#  'thin plastic',
#  'rough handling',
#  'outer cardboard',
#  'poor experience',
#  'beautiful box',
#  'good product',
#  'perfect box',
#  'original factory',
#  'good deal',
#  'little beauty',
#  'vividh bharti',
#  'marvellous sound',
#  'transparent sound',
#  'good sound',
#  'little genius',
#  'sound clarity',
#  'transparent quality',
#  'tiny speaker',
#  'treble bass',
#  'foolish compare',
#  'bose sound',
#  'twice music',
#  'loud election',
#  'sound product',
#  'worth money',
#  'worthy product',
#  'excellent quality',
#  'exceptional quality',
#  'sound quality',
#  'full sound',
#  'clear sound',
#  'satisfied speaker',
#  'bossy bose',
#  'bossy crispy',
#  'balanced auto',
#  'equalized bass',
#  'high satisfaction',
#  'bigger speaker',
#  'portable speaker',
#  'audible punch',
#  'bose revolve',
#  'sound quality',
#  'top notch',
#  'light weight',
#  'con drain',
#  'satisfied love',
#  'great sound',
#  'disturbing fact',
#  'crisp sound',
#  'best quality',
#  'riyaz morning',
#  'small gathering',
#  'good package',
#  'trebble base',
#  'sound quality',
#  'absolute beast',
#  'good predecessor',
#  'original revolve',
#  'natural music',
#  'previous version',
#  'compatible window',
#  'mic noise',
#  'quick wellto',
#  'different price',
#  'mixed packaging',
#  'first lot',
#  'junior model',
#  'correct price',
#  'natural sound',
#  'sound quality',
#  'perfect blend',
#  'overall music',
#  'perfect output',
#  'high volume',
#  'perfect match',
#  'treble volume',
#  'superb quality',
#  'excellent form',
#  'sound quality',
#  'portable case',
#  'durable disadvantage',
#  'bigger driver',
#  'open area',
#  'audio sizebase',
#  'clarityother frequency',
#  'versatile play',
#  'best sound',
#  'expensive speaker',
#  'subtle note',
#  'first bose',
#  'quick sound',
#  'sound clarity',
#  'excess percent',
#  'bose app',
#  'good battery',
#  'full charge',
#  'connect device',
#  'useful music',
#  'next level',
#  'top speaker',
#  'whole year',
#  'good win',
#  'many day',
#  'good speaker',
#  'soundlink revolve',
#  'last day',
#  'good water',
#  'outside room',
#  'best part',
#  'high volume',
#  'exact price',
#  'ok price',
#  'perfect condition',
#  'satisfied product',
#  'lesser mrps',
#  'sound quality',
#  'happy sound',
#  'balanced sound',
#  'sound quality',
#  'loud crystal',
#  'clear sound',
#  'much bass',
#  'amazing music',
#  'important product',
#  'audio tech',
#  'skeptical price',
#  'rounded treat',
#  'sound quality',
#  'better others',
#  'best surround',
#  'portable speaker',
#  'first bose',
#  'live performance',
#  'incredible piece',
#  'sound type',
#  'refund purchase',
#  'top notch',
#  'sound quality',
#  'loud work',
#  'good sound',
#  'sound quality',
#  'good investment',
#  'amazing voice',
#  'fantastic using',
#  'expensive sale',
#  'lowest price',
#  'prime day',
#  'well battery',
#  'sound quality',
#  'awesome product',
#  'bose speaker',
#  'main purpose',
#  'audio video',
#  'annoying answer',
#  'disappointed behaviour',
#  'good quality',
#  'suitable home',
#  'wise gud',
#  'portable speaker',
#  'good everyday',
#  'much bass',
#  'remote party',
#  'original packing',
#  'easy connectivity',
#  'awesome sound',
#  'sound quality',
#  'deep bass',
#  'audio quality',
#  'small speaker',
#  'good quality',
#  'fantastic piece',
#  'good bass',
#  'bt connection',
#  'long battery',
#  'sensitive ear',
#  'instrument sound',
#  'bose music',
#  'much help',
#  'sound quality',
#  'excellent product',
#  'bose product',
#  'bose speaker',
#  'sound quality',
#  'sound quality',
#  'good bose',
#  'original product',
#  'sound quality',
#  'sound quality',
#  'great product',
#  'excellent product',
#  'good recommend',
#  'bose vol',
#  'cheaper product',
#  'sound quality',
#  'portable speaker',
#  'great sound',
#  'sound quality',
#  'sound expectation',
#  'dull term',
#  'sound bar',
#  'lesser price',
#  'worth investment',
#  'top speaker',
#  'spare tv',
#  'pathetic service',
#  'soundlink revolve',
#  'bose product',
#  'irreparable mention',
#  'proper service',
#  'bose product',
#  'entire money',
#  'bose sale',
#  'futile email',
#  'sound quality',
#  'awesome purchase',
#  'expensive product',
#  'well day',
#  'half price',
#  'available service',
#  'bose revolve',
#  'technical knowledge',
#  'first time',
#  'prime customer',
#  'good size',
#  'good amount',
#  'deep bass',
#  'seprate bass',
#  'deeper bass',
#  'know couple',
#  'cautious spend',
#  'willing purchase',
#  'best business',
#  'wrong product',
#  'enough pinch',
#  'terrible sale',
#  'sound mind',
#  'dirty time',
#  'glad buy',
#  'good purchase',
#  'sound system',
#  'good clarity',
#  'pure treat',
#  'poor quality',
#  'connect phone',
#  'kind quality',
#  'technical call',
#  'technical support',
#  'technical fee',
#  'worth extent',
#  'portable home',
#  'natural mono',
#  'least hour',
#  'moderate volume',
#  'new one',
#  'best feature',
#  'connect speaker',
#  'portable home',
#  'big speaker',
#  'louder room',
#  'loud bose',
#  'portable home',
#  'great care',
#  'great deal',
#  'first generation',
#  'second gen',
#  'misleading piece',
#  'soundlink revolve',
#  'portable speaker',
#  'serious piece',
#  'sound quality',
#  'great frequency',
#  'quick hassle',
#  'bose app',
#  'simple use',
#  'sound quality',
#  'clear lack',
#  'outdoor use',
#  'casual listening',
#  'worth amount',
#  'sound quality',
#  'clear ease',
#  'sound quality',
#  'portable speaker',
#  'amazing clarity',
#  'bose revolve',
#  'excellent friend',
#  'black finish',
#  'great love',
#  'great sound',
#  'good battery',
#  'happy product',
#  'great sound']

# %%
freq_count = {}
for key in all_keyword:
    if key in freq_count:
        freq_count[key] +=1
    else:
        freq_count[key] = 1

# %%
len(freq_count)
# Out:
# 264

# %%
freq_count
# Out:
# {'balanced sound': 2,
#  'poor bose': 1,
#  'technical team': 1,
#  'portable speaker': 7,
#  'sound quality': 27,
#  'high portability': 1,
#  'perfect trip': 1,
#  'full volume': 1,
#  'full week': 1,
#  'daily music': 1,
#  'worth money': 2,
#  'perfect condition': 2,
#  'full price': 1,
#  'individual perception': 1,
#  'full usagea': 1,
#  'sweet spot': 1,
#  'ii generation': 1,
#  'heavy bass': 1,
#  'equaliser source': 1,
#  'sound punchyb': 1,
#  'old song': 1,
#  'bt connectivity': 1,
#  'bt version': 1,
#  'basic equilizer': 1,
#  'timesoverall verdict': 1,
#  'basic job': 1,
#  'best blutooth': 1,
#  'much product': 1,
#  'worth shipment': 1,
#  'outer box': 1,
#  'thin plastic': 1,
#  'rough handling': 1,
#  'outer cardboard': 1,
#  'poor experience': 1,
#  'beautiful box': 1,
#  'good product': 1,
#  'perfect box': 1,
#  'original factory': 1,
#  'good deal': 1,
#  'little beauty': 1,
#  'vividh bharti': 1,
#  'marvellous sound': 1,
#  'transparent sound': 1,
#  'good sound': 2,
#  'little genius': 1,
#  'sound clarity': 2,
#  'transparent quality': 1,
#  'tiny speaker': 1,
#  'treble bass': 1,
#  'foolish compare': 1,
#  'bose sound': 1,
#  'twice music': 1,
#  'loud election': 1,
#  'sound product': 1,
#  'worthy product': 1,
#  'excellent quality': 1,
#  'exceptional quality': 1,
#  'full sound': 1,
#  'clear sound': 2,
#  'satisfied speaker': 1,
#  'bossy bose': 1,
#  'bossy crispy': 1,
#  'balanced auto': 1,
#  'equalized bass': 1,
#  'high satisfaction': 1,
#  'bigger speaker': 1,
#  'audible punch': 1,
#  'bose revolve': 3,
#  'top notch': 2,
#  'light weight': 1,
#  'con drain': 1,
#  'satisfied love': 1,
#  'great sound': 4,
#  'disturbing fact': 1,
#  'crisp sound': 1,
#  'best quality': 1,
#  'riyaz morning': 1,
#  'small gathering': 1,
#  'good package': 1,
#  'trebble base': 1,
#  'absolute beast': 1,
#  'good predecessor': 1,
#  'original revolve': 1,
#  'natural music': 1,
#  'previous version': 1,
#  'compatible window': 1,
#  'mic noise': 1,
#  'quick wellto': 1,
#  'different price': 1,
#  'mixed packaging': 1,
#  'first lot': 1,
#  'junior model': 1,
#  'correct price': 1,
#  'natural sound': 1,
#  'perfect blend': 1,
#  'overall music': 1,
#  'perfect output': 1,
#  'high volume': 2,
#  'perfect match': 1,
#  'treble volume': 1,
#  'superb quality': 1,
#  'excellent form': 1,
#  'portable case': 1,
#  'durable disadvantage': 1,
#  'bigger driver': 1,
#  'open area': 1,
#  'audio sizebase': 1,
#  'clarityother frequency': 1,
#  'versatile play': 1,
#  'best sound': 1,
#  'expensive speaker': 1,
#  'subtle note': 1,
#  'first bose': 2,
#  'quick sound': 1,
#  'excess percent': 1,
#  'bose app': 2,
#  'good battery': 2,
#  'full charge': 1,
#  'connect device': 1,
#  'useful music': 1,
#  'next level': 1,
#  'top speaker': 2,
#  'whole year': 1,
#  'good win': 1,
#  'many day': 1,
#  'good speaker': 1,
#  'soundlink revolve': 3,
#  'last day': 1,
#  'good water': 1,
#  'outside room': 1,
#  'best part': 1,
#  'exact price': 1,
#  'ok price': 1,
#  'satisfied product': 1,
#  'lesser mrps': 1,
#  'happy sound': 1,
#  'loud crystal': 1,
#  'much bass': 2,
#  'amazing music': 1,
#  'important product': 1,
#  'audio tech': 1,
#  'skeptical price': 1,
#  'rounded treat': 1,
#  'better others': 1,
#  'best surround': 1,
#  'live performance': 1,
#  'incredible piece': 1,
#  'sound type': 1,
#  'refund purchase': 1,
#  'loud work': 1,
#  'good investment': 1,
#  'amazing voice': 1,
#  'fantastic using': 1,
#  'expensive sale': 1,
#  'lowest price': 1,
#  'prime day': 1,
#  'well battery': 1,
#  'awesome product': 1,
#  'bose speaker': 2,
#  'main purpose': 1,
#  'audio video': 1,
#  'annoying answer': 1,
#  'disappointed behaviour': 1,
#  'good quality': 2,
#  'suitable home': 1,
#  'wise gud': 1,
#  'good everyday': 1,
#  'remote party': 1,
#  'original packing': 1,
#  'easy connectivity': 1,
#  'awesome sound': 1,
#  'deep bass': 2,
#  'audio quality': 1,
#  'small speaker': 1,
#  'fantastic piece': 1,
#  'good bass': 1,
#  'bt connection': 1,
#  'long battery': 1,
#  'sensitive ear': 1,
#  'instrument sound': 1,
#  'bose music': 1,
#  'much help': 1,
#  'excellent product': 2,
#  'bose product': 3,
#  'good bose': 1,
#  'original product': 1,
#  'great product': 1,
#  'good recommend': 1,
#  'bose vol': 1,
#  'cheaper product': 1,
#  'sound expectation': 1,
#  'dull term': 1,
#  'sound bar': 1,
#  'lesser price': 1,
#  'worth investment': 1,
#  'spare tv': 1,
#  'pathetic service': 1,
#  'irreparable mention': 1,
#  'proper service': 1,
#  'entire money': 1,
#  'bose sale': 1,
#  'futile email': 1,
#  'awesome purchase': 1,
#  'expensive product': 1,
#  'well day': 1,
#  'half price': 1,
#  'available service': 1,
#  'technical knowledge': 1,
#  'first time': 1,
#  'prime customer': 1,
#  'good size': 1,
#  'good amount': 1,
#  'seprate bass': 1,
#  'deeper bass': 1,
#  'know couple': 1,
#  'cautious spend': 1,
#  'willing purchase': 1,
#  'best business': 1,
#  'wrong product': 1,
#  'enough pinch': 1,
#  'terrible sale': 1,
#  'sound mind': 1,
#  'dirty time': 1,
#  'glad buy': 1,
#  'good purchase': 1,
#  'sound system': 1,
#  'good clarity': 1,
#  'pure treat': 1,
#  'poor quality': 1,
#  'connect phone': 1,
#  'kind quality': 1,
#  'technical call': 1,
#  'technical support': 1,
#  'technical fee': 1,
#  'worth extent': 1,
#  'portable home': 3,
#  'natural mono': 1,
#  'least hour': 1,
#  'moderate volume': 1,
#  'new one': 1,
#  'best feature': 1,
#  'connect speaker': 1,
#  'big speaker': 1,
#  'louder room': 1,
#  'loud bose': 1,
#  'great care': 1,
#  'great deal': 1,
#  'first generation': 1,
#  'second gen': 1,
#  'misleading piece': 1,
#  'serious piece': 1,
#  'great frequency': 1,
#  'quick hassle': 1,
#  'simple use': 1,
#  'clear lack': 1,
#  'outdoor use': 1,
#  'casual listening': 1,
#  'worth amount': 1,
#  'clear ease': 1,
#  'amazing clarity': 1,
#  'excellent friend': 1,
#  'black finish': 1,
#  'great love': 1,
#  'happy product': 1}

# %%
unique_keywords = freq_count.keys()
unique_keywords
# Out:
# dict_keys(['balanced sound', 'poor bose', 'technical team', 'portable speaker', 'sound quality', 'high portability', 'perfect trip', 'full volume', 'full week', 'daily music', 'worth money', 'perfect condition', 'full price', 'individual perception', 'full usagea', 'sweet spot', 'ii generation', 'heavy bass', 'equaliser source', 'sound punchyb', 'old song', 'bt connectivity', 'bt version', 'basic equilizer', 'timesoverall verdict', 'basic job', 'best blutooth', 'much product', 'worth shipment', 'outer box', 'thin plastic', 'rough handling', 'outer cardboard', 'poor experience', 'beautiful box', 'good product', 'perfect box', 'original factory', 'good deal', 'little beauty', 'vividh bharti', 'marvellous sound', 'transparent sound', 'good sound', 'little genius', 'sound clarity', 'transparent quality', 'tiny speaker', 'treble bass', 'foolish compare', 'bose sound', 'twice music', 'loud election', 'sound product', 'worthy product', 'excellent quality', 'exceptional quality', 'full sound', 'clear sound', 'satisfied speaker', 'bossy bose', 'bossy crispy', 'balanced auto', 'equalized bass', 'high satisfaction', 'bigger speaker', 'audible punch', 'bose revolve', 'top notch', 'light weight', 'con drain', 'satisfied love', 'great sound', 'disturbing fact', 'crisp sound', 'best quality', 'riyaz morning', 'small gathering', 'good package', 'trebble base', 'absolute beast', 'good predecessor', 'original revolve', 'natural music', 'previous version', 'compatible window', 'mic noise', 'quick wellto', 'different price', 'mixed packaging', 'first lot', 'junior model', 'correct price', 'natural sound', 'perfect blend', 'overall music', 'perfect output', 'high volume', 'perfect match', 'treble volume', 'superb quality', 'excellent form', 'portable case', 'durable disadvantage', 'bigger driver', 'open area', 'audio sizebase', 'clarityother frequency', 'versatile play', 'best sound', 'expensive speaker', 'subtle note', 'first bose', 'quick sound', 'excess percent', 'bose app', 'good battery', 'full charge', 'connect device', 'useful music', 'next level', 'top speaker', 'whole year', 'good win', 'many day', 'good speaker', 'soundlink revolve', 'last day', 'good water', 'outside room', 'best part', 'exact price', 'ok price', 'satisfied product', 'lesser mrps', 'happy sound', 'loud crystal', 'much bass', 'amazing music', 'important product', 'audio tech', 'skeptical price', 'rounded treat', 'better others', 'best surround', 'live performance', 'incredible piece', 'sound type', 'refund purchase', 'loud work', 'good investment', 'amazing voice', 'fantastic using', 'expensive sale', 'lowest price', 'prime day', 'well battery', 'awesome product', 'bose speaker', 'main purpose', 'audio video', 'annoying answer', 'disappointed behaviour', 'good quality', 'suitable home', 'wise gud', 'good everyday', 'remote party', 'original packing', 'easy connectivity', 'awesome sound', 'deep bass', 'audio quality', 'small speaker', 'fantastic piece', 'good bass', 'bt connection', 'long battery', 'sensitive ear', 'instrument sound', 'bose music', 'much help', 'excellent product', 'bose product', 'good bose', 'original product', 'great product', 'good recommend', 'bose vol', 'cheaper product', 'sound expectation', 'dull term', 'sound bar', 'lesser price', 'worth investment', 'spare tv', 'pathetic service', 'irreparable mention', 'proper service', 'entire money', 'bose sale', 'futile email', 'awesome purchase', 'expensive product', 'well day', 'half price', 'available service', 'technical knowledge', 'first time', 'prime customer', 'good size', 'good amount', 'seprate bass', 'deeper bass', 'know couple', 'cautious spend', 'willing purchase', 'best business', 'wrong product', 'enough pinch', 'terrible sale', 'sound mind', 'dirty time', 'glad buy', 'good purchase', 'sound system', 'good clarity', 'pure treat', 'poor quality', 'connect phone', 'kind quality', 'technical call', 'technical support', 'technical fee', 'worth extent', 'portable home', 'natural mono', 'least hour' ...

# %%
clustures = []

used_keywords = []

for i in tqdm(unique_keywords):
    current_custer = [i]
    
    if (i in used_keywords):
        continue
    
    used_keywords.append(i)
    
    
    for j in unique_keywords:
        if  (j in used_keywords):
            continue
    
        current_score = similarity_calc(i,j)
        if current_score>0.7:
            current_custer.append(j)
            used_keywords.append(j)
            
    
    clustures.append(current_custer)
        
#     break
# Out:
# 100%|█████████████████████████████████████████| 264/264 [05:34<00:00,  1.27s/it]

# %%
len(clustures)
# Out:
# 160

# %%
clustures[:10]
# Out:
# [['balanced sound',
#   'sound quality',
#   'good sound',
#   'sound clarity',
#   'bose sound',
#   'sound product',
#   'full sound',
#   'clear sound',
#   'great sound',
#   'crisp sound',
#   'natural sound',
#   'best sound',
#   'quick sound',
#   'sound type',
#   'audio quality',
#   'instrument sound',
#   'sound system'],
#  ['poor bose', 'good bose'],
#  ['technical team'],
#  ['portable speaker',
#   'expensive speaker',
#   'audio tech',
#   'bose speaker',
#   'small speaker',
#   'connect speaker'],
#  ['high portability'],
#  ['perfect trip'],
#  ['full volume', 'high volume', 'treble volume', 'moderate volume'],
#  ['full week'],
#  ['daily music',
#   'twice music',
#   'natural music',
#   'overall music',
#   'useful music',
#   'amazing music',
#   'bose music'],
#  ['worth money',
#   'worth investment',
#   'good amount',
#   'worth extent',
#   'worth amount']]

# %%
final_result = []
for cp in clustures:
    cluster_key_count = {}
    for key_c in cp:
        cluster_key_count[key_c] = freq_count[key_c]
    
    items = []
    for i in list(tuple(cluster_key_count.keys())):
        items.append(i.split()[0])
    dict1 = {}
    for item in items:
        if not item in dict1:
            dict1[item] = items.count(item)
    dict1 = sorted(dict1.keys(), reverse=True)[0]

    curr_cul_keys = list(cluster_key_count.keys())
    curr_cul_values = list(cluster_key_count.values())
    sum_of_similar_words = np.sum(curr_cul_values)
    highest_count_key = curr_cul_keys[np.argmax(curr_cul_values)]
    highest_count_value = np.max(curr_cul_values)
    final_result.append([cluster_key_count,sum_of_similar_words,highest_count_key,len(cluster_key_count), dict1])
    
#     break

# %%
final_result
# Out:
# [[{'balanced sound': 2,
#    'sound quality': 27,
#    'good sound': 2,
#    'sound clarity': 2,
#    'bose sound': 1,
#    'sound product': 1,
#    'full sound': 1,
#    'clear sound': 2,
#    'great sound': 4,
#    'crisp sound': 1,
#    'natural sound': 1,
#    'best sound': 1,
#    'quick sound': 1,
#    'sound type': 1,
#    'audio quality': 1,
#    'instrument sound': 1,
#    'sound system': 1},
#   50,
#   'sound quality',
#   17,
#   'sound'],
#  [{'poor bose': 1, 'good bose': 1}, 2, 'poor bose', 2, 'poor'],
#  [{'technical team': 1}, 1, 'technical team', 1, 'technical'],
#  [{'portable speaker': 7,
#    'expensive speaker': 1,
#    'audio tech': 1,
#    'bose speaker': 2,
#    'small speaker': 1,
#    'connect speaker': 1},
#   13,
#   'portable speaker',
#   6,
#   'small'],
#  [{'high portability': 1}, 1, 'high portability', 1, 'high'],
#  [{'perfect trip': 1}, 1, 'perfect trip', 1, 'perfect'],
#  [{'full volume': 1,
#    'high volume': 2,
#    'treble volume': 1,
#    'moderate volume': 1},
#   5,
#   'high volume',
#   4,
#   'treble'],
#  [{'full week': 1}, 1, 'full week', 1, 'full'],
#  [{'daily music': 1,
#    'twice music': 1,
#    'natural music': 1,
#    'overall music': 1,
#    'useful music': 1,
#    'amazing music': 1,
#    'bose music': 1},
#   7,
#   'daily music',
#   7,
#   'useful'],
#  [{'worth money': 2,
#    'worth investment': 1,
#    'good amount': 1,
#    'worth extent': 1,
#    'worth amount': 1},
#   6,
#   'worth money',
#   5,
#   'worth'],
#  [{'perfect condition': 2, 'perfect output': 1},
#   3,
#   'perfect condition',
#   2,
#   'perfect'],
#  [{'full price': 1,
#    'different price': 1,
#    'correct price': 1,
#    'exact price': 1,
#    'ok price': 1,
#    'expensive sale': 1,
#    'half price': 1},
#   7,
#   'full price',
#   7,
#   'ok'],
#  [{'individual perception': 1}, 1, 'individual perception', 1, 'individual'],
#  [{'full usagea': 1, 'simple use': 1}, 2, 'full usagea', 2, 'simple'],
#  [{'sweet spot': 1}, 1, 'sweet spot', 1, 'sweet'],
#  [{'ii generation': 1, 'first generation': 1}, 2, 'ii generation', 2, 'ii'],
#  [{'heavy bass': 1,
#    'treble bass': 1,
#    'equalized bass': 1,
#    'much bass': 2,
#    'deep bass': 2,
#    'good bass': 1,
#    'seprate bass': 1,
#    'deeper bass': 1},
#   10,
#   'much bass',
#   8,
#   'treble'],
#  [{'equaliser source': 1}, 1, 'equaliser source', 1, 'equaliser'],
#  [{'sound punchyb': 1,
#    'marvellous sound': 1,
#    'audible punch': 1,
#    'mic noise': 1,
#    'awesome sound': 1,
#    'loud bose': 1},
#   6,
#   'sound punchyb',
#   6,
#   'sound'],
#  [{'old song': 1}, 1, 'old song', 1, 'old'],
#  [{'bt connectivity': 1, 'easy connectivity': 1, 'bt connection': 1},
#   3,
#   'bt connectivity',
#   3,
#   'easy'],
#  [{'bt version': 1}, 1, 'bt version', 1, 'bt'],
#  [{'basic equilizer': 1}, 1, 'basic equilizer', 1, 'basic'],
#  [{'timesoverall verdict': 1}, 1, 'timesoverall verdict', 1, 'timesoverall'],
#  [{'basic job': 1}, 1, 'basic job', 1, 'basic'],
#  [{'best blutooth': 1}, 1, 'best blutooth', 1, 'best'],
#  [{'much product': 1,
#    'important product': 1,
#    'great product': 1,
#    'expensive product': 1},
#   4,
#   'much product',
#   4,
#   'much'],
#  [{'worth shipment': 1}, 1, 'worth shipment', 1, 'worth'],
#  [{'outer box': 1, 'outer cardboard': 1, 'beautiful box': 1},
#   3,
#   'outer box',
#   3,
#   'outer'],
#  [{'thin plastic': 1}, 1, 'thin plastic', 1, 'thin'],
#  [{'rough handling': 1}, 1, 'rough handling', 1, 'rough'],
#  [{'poor experience': 1}, 1, 'poor experience', 1, 'poor'],
#  [{'good product': 1,
#    'worthy product': 1,
#    'excellent quality': 1,
#    'best quality': 1,
#    'satisfied product': 1,
#    'awesome product': 1,
#    'good quality': 2,
#    'excellent product': 2,
#    'bose product': 3,
#    'good purchase': 1,
#    'happy product': 1},
#   15,
#   'bose product',
#   11,
#   'worthy'],
#  [{'perfect box': 1}, 1, 'perfect box', 1, 'perfect'],
#  [{'original factory': 1, 'original product': 1},
#   2,
#   'original factory',
#   2,
#   'original'],
#  [{'good deal': 1, 'good win': 1, 'glad buy': 1, 'great deal': 1},
#   4,
#   'good deal',
#   4,
#   'great'],
#  [{'little beauty': 1}, 1, 'little beauty', 1, 'little'],
#  [{'vividh bharti': 1}, 1, 'vividh bharti', 1, 'vividh'],
#  [{'transparent sound': 1}, 1, 'transparent sound', 1, 'transparent'],
#  [{'little genius': 1}, 1, 'little genius', 1, 'little'],
#  [{'transparent quality': 1}, 1, 'transparent quality', 1, 'transparent'],
#  [{'tiny speaker': 1}, 1, 'tiny speaker', 1, 'tiny'],
#  [{'foolish compare': 1}, 1, 'foolish compare', 1, 'foolish'],
#  [{'loud election': 1}, 1, 'loud election', 1, 'loud'],
#  [{'exceptional quality': 1,
#    'superb quality': 1,
#    'excellent form': 1,
#    'fantastic using': 1,
#    'kind quality': 1},
#   5,
#   'exceptional quality',
#   5,
#   'superb'],
#  [{'satisfied speaker': 1, 'good speaker': 1, 'happy sound': 1},
#   3,
#   'satisfied speaker',
#   3,
#   'satisfied'],
#  [{'bossy bose': 1, 'bossy crispy': 1}, 2, 'bossy bose', 2, 'bossy'],
#  [{'balanced auto': 1}, 1, 'balanced auto', 1, 'balanced'],
#  [{'high satisfaction': 1}, 1, 'high satisfaction', 1, 'high'],
#  [{'bigger speaker': 1, 'top speaker': 2, 'big speaker': 1},
#   4,
#   'top speaker',
#   3,
#   'top'],
#  [{'bose revolve': 3, 'original revolve': 1},
#   4,
#   'bose revolve',
#   2,
#   'original'],
#  [{'top notch': 2}, 2, 'top notch', 1, 'top'],
#  [{'light weight': 1}, 1, 'light weight', 1, 'light'],
#  [{'con drain': 1}, 1, 'con drain', 1, 'con'],
#  [{'satisfied love': 1, 'great love': 1}, 2, 'satisfied love', 2, 'satisfied'],
#  [{'disturbing fact': 1}, 1, 'disturbing fact', 1, 'disturbing'],
#  [{'riyaz morning': 1}, 1, 'riyaz morning', 1, 'riyaz'],
#  [{'small gathering': 1}, 1, 'small gathering', 1, 'small'],
#  [{'good package': 1}, 1, 'good package', 1, 'good'],
#  [{'trebble base': 1}, 1, 'trebble base', 1, 'trebble'],
#  [{'absolute beast': 1}, 1, 'absolute beast', 1, 'absolute'],
#  [{'good predecessor': 1}, 1, 'good predecessor', 1, 'good'],
#  [{'previous version': 1}, 1, 'previous version', 1, 'previous'],
#  [{'compatible window': 1}, 1, 'compatible window', 1, 'compatible'],
#  [{'quick wellto': 1, 'quick hassle': 1}, 2, 'quick wellto', 2, 'quick'],
#  [{'mixed packaging': 1}, 1, 'mixed packaging', 1, 'mixed'],
#  [{'first lot': 1, 'first bose': 2}, 3, 'first bose', 2, 'first'],
#  [{'junior model': 1}, 1, 'junior model', 1, 'junior'],
#  [{'perfect blend': 1}, 1, 'perfect blend', 1, 'perfect'],
#  [{'perfect match': 1}, 1, 'perfect match', 1, 'perfect'],
#  [{'portable case': 1}, 1, 'portable case', 1, 'portable'],
#  [{'durable disadvantage': 1}, 1, 'durable disadvantage', 1, 'durable'],
#  [{'bigger driver': 1}, 1, 'bigger driver', 1, 'bigger'],
#  [{'open area': 1}, 1, 'open area', 1, 'open'],
#  [{'audio sizebase': 1}, 1, 'audio sizebase', 1, 'audio'],
#  [{'clarityother frequency': 1, 'great frequency': 1},
#   2,
#   'clarityother frequency',
#   2,
#   'great'],
#  [{'versatile play': 1}, 1, 'versatile play', 1, 'versatile'],
#  [{'subtle note': 1}, 1, 'subtle note', 1, 'subtle'],
#  [{'excess percent': 1}, 1, 'excess percent', 1, 'excess'],
#  [{'bose app': 2}, 2, 'bose app', 1, 'bose'],
#  [{'good battery': 2, 'well battery': 1, 'long battery': 1},
#   4,
#   'good battery',
#   3,
#   'well'],
#  [{'full charge': 1}, 1, 'full charge', 1, 'full'],
#  [{'connect device': 1, 'connect phone': 1},
#   2,
#   'connect device',
#   2,
#   'connect'],
#  [{'next level': 1}, 1, 'next level', 1, 'next'],
#  [{'whole year': 1}, 1, 'whole year', 1, 'whole'],
#  [{'many day': 1, 'well day': 1}, 2, 'many day', 2, 'well'],
#  [{'soundlink revolve': 3, 'sound bar': 1},
#   4,
#   'soundlink revolve',
#   2,
#   'soundlink'],
#  [{'last day': 1}, 1, 'last day', 1, 'last'],
#  [{'good water': 1}, 1, 'good water', 1, 'good'],
#  [{'outside room': 1}, 1, 'outside room', 1, 'outside'],
#  [{'best part': 1}, 1, 'best part', 1, 'best'],
#  [{'lesser mrps': 1}, 1, 'lesser mrps', 1, 'lesser'],
#  [{'loud crystal': 1}, 1, 'loud crystal', 1, 'loud'],
#  [{'skeptical price': 1}, 1, 'skeptical price', 1, 'skeptical'],
#  [{'rounded treat': 1}, 1, 'rounded treat', 1, 'rounded'],
#  [{'better others': 1}, 1, 'better others', 1, 'better'],
#  [{'best surround': 1}, 1, 'best surround', 1, 'best'],
#  [{'live performance': 1}, 1, 'live performance', 1, 'live'],
#  [{'incredible piece': 1, 'fantastic piece': 1},
#   2,
#   'incredible piece',
#   2,
#   'incredible'],
#  [{'refund purchase': 1}, 1, 'refund purchase', 1, 'refund'],
#  [{'loud work': 1}, 1, 'loud work', 1, 'loud'],
#  [{'good investment': 1}, 1, 'good investment', 1, 'good'],
#  [{'amazing voice': 1}, 1, 'amazing voice', 1, 'amazing'],
#  [{'lowest price': 1, 'lesser price': 1}, 2, 'lowest price', 2, 'lowest'],
#  [{'prime day': 1}, 1, 'prime day', 1, 'prime'],
#  [{'main purpose': 1}, 1, 'main purpose', 1, 'main'],
#  [{'audio video': 1}, 1, 'audio video', 1, 'audio'],
#  [{'annoying answer': 1}, 1, 'annoying answer', 1, 'annoying'],
#  [{'disappointed behaviour': 1},
#   1,
#   'disappointed behaviour',
#   1,
#   'disappointed'],
#  [{'suitable home': 1, 'portable home': 3}, 4, 'portable home', 2, 'suitable'],
#  [{'wise gud': 1}, 1, 'wise gud', 1, 'wise'],
#  [{'good everyday': 1}, 1, 'good everyday', 1, 'good'],
#  [{'remote party': 1}, 1, 'remote party', 1, 'remote'],
#  [{'original packing': 1}, 1, 'original packing', 1, 'original'],
#  [{'sensitive ear': 1}, 1, 'sensitive ear', 1, 'sensitive'],
#  [{'much help': 1}, 1, 'much help', 1, 'much'],
#  [{'good recommend': 1}, 1, 'good recommend', 1, 'good'],
#  [{'bose vol': 1}, 1, 'bose vol', 1, 'bose'],
#  [{'cheaper product': 1}, 1, 'cheaper product', 1, 'cheaper'],
#  [{'sound expectation': 1}, 1, 'sound expectation', 1, 'sound'],
#  [{'dull term': 1}, 1, 'dull term', 1, 'dull'],
#  [{'spare tv': 1}, 1, 'spare tv', 1, 'spare'],
#  [{'pathetic service': 1, 'proper service': 1},
#   2,
#   'pathetic service',
#   2,
#   'proper'],
#  [{'irreparable mention': 1}, 1, 'irreparable mention', 1, 'irreparable'],
#  [{'entire money': 1}, 1, 'entire money', 1, 'entire'],
#  [{'bose sale': 1}, 1, 'bose sale', 1, 'bose'],
#  [{'futile email': 1}, 1, 'futile email', 1, 'futile'],
#  [{'awesome purchase': 1, 'willing purchase': 1},
#   2,
#   'awesome purchase',
#   2,
#   'willing'],
#  [{'available service': 1}, 1, 'available service', 1, 'available'],
#  [{'technical knowledge': 1, 'technical support': 1},
#   2,
#   'technical knowledge',
#   2,
#   'technical'],
#  [{'first time': 1}, 1, 'first time', 1, 'first'],
#  [{'prime customer': 1}, 1, 'prime customer', 1, 'prime'],
#  [{'good size': 1}, 1, 'good size', 1, 'good'],
#  [{'know couple': 1}, 1, 'know couple', 1, 'know'],
#  [{'cautious spend': 1}, 1, 'cautious spend', 1, 'cautious'],
#  [{'best business': 1}, 1, 'best business', 1, 'best'],
#  [{'wrong product': 1}, 1, 'wrong product', 1, 'wrong'],
#  [{'enough pinch': 1}, 1, 'enough pinch', 1, 'enough'],
#  [{'terrible sale': 1}, 1, 'terrible sale', 1, 'terrible'],
#  [{'sound mind': 1}, 1, 'sound mind', 1, 'sound'],
#  [{'dirty time': 1}, 1, 'dirty time', 1, 'dirty'],
#  [{'good clarity': 1, 'clear ease': 1, 'amazing clarity': 1},
#   3,
#   'good clarity',
#   3,
#   'good'],
#  [{'pure treat': 1}, 1, 'pure treat', 1, 'pure'],
#  [{'poor quality': 1}, 1, 'poor quality', 1, 'poor'],
#  [{'technical call': 1}, 1, 'technical call', 1, 'technical'],
#  [{'technical fee': 1}, 1, 'technical fee', 1, 'technical'],
#  [{'natural mono': 1}, 1, 'natural mono', 1, 'natural'],
#  [{'least hour': 1}, 1, 'least hour', 1, 'least'],
#  [{'new one': 1}, 1, 'new one', 1, 'new'],
#  [{'best feature': 1}, 1, 'best feature', 1, 'best'],
#  [{'louder room': 1}, 1, 'louder room', 1, 'louder'],
#  [{'great care': 1}, 1, 'great care', 1, 'great'],
#  [{'second gen': 1}, 1, 'second gen', 1, 'second'],
#  [{'misleading piece': 1}, 1, 'misleading piece', 1, 'misleading'],
#  [{'serious piece': 1}, 1, 'serious piece', 1, 'serious'],
#  [{'clear lack': 1}, 1, 'clear lack', 1, 'clear'],
#  [{'outdoor use': 1}, 1, 'outdoor use', 1, 'outdoor'],
#  [{'casual listening': 1}, 1, 'casual listening', 1, 'casual'],
#  [{'excellent friend': 1}, 1, 'excellent friend', 1, 'excellent'],
#  [{'black finish': 1}, 1, 'black finish', 1, 'black']]

# %%
df = pd.DataFrame(final_result,columns=["similar_words_and_count","count_of_similar_words","most_used_similar_word","total_similar_words", "key_expressions"])

# %%
sorted_df = df.sort_values('total_similar_words',ascending=False).reset_index(drop=True)

# %%
sorted_df
# Out:
#                                similar_words_and_count  \
# 0    {'balanced sound': 2, 'sound quality': 27, 'go...
# 1    {'good product': 1, 'worthy product': 1, 'exce...
# 2    {'heavy bass': 1, 'treble bass': 1, 'equalized...
# 3    {'full price': 1, 'different price': 1, 'corre...
# 4    {'daily music': 1, 'twice music': 1, 'natural ...
# ..                                                 ...
# 155                            {'previous version': 1}
# 156                            {'good predecessor': 1}
# 157                              {'absolute beast': 1}
# 158                                {'trebble base': 1}
# 159                                {'black finish': 1}
#
#      count_of_similar_words most_used_similar_word  total_similar_words  \
# 0                        50          sound quality                   17
# 1                        15           bose product                   11
# 2                        10              much bass                    8
# 3                         7             full price                    7
# 4                         7            daily music                    7
# ..                      ...                    ...                  ...
# 155                       1       previous version                    1
# 156                       1       good predecessor                    1
# 157                       1         absolute beast                    1
# 158                       1           trebble base                    1
# 159                       1           black finish                    1
#
#     key_expressions
# 0             sound
# 1            worthy
# 2            treble
# 3                ok
# 4            useful
# ..              ...
# 155        previous
# 156            good
# 157        absolute
# 158         trebble
# 159           black
#
# [160 rows x 5 columns]

# %%
sorted_df.to_csv("/home/heptagon/Desktop/nps_review_analysis/most_keywords.csv", index=False)

# %%
print((sorted_df.most_used_similar_word).to_list()[:20])
# Out:
# ['sound quality', 'bose product', 'much bass', 'full price', 'daily music', 'portable speaker', 'sound punchyb', 'exceptional quality', 'worth money', 'high volume', 'good deal', 'much product', 'top speaker', 'satisfied speaker', 'good clarity', 'outer box', 'bt connectivity', 'good battery', 'portable home', 'original factory']
