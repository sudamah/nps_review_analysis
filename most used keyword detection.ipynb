# %%
from transformers import AutoTokenizer, AutoModel
import torch
import pandas as pd
import numpy as np
import re
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import warnings
from wordcloud import WordCloud, STOPWORDS

warnings.filterwarnings("ignore")

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
model = AutoModel.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0]  # First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min = 1e-9)


def embeding_calc(sentences):

    # tokenizing
    encoded_input = tokenizer(sentences, padding = True, truncation = True, return_tensors = 'pt')

    # passing though model
    with torch.no_grad():
        model_output = model(**encoded_input)

    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    return sentence_embeddings

# %%
result = embeding_calc(['balanced sound','good sound'])

# %%
len(result)
# Out:
# 2

# %%
score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))

# %%
score[0][0]
# Out:
# 0.7417778

# %%
def similarity_calc(input1,input2):
    result = embeding_calc([input1,input2])
    score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))
    return score[0][0]

# %%
similarity_calc('balanced sound','poor bose')
# Out:
# 0.16619003

# %% [markdown]
# # Data processing

# %%
df = pd.read_csv('/home/heptagon/Desktop/nps_review_analysis/dataset/BankPanacea_detail_review_topic.csv')

# %%
df.shape
# Out:
# (337, 4)

# %%
df.head()
# Out:
#                                             comments  \
# 0  Smooth easy The loan was exactly as described ...
# 1  The company is doing an amazing job at how pro...
# 2  Parker Beller went out of his way to accommoda...
# 3  Know your customer instructions need update an...
# 4  All customer happily receive all answer happil...
#
#                                                topic sentiment          type
# 0                               easy loan,hidden fee  NEGATIVE  appreciation
# 1                  amazing job,professional customer  POSITIVE  appreciation
# 2      medical school,hectic schedule,available time  NEGATIVE   information
# 3  better clarity,financial transaction,slow proc...  POSITIVE   information
# 4                                         great life  POSITIVE  appreciation

# %%
all_keyword = []
for key_str in tqdm(df.topic):
#     print(key_str)
    splited_str = key_str.split(',')
    if len(splited_str)>0:
        all_keyword += splited_str
#     break

all_keyword
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 337/337 [00:00<00:00, 254589.42it/s]
# ['easy loan',
#  'hidden fee',
#  'amazing job',
#  'professional customer',
#  'medical school',
#  'hectic schedule',
#  'available time',
#  'better clarity',
#  'financial transaction',
#  'slow process',
#  'current balance',
#  'long time',
#  'welcome package',
#  'postal mail',
#  'last name',
#  'closed account',
#  'great life',
#  'pleasant response',
#  'wonderful answer',
#  'faster parker',
#  'professional offering',
#  'entire process',
#  'efficient service',
#  'grateful help',
#  'highest professionalism',
#  'medical office',
#  'high yield',
#  'medical student',
#  'amazed account',
#  'online bank',
#  'personal banker',
#  'primary contact',
#  'private student',
#  'great option',
#  'monthly payment',
#  'better interest',
#  'primary care',
#  'recommend service',
#  'private loan',
#  'multiple loan',
#  'primary care',
#  'monthly payment',
#  'lower interest',
#  'best experience',
#  'myriad company',
#  'easy effortless',
#  'excellent service',
#  'medical field',
#  'financial service',
#  'early career',
#  'easy hope',
#  'good thing',
#  'closed loan',
#  'amazing customer',
#  'great bank',
#  'dental office',
#  'polite people',
#  'smoother process',
#  'huge bank',
#  'financial institution',
#  'appropriate value',
#  'online personable',
#  'seamless experience',
#  'primary care',
#  'wonderful work',
#  'good experience',
#  'personal banker',
#  'timely manner',
#  'financial support',
#  'excellent communication',
#  'unbeatable rate',
#  'easy application',
#  'personal banker',
#  'thankful support',
#  'easy banker',
#  'helpful guide',
#  'specific person',
#  'much money',
#  'medical school',
#  'able pay',
#  'financial situation',
#  'top stress',
#  'first year',
#  'financial burden',
#  'new city',
#  'financial advisor',
#  'medical school',
#  'big bill',
#  'marginal income',
#  'amazing experience',
#  'easy panacea',
#  'financial institution',
#  'financial situation',
#  'new resident',
#  'amazing product',
#  'great interest',
#  'financial track',
#  'individual medicine',
#  'financial risk',
#  'inappropriate panacea',
#  'recommend panacea',
#  'quick seamless',
#  'personal banker',
#  'diligent interface',
#  'timely completion',
#  'smooth experience',
#  'larger investment',
#  'first time',
#  'quick help',
#  'good thing',
#  'financial need',
#  'grateful help',
#  'excellent experience',
#  'best market',
#  'personal banker',
#  'great job',
#  'recommend bank',
#  'easy process',
#  'grateful institution',
#  'medical student',
#  'great customer',
#  'entire process',
#  'pleasant one',
#  'financial employee',
#  'whole process',
#  'financial help',
#  'medical training',
#  'financial institution',
#  'easy work',
#  'quick turnaround',
#  'exceptional banker',
#  'great rate',
#  'hard credit',
#  'quick disbursement',
#  'high interest',
#  'unexpected expense',
#  'helpful loan',
#  'prompt response',
#  'enough answer',
#  'positive experience',
#  'financial credit',
#  'medical education',
#  'easy process',
#  'great customer',
#  'worried afford',
#  'new state',
#  'secure loan',
#  'first conversation',
#  'personal loan',
#  'first job',
#  'easy work',
#  'highest level',
#  'professional service',
#  'great customer',
#  'extra mile',
#  'financial planner',
#  'quick respond',
#  'excellent experience',
#  'competitive transparency',
#  'second none',
#  'amazing service',
#  'amazing service',
#  'medical student',
#  'competitive rate',
#  'primary care',
#  'responsive question',
#  'great work',
#  'shannon rest',
#  'fantastic experience',
#  'navigate website',
#  'professional communication',
#  'efficient work',
#  'prompt respond',
#  'personal banker',
#  'available help',
#  'best physician',
#  'available market',
#  'primary banker',
#  'whole process',
#  'great experience',
#  'true life',
#  'saver intern',
#  'helpful way',
#  'financial providing',
#  'financial portion',
#  'medical student',
#  'smooth user',
#  'extra money',
#  'close construction',
#  'efficient encounter',
#  'great coordinating',
#  'quick loan',
#  'wonderful experience',
#  'primary care',
#  'entire loan',
#  'new panacea',
#  'whole process',
#  'much panacea',
#  'wonderful customer',
#  'able help',
#  'little week',
#  'main coordinator',
#  'able answer',
#  'similar position',
#  'primary banker',
#  'excellent customer',
#  'financial organization',
#  'helpless credit',
#  'fast day',
#  'whole process',
#  'future loan',
#  'wonderful work',
#  'whole process',
#  'professional need',
#  'dental clinic',
#  'couple week',
#  'scheduled effort',
#  'many lender',
#  'great work',
#  'easy apply',
#  'awesome deal',
#  'attentive need',
#  'painless love',
#  'financial struggle',
#  'medical student',
#  'new resident',
#  'decent amount',
#  'perfect fact',
#  'first year',
#  'medical school',
#  'medical school',
#  'high interest',
#  'spare income',
#  'financial institution',
#  'early career',
#  'primary banker',
#  'excellent experience',
#  'efficient process',
#  'great interest',
#  'helpful process',
#  'great communication',
#  'great experience',
#  'hectic transition',
#  'medical school',
#  'financial team',
#  'medical student',
#  'fourth year',
#  'medical student',
#  'extra fund',
#  'fourth year',
#  'medical school',
#  'best rate',
#  'free banker',
#  'happy answer',
#  'complete fund',
#  'great option',
#  'medical field',
#  'excellent experience',
#  'primary care',
#  'real person',
#  'personal banker',
#  'large institution',
#  'physical location',
#  'able transaction',
#  'long waiting',
#  'normal daytime',
#  'unique privilege',
#  'amazing service',
#  'medical student',
#  'primary banker',
#  'amazing communication',
#  'alex panacea',
#  'amazing job',
#  'outstanding communication',
#  'great experience',
#  'reasonable rate',
#  'important thing',
#  'first year',
#  'navigate time',
#  'medical school',
#  'rich parent',
#  'many loan',
#  'personal loan',
#  'regular bank',
#  'medical school',
#  'financial institution',
#  'easy work',
#  'first month',
#  'private student',
#  'prior banking',
#  'primary care',
#  'helpful application',
#  'dental school',
#  'extra finance',
#  'grateful panacea',
#  'financial team',
#  'great experience',
#  'easy loan',
#  'great correspondence',
#  'excellent response',
#  'first choice',
#  'phenomenal experience',
#  'entire process',
#  'easy work',
#  'professional training',
#  'legitimate see',
#  'personal loan',
#  'online account',
#  'couple hour',
#  'speak phone',
#  'prompt response',
#  'frequent reminder',
#  'primary account',
#  'good experience',
#  'happy costumer',
#  'great experience',
#  'easier email',
#  'federal interest',
#  'private loan',
#  'financial relief',
#  'complete training',
#  'fantastic experience',
#  'dental practice',
#  'medical student',
#  'primary care',
#  'entire process',
#  'entire time',
#  'wonderful experience',
#  'strict requirement',
#  'great work',
#  'personal loan',
#  'entire time',
#  'fantastic banker',
#  'excellent customer',
#  'hard help',
#  'best option',
#  'competitive interest',
#  'fair interest',
#  'excellent customer',
#  'medical school',
#  'great help',
#  'friendly service',
#  'great interest',
#  'excellent communication',
#  'long period',
#  'incredible experience',
#  'personal banker',
#  'fantastic service',
#  'best bank',
#  'fresh training',
#  'additional fund',
#  'quick cash',
#  'primary banker',
#  'quick painless',
#  'primary banker',
#  'efficient manner',
#  'happy experience',
#  'professional staff',
#  'efficient underwriting',
#  'new product',
#  'fantastic work',
#  'honest application',
#  'simple fund',
#  'primary care',
#  'quick reply',
#  'overall process',
#  'wonderful deal',
#  'happy service',
#  'whole process',
#  'straightforward banker',
#  'grateful company',
#  'financial relief',
#  'financial need',
#  'medical student',
#  'high interest',
#  'high student',
#  'amazing customer',
#  'whole experience',
#  'unparalleled customer',
#  'financial institution',
#  'incredible job',
#  'attentive kind',
#  'amazing experience',
#  'excellent service',
#  'whole process',
#  'high interest',
#  'difficult time',
#  'amazing raquel',
#  'happier result',
#  'satisfactory service',
#  'helpful staff',
#  'fast problem',
#  'medical school',
#  'great customer',
#  'great partner',
#  'easy work',
#  'excellent experience',
#  'initial deposit',
#  'remarkable experience',
#  'timely manner',
#  'medical student',
#  'frantic cost',
#  'easy application',
#  'many service',
#  'medical student',
#  'primary care',
#  'secure fund',
#  'extra loan',
#  'medical school',
#  'worth peace',
#  'happy decision',
#  'medical student',
#  'fast headache',
#  'free prn',
#  'recommend trainee',
#  'best trust',
#  'entire process',
#  'excellent experience',
#  'much help',
#  'great experience',
#  'multiple pre',
#  'lowest interest',
#  'longer term',
#  'monthly payment',
#  'soft inquiry',
#  'monthly payment',
#  'great experience',
#  'special shout',
#  'alex kugler',
#  'personal banker',
#  'whole process',
#  'recommend others',
#  'online experience',
#  'true definition',
#  'great experience',
#  'private loan',
#  'great customer',
#  'speedy turnover',
#  'high card',
#  'medical loan',
#  'extra money',
#  'existent parker',
#  'fair repayment',
#  'better credit',
#  'personal loan',
#  'easy identity',
#  'much peace',
#  'new chapter',
#  'higher income',
#  'able pay',
#  'unable resident',
#  'future loan',
#  'great experience',
#  'responsive loan',
#  'great customer',
#  'timely response',
#  'extra mile',
#  'easy transaction',
#  'professional interaction',
#  'proffesional employee',
#  'polite calm',
#  'excellent customer',
#  'friendly staff',
#  'great service',
#  'medical student',
#  'great service',
#  'nice customer',
#  'amazing prompt',
#  'excellent expedient',
#  'entire time',
#  'fast quality',
#  'sincere recommendation',
#  'streamlined process',
#  'good experience',
#  'medical doctor',
#  'full time',
#  'late payment',
#  'red flag',
#  'small mistake',
#  'correct approve',
#  'late payment',
#  'expensive book',
#  'academic activity',
#  'experian credit',
#  'best way',
#  'bad effect',
#  'future credit',
#  'entire debt',
#  'personal loan',
#  'bad effect',
#  'advertisement panacea',
#  'difficult way',
#  'illogical reason',
#  'seamless experience',
#  'good experience',
#  'many thanks',
#  'easy transaction',
#  'easy process',
#  'excellent service',
#  'great experience',
#  'usual keep',
#  'great hope',
#  'easy work',
#  'great service',
#  'excellent trust',
#  'nice bank',
#  'medical student',
#  'quick love',
#  'early interest',
#  'medical student',
#  'financial security',
#  'high interest',
#  'lower interest',
#  'rare find',
#  'medical student',
#  'easy process',
#  'good communication',
#  'great experience',
#  'tedious process',
#  'primary care',
#  'financial healthcare',
#  'financial team',
#  'delightful experience',
#  'primary care',
#  'nice change',
#  'online bot',
#  'relevant detail',
#  'efficient keeping',
#  'extra money',
#  'last month',
#  'new place',
#  'impressed professionalism',
#  'responsive email',
#  'financial institution',
#  'financial need',
#  'easy application',
#  'personal banker',
#  'long time',
#  'medical school',
#  'hidden fee',
#  'personal banking',
#  'personal touch',
#  'single person',
#  'quick communication',
#  'helpful process',
#  'happier attention',
#  'excellent customer',
#  'competitive rate',
#  'helpful process',
#  'last year',
#  'dental practice',
#  'cumbersome process',
#  'best interest',
#  'entire process',
#  'able answer',
#  'second time',
#  'personal loan',
#  'satisfied loan',
#  'early payment',
#  'personal loan',
#  'technical difficulty',
#  'third credit',
#  'several point',
#  'recommend panacea',
#  'special opportunity',
#  'great job',
#  'whole process',
#  'crazy schedule',
#  'first contact',
#  'conducted process',
#  'true thank',
#  'open loan',
#  'great option',
#  'many month',
#  'several hit',
#  'large debt',
#  'private student',
#  'real deal',
#  'personal banker',
#  'hard credit',
#  'monthly payment',
#  'financial instrument',
#  'digital age',
#  'professional student',
#  'financial service',
#  'personal loan',
#  'resident physician',
#  'representative phone',
#  'complete application',
#  'direct payment',
#  'fortunate company',
#  'low income',
#  'reliable company',
#  'primary banker',
#  'limited communication',
#  'great experience',
#  'excellent experience',
#  'straightforward application',
#  'easy document',
#  'good communication',
#  'whole process',
#  'personalized lending',
#  'best experience',
#  'grateful panacea',
#  'medical student',
#  'final year',
#  'personal loan',
#  'easy communication',
#  'friendly application',
#  'simple term',
#  'reasonable student',
#  'medical school',
#  'first year',
#  'low fund',
#  'medical profession',
#  'recommend panacea',
#  'write review',
#  'financial accident',
#  'personal loan',
#  'professional process',
#  'excellent communication',
#  'available time',
#  'mic drop',
#  'straightforward raquel',
#  'wonderful service',
#  'helpful working',
#  'easy process',
#  'fourth year',
#  'medical student',
#  'primary care',
#  'whole process',
#  'pleasant loan',
#  'primary care',
#  'technical difficulty',
#  'able solve',
#  'financial safety',
#  'net catch',
#  'great institution',
#  'quick service',
#  'whole process',
#  'full weekend',
#  'helpful assistance',
#  'primary care',
#  'excellent experience',
#  'excellent experience',
#  'excellent resource',
#  'personal loan',
#  'easy decision',
#  'precious company',
#  'crazy hour',
#  'late midnight',
#  'future banking',
#  'high interest',
#  'easy payment',
#  'primary care',
#  'many others',
#  'easy representative',
#  'friendly fund',
#  'whole process',
#  'courteous professional',
#  'multiple time',
#  'excellent service',
#  'personalized service',
#  'several lender',
#  'recommend friend',
#  'responsive opening',
#  'efficient kind',
#  'first generation',
#  'medical school',
#  'middle class',
#  'financial support',
#  'medical school',
#  'personal debt',
#  'awesome bank',
#  'financial group',
#  'amazing experience',
#  'first phone',
#  'professional kind',
#  'wonderful experience',
#  'pleased panacea',
#  'massive priority',
#  'financial project',
#  'thoughtful approach',
#  'expensive city',
#  'easy process',
#  'enough physician',
#  'similar situation',
#  'nice love',
#  'attentive customer',
#  'fast employee',
#  'great rate',
#  'easy underwriting',
#  'whole process',
#  'quick response',
#  'def work',
#  'super kind',
#  'residant prn',
#  'great process',
#  'complete pay',
#  'seamless banker',
#  'helpful concierge',
#  'well schedule',
#  'great experience',
#  'whole process',
#  'first time',
#  'excellent experience',
#  'private practice',
#  'personal loan',
#  'young physician',
#  'primary care',
#  'unusual circumstance',
#  'available email',
#  'easy banking',
#  'financial future',
#  'enough resident',
#  'major life',
#  'straightforward process',
#  'personal banker',
#  'available answer',
#  'personal loan',
#  'high interest',
#  'best decision',
#  'financial life',
#  'past year',
#  'medical school',
#  'financial transaction',
#  'reasonable banker',
#  'alex kugler',
#  'medium loan',
#  'great resource',
#  'financial need',
#  'easy use',
#  'easy work',
#  'able answer',
#  'fourth year',
#  'medical student',
#  'personable customer',
#  'smooth experience',
#  'grateful work',
#  'amazing people',
#  'great customer',
#  'simple paperwork',
#  'respectful lack',
#  'awesome loan',
#  'new account',
#  'unparalleled communication',
#  'online banking',
#  'personal loan',
#  'full fund',
#  'easy banker',
#  'amazing experience',
#  'primary banker',
#  'financial need',
#  'fast interest',
#  'great experience',
#  'primary care',
#  'best process',
#  'easy stress',
#  'great application',
#  'simple team',
#  'primary care',
#  'great texting',
#  'mean communication',
#  'many bank',
#  'hard time',
#  'financial aid',
#  'verifiable income',
#  'medical school',
#  'quick respond',
#  'easy need',
#  'wonderful experience',
#  'personal banker',
#  'smoother process',
#  'personal loan',
#  'complete residency',
#  'available question',
#  'financial service',
#  'best customer',
#  'whole process',
#  'utmost professionalism',
#  'quick respond',
#  'accessible phone',
#  'medical student',
#  'financial situation',
#  'skeptical system',
#  'catered position',
#  'financial burden',
#  'fourth year',
#  'grateful panacea',
#  'best interest',
#  'simple stress',
#  'free process',
#  'personal care',
#  'better loan',
#  'wonderful start',
#  'fast asset',
#  'professional nationwide',
#  'efficient experience',
#  'financial field',
#  'best consumer',
#  'little salary',
#  'highest interest',
#  'excellent customer',
#  'friendly employee',
#  'quick enroll',
#  'timely response',
#  'amazing rate',
#  'online minute',
#  'entire process',
#  'available account',
#  'excellent experience',
#  'helpful question',
#  'fast funding',
#  'second year',
#  'medical student',
#  'short coat',
#  'large bank',
#  'free transfer',
#  'main reason',
#  'large bank',
#  'amazing customer',
#  'main reason',
#  'quick answer',
#  'nationwide atm',
#  'first time',
#  'deceptive wording',
#  'online purchase',
#  'large bank',
#  'mobile app',
#  'basic thing',
#  'overall love',
#  'great accessory',
#  'fast contract',
#  'thankful care',
#  'tremendous credit',
#  'financial hardship',
#  'great interest',
#  'impossible find',
#  'back time',
#  'financial life',
#  'personal service',
#  'unparalleled experience',
#  'half hour',
#  'personal banker',
#  'small window',
#  'several email',
#  'personal email',
#  'electronic interest',
#  'financial breathing',
#  'little effort',
#  'communicative efficient',
#  'great experience',
#  'future need',
#  'seamless application',
#  'financial circumstance',
#  'stressful transition',
#  'efficient process',
#  'next step',
#  'stressful period',
#  'great experience',
#  'medical school',
#  'first credit',
#  'weary applying',
#  'certain company',
#  'healthier shape',
#  'right track',
#  'whole picture',
#  'back question',
#  'next step',
#  'helpful return',
#  'fellow resident',
#  'good employer',
#  'great appreciate',
#  'clear term',
#  'quick disbursement',
#  'fantastic organization',
#  'great customer',
#  'extra mile',
#  'easy access',
#  'primary banker',
#  'excellent experience',
#  'individual process',
#  'professional kind',
#  'willing help',
#  'extra fund',
#  'costly season',
#  'great work',
#  'great experience',
#  'alex assistance',
#  'great experience',
#  'objective attentive',
#  'resourceful research',
#  'good description',
#  'great experience',
#  'wonderful team',
#  'pushed thing',
#  'med school',
#  'best rate',
#  'possible debt',
#  'future business',
#  'financial institution',
#  'personal banker',
#  'absolute pleasure',
#  'entire team',
#  'able pay',
#  'simple loan',
#  'financial stress',
#  'first month',
#  'real time',
#  'entire loan',
#  'personal banker',
#  'great move',
#  'new state',
#  'minimum payment',
#  'friendly customer',
#  'personal loan',
#  'appropriate time',
#  'wonderful experience',
#  'quick kind',
#  'helpful service',
#  'personable staff',
#  'great experience',
#  'personal loan',
#  'primary care',
#  'supportive customer',
#  'complete residency',
#  'financial help',
#  'personal loan',
#  'due debt',
#  'entire process',
#  'transparent communication',
#  'personal phone',
#  'wonderful customer',
#  'pleasant work',
#  'easy breeze',
#  'able answer',
#  'amazing concept',
#  'able talk',
#  'financial package',
#  'excellent customer',
#  'predatory work',
#  'hard support',
#  'tough find',
#  'patient kind',
#  'medical field',
#  'efficient process',
#  'single complaint',
#  'real person',
#  'responsive work',
#  'odd hour',
#  'medical practice',
#  'right product',
#  'excellent customer',
#  'helpful guiding',
#  'approachable question',
#  'personal loan',
#  'complete application',
#  'continual outreach',
#  'general email',
#  'individual loan',
#  'great service',
#  'great service',
#  'transparent loan',
#  'nice work',
#  'financial institution',
#  'specific need',
#  'costumer service',
#  'regular job',
#  'representative company',
#  'lower loan',
#  'amazing think',
#  'timely delivery',
#  'amazing work',
#  'excellent customer',
#  'primary care',
#  'answered question',
#  'available time',
#  'right choice',
#  'little time',
#  'away parker',
#  'physical location',
#  'appreciated help',
#  'personal banker',
#  'available walk',
#  'best customer',
#  'whole transaction',
#  'ongoing relationship',
#  'resident physician',
#  'many classmate',
#  'awesome service',
#  'fast response',
#  'clear term',
#  'clear instruction',
#  'fast decision',
#  'better banking',
#  'financial hope',
#  'medical student',
#  'financial situation',
#  'medical student',
#  'financial need',
#  ...]

# %%
freq_count = {}
for key in all_keyword:
    if key in freq_count:
        freq_count[key] +=1
    else:
        freq_count[key] = 1

# %%
len(freq_count)
# Out:
# 773

# %%
freq_count
# Out:
# {'easy loan': 2,
#  'hidden fee': 2,
#  'amazing job': 2,
#  'professional customer': 1,
#  'medical school': 21,
#  'hectic schedule': 1,
#  'available time': 3,
#  'better clarity': 1,
#  'financial transaction': 2,
#  'slow process': 1,
#  'current balance': 1,
#  'long time': 2,
#  'welcome package': 1,
#  'postal mail': 1,
#  'last name': 1,
#  'closed account': 1,
#  'great life': 1,
#  'pleasant response': 1,
#  'wonderful answer': 1,
#  'faster parker': 1,
#  'professional offering': 1,
#  'entire process': 10,
#  'efficient service': 1,
#  'grateful help': 3,
#  'highest professionalism': 1,
#  'medical office': 1,
#  'high yield': 1,
#  'medical student': 30,
#  'amazed account': 1,
#  'online bank': 2,
#  'personal banker': 24,
#  'primary contact': 1,
#  'private student': 3,
#  'great option': 3,
#  'monthly payment': 5,
#  'better interest': 1,
#  'primary care': 24,
#  'recommend service': 1,
#  'private loan': 4,
#  'multiple loan': 1,
#  'lower interest': 2,
#  'best experience': 3,
#  'myriad company': 1,
#  'easy effortless': 1,
#  'excellent service': 5,
#  'medical field': 5,
#  'financial service': 3,
#  'early career': 2,
#  'easy hope': 1,
#  'good thing': 2,
#  'closed loan': 1,
#  'amazing customer': 5,
#  'great bank': 1,
#  'dental office': 1,
#  'polite people': 1,
#  'smoother process': 2,
#  'huge bank': 1,
#  'financial institution': 14,
#  'appropriate value': 1,
#  'online personable': 1,
#  'seamless experience': 2,
#  'wonderful work': 2,
#  'good experience': 4,
#  'timely manner': 4,
#  'financial support': 3,
#  'excellent communication': 3,
#  'unbeatable rate': 1,
#  'easy application': 4,
#  'thankful support': 1,
#  'easy banker': 2,
#  'helpful guide': 1,
#  'specific person': 1,
#  'much money': 1,
#  'able pay': 3,
#  'financial situation': 5,
#  'top stress': 1,
#  'first year': 4,
#  'financial burden': 4,
#  'new city': 1,
#  'financial advisor': 1,
#  'big bill': 1,
#  'marginal income': 1,
#  'amazing experience': 5,
#  'easy panacea': 1,
#  'new resident': 2,
#  'amazing product': 1,
#  'great interest': 4,
#  'financial track': 1,
#  'individual medicine': 1,
#  'financial risk': 1,
#  'inappropriate panacea': 1,
#  'recommend panacea': 3,
#  'quick seamless': 1,
#  'diligent interface': 1,
#  'timely completion': 1,
#  'smooth experience': 2,
#  'larger investment': 1,
#  'first time': 3,
#  'quick help': 1,
#  'financial need': 7,
#  'excellent experience': 12,
#  'best market': 1,
#  'great job': 2,
#  'recommend bank': 1,
#  'easy process': 6,
#  'grateful institution': 1,
#  'great customer': 9,
#  'pleasant one': 1,
#  'financial employee': 1,
#  'whole process': 21,
#  'financial help': 3,
#  'medical training': 1,
#  'easy work': 9,
#  'quick turnaround': 1,
#  'exceptional banker': 1,
#  'great rate': 2,
#  'hard credit': 2,
#  'quick disbursement': 2,
#  'high interest': 7,
#  'unexpected expense': 2,
#  'helpful loan': 1,
#  'prompt response': 2,
#  'enough answer': 1,
#  'positive experience': 1,
#  'financial credit': 1,
#  'medical education': 2,
#  'worried afford': 1,
#  'new state': 2,
#  'secure loan': 2,
#  'first conversation': 1,
#  'personal loan': 22,
#  'first job': 1,
#  'highest level': 1,
#  'professional service': 1,
#  'extra mile': 3,
#  'financial planner': 1,
#  'quick respond': 4,
#  'competitive transparency': 1,
#  'second none': 2,
#  'amazing service': 5,
#  'competitive rate': 3,
#  'responsive question': 2,
#  'great work': 4,
#  'shannon rest': 1,
#  'fantastic experience': 2,
#  'navigate website': 1,
#  'professional communication': 1,
#  'efficient work': 1,
#  'prompt respond': 1,
#  'available help': 2,
#  'best physician': 1,
#  'available market': 1,
#  'primary banker': 11,
#  'great experience': 26,
#  'true life': 1,
#  'saver intern': 1,
#  'helpful way': 1,
#  'financial providing': 1,
#  'financial portion': 1,
#  'smooth user': 1,
#  'extra money': 3,
#  'close construction': 1,
#  'efficient encounter': 1,
#  'great coordinating': 1,
#  'quick loan': 1,
#  'wonderful experience': 6,
#  'entire loan': 2,
#  'new panacea': 1,
#  'much panacea': 1,
#  'wonderful customer': 2,
#  'able help': 2,
#  'little week': 1,
#  'main coordinator': 1,
#  'able answer': 4,
#  'similar position': 1,
#  'excellent customer': 12,
#  'financial organization': 1,
#  'helpless credit': 1,
#  'fast day': 1,
#  'future loan': 2,
#  'professional need': 1,
#  'dental clinic': 1,
#  'couple week': 1,
#  'scheduled effort': 1,
#  'many lender': 1,
#  'easy apply': 1,
#  'awesome deal': 1,
#  'attentive need': 1,
#  'painless love': 1,
#  'financial struggle': 1,
#  'decent amount': 1,
#  'perfect fact': 1,
#  'spare income': 1,
#  'efficient process': 3,
#  'helpful process': 3,
#  'great communication': 1,
#  'hectic transition': 1,
#  'financial team': 3,
#  'fourth year': 5,
#  'extra fund': 3,
#  'best rate': 3,
#  'free banker': 1,
#  'happy answer': 1,
#  'complete fund': 1,
#  'real person': 3,
#  'large institution': 1,
#  'physical location': 2,
#  'able transaction': 1,
#  'long waiting': 1,
#  'normal daytime': 1,
#  'unique privilege': 1,
#  'amazing communication': 1,
#  'alex panacea': 1,
#  'outstanding communication': 1,
#  'reasonable rate': 1,
#  'important thing': 1,
#  'navigate time': 1,
#  'rich parent': 1,
#  'many loan': 1,
#  'regular bank': 1,
#  'first month': 2,
#  'prior banking': 1,
#  'helpful application': 1,
#  'dental school': 1,
#  'extra finance': 1,
#  'grateful panacea': 3,
#  'great correspondence': 1,
#  'excellent response': 1,
#  'first choice': 1,
#  'phenomenal experience': 1,
#  'professional training': 1,
#  'legitimate see': 1,
#  'online account': 1,
#  'couple hour': 1,
#  'speak phone': 1,
#  'frequent reminder': 1,
#  'primary account': 1,
#  'happy costumer': 1,
#  'easier email': 1,
#  'federal interest': 1,
#  'financial relief': 2,
#  'complete training': 1,
#  'dental practice': 2,
#  'entire time': 3,
#  'strict requirement': 1,
#  'fantastic banker': 1,
#  'hard help': 1,
#  'best option': 1,
#  'competitive interest': 1,
#  'fair interest': 2,
#  'great help': 1,
#  'friendly service': 1,
#  'long period': 1,
#  'incredible experience': 1,
#  'fantastic service': 1,
#  'best bank': 1,
#  'fresh training': 1,
#  'additional fund': 1,
#  'quick cash': 1,
#  'quick painless': 1,
#  'efficient manner': 1,
#  'happy experience': 1,
#  'professional staff': 1,
#  'efficient underwriting': 1,
#  'new product': 1,
#  'fantastic work': 1,
#  'honest application': 1,
#  'simple fund': 1,
#  'quick reply': 1,
#  'overall process': 1,
#  'wonderful deal': 1,
#  'happy service': 1,
#  'straightforward banker': 1,
#  'grateful company': 1,
#  'high student': 1,
#  'whole experience': 1,
#  'unparalleled customer': 1,
#  'incredible job': 1,
#  'attentive kind': 1,
#  'difficult time': 2,
#  'amazing raquel': 1,
#  'happier result': 1,
#  'satisfactory service': 1,
#  'helpful staff': 1,
#  'fast problem': 1,
#  'great partner': 1,
#  'initial deposit': 1,
#  'remarkable experience': 1,
#  'frantic cost': 1,
#  'many service': 1,
#  'secure fund': 1,
#  'extra loan': 1,
#  'worth peace': 1,
#  'happy decision': 1,
#  'fast headache': 1,
#  'free prn': 1,
#  'recommend trainee': 1,
#  'best trust': 1,
#  'much help': 1,
#  'multiple pre': 1,
#  'lowest interest': 1,
#  'longer term': 1,
#  'soft inquiry': 1,
#  'special shout': 1,
#  'alex kugler': 3,
#  'recommend others': 1,
#  'online experience': 1,
#  'true definition': 1,
#  'speedy turnover': 1,
#  'high card': 1,
#  'medical loan': 1,
#  'existent parker': 1,
#  'fair repayment': 1,
#  'better credit': 1,
#  'easy identity': 1,
#  'much peace': 1,
#  'new chapter': 1,
#  'higher income': 1,
#  'unable resident': 1,
#  'responsive loan': 1,
#  'timely response': 2,
#  'easy transaction': 2,
#  'professional interaction': 1,
#  'proffesional employee': 1,
#  'polite calm': 1,
#  'friendly staff': 3,
#  'great service': 5,
#  'nice customer': 1,
#  'amazing prompt': 1,
#  'excellent expedient': 1,
#  'fast quality': 1,
#  'sincere recommendation': 1,
#  'streamlined process': 1,
#  'medical doctor': 1,
#  'full time': 1,
#  'late payment': 2,
#  'red flag': 1,
#  'small mistake': 1,
#  'correct approve': 1,
#  'expensive book': 1,
#  'academic activity': 1,
#  'experian credit': 1,
#  'best way': 1,
#  'bad effect': 2,
#  'future credit': 1,
#  'entire debt': 1,
#  'advertisement panacea': 1,
#  'difficult way': 1,
#  'illogical reason': 1,
#  'many thanks': 1,
#  'usual keep': 1,
#  'great hope': 1,
#  'excellent trust': 1,
#  'nice bank': 1,
#  'quick love': 1,
#  'early interest': 1,
#  'financial security': 1,
#  'rare find': 1,
#  'good communication': 2,
#  'tedious process': 1,
#  'financial healthcare': 1,
#  'delightful experience': 1,
#  'nice change': 1,
#  'online bot': 1,
#  'relevant detail': 1,
#  'efficient keeping': 1,
#  'last month': 1,
#  'new place': 1,
#  'impressed professionalism': 1,
#  'responsive email': 1,
#  'personal banking': 1,
#  'personal touch': 1,
#  'single person': 1,
#  'quick communication': 1,
#  'happier attention': 1,
#  'last year': 1,
#  'cumbersome process': 1,
#  'best interest': 2,
#  'second time': 1,
#  'satisfied loan': 1,
#  'early payment': 1,
#  'technical difficulty': 2,
#  'third credit': 1,
#  'several point': 1,
#  'special opportunity': 1,
#  'crazy schedule': 1,
#  'first contact': 1,
#  'conducted process': 1,
#  'true thank': 1,
#  'open loan': 1,
#  'many month': 1,
#  'several hit': 1,
#  'large debt': 1,
#  'real deal': 1,
#  'financial instrument': 1,
#  'digital age': 1,
#  'professional student': 1,
#  'resident physician': 2,
#  'representative phone': 1,
#  'complete application': 2,
#  'direct payment': 1,
#  'fortunate company': 1,
#  'low income': 1,
#  'reliable company': 1,
#  'limited communication': 1,
#  'straightforward application': 1,
#  'easy document': 1,
#  'personalized lending': 1,
#  'final year': 1,
#  'easy communication': 1,
#  'friendly application': 1,
#  'simple term': 1,
#  'reasonable student': 1,
#  'low fund': 2,
#  'medical profession': 1,
#  'write review': 1,
#  'financial accident': 1,
#  'professional process': 1,
#  'mic drop': 1,
#  'straightforward raquel': 1,
#  'wonderful service': 1,
#  'helpful working': 1,
#  'pleasant loan': 1,
#  'able solve': 1,
#  'financial safety': 1,
#  'net catch': 1,
#  'great institution': 1,
#  'quick service': 1,
#  'full weekend': 1,
#  'helpful assistance': 1,
#  'excellent resource': 2,
#  'easy decision': 1,
#  'precious company': 1,
#  'crazy hour': 1,
#  'late midnight': 1,
#  'future banking': 1,
#  'easy payment': 1,
#  'many others': 1,
#  'easy representative': 1,
#  'friendly fund': 1,
#  'courteous professional': 1,
#  'multiple time': 1,
#  'personalized service': 1,
#  'several lender': 1,
#  'recommend friend': 1,
#  'responsive opening': 1,
#  'efficient kind': 1,
#  'first generation': 2,
#  'middle class': 1,
#  'personal debt': 1,
#  'awesome bank': 1,
#  'financial group': 1,
#  'first phone': 1,
#  'professional kind': 3,
#  'pleased panacea': 1,
#  'massive priority': 1,
#  'financial project': 1,
#  'thoughtful approach': 1,
#  'expensive city': 1,
#  'enough physician': 1,
#  'similar situation': 1,
#  'nice love': 1,
#  'attentive customer': 1,
#  'fast employee': 1,
#  'easy underwriting': 1,
#  'quick response': 2,
#  'def work': 1,
#  'super kind': 1,
#  'residant prn': 1,
#  'great process': 1,
#  'complete pay': 1,
#  'seamless banker': 1,
#  'helpful concierge': 1,
#  'well schedule': 1,
#  'private practice': 1,
#  'young physician': 1,
#  'unusual circumstance': 1,
#  'available email': 1,
#  'easy banking': 1,
#  'financial future': 1,
#  'enough resident': 1,
#  'major life': 1,
#  'straightforward process': 1,
#  'available answer': 1,
#  'best decision': 1,
#  'financial life': 2,
#  'past year': 1,
#  'reasonable banker': 1,
#  'medium loan': 1,
#  'great resource': 1,
#  'easy use': 2,
#  'personable customer': 1,
#  'grateful work': 1,
#  'amazing people': 1,
#  'simple paperwork': 1,
#  'respectful lack': 1,
#  'awesome loan': 1,
#  'new account': 3,
#  'unparalleled communication': 1,
#  'online banking': 2,
#  'full fund': 1,
#  'fast interest': 1,
#  'best process': 1,
#  'easy stress': 1,
#  'great application': 1,
#  'simple team': 1,
#  'great texting': 1,
#  'mean communication': 1,
#  'many bank': 1,
#  'hard time': 1,
#  'financial aid': 1,
#  'verifiable income': 1,
#  'easy need': 1,
#  'complete residency': 2,
#  'available question': 4,
#  'best customer': 3,
#  'utmost professionalism': 1,
#  'accessible phone': 2,
#  'skeptical system': 1,
#  'catered position': 1,
#  'simple stress': 1,
#  'free process': 1,
#  'personal care': 1,
#  'better loan': 1,
#  'wonderful start': 1,
#  'fast asset': 1,
#  'professional nationwide': 1,
#  'efficient experience': 1,
#  'financial field': 1,
#  'best consumer': 1,
#  'little salary': 1,
#  'highest interest': 1,
#  'friendly employee': 1,
#  'quick enroll': 1,
#  'amazing rate': 1,
#  'online minute': 1,
#  'available account': 1,
#  'helpful question': 1,
#  'fast funding': 1,
#  'second year': 1,
#  'short coat': 1,
#  'large bank': 3,
#  'free transfer': 1,
#  'main reason': 2,
#  'quick answer': 1,
#  'nationwide atm': 1,
#  'deceptive wording': 1,
#  'online purchase': 1,
#  'mobile app': 1,
#  'basic thing': 1,
#  'overall love': 1,
#  'great accessory': 1,
#  'fast contract': 1,
#  'thankful care': 1,
#  'tremendous credit': 1,
#  'financial hardship': 1,
#  'impossible find': 1,
#  'back time': 1,
#  'personal service': 1,
#  'unparalleled experience': 1,
#  'half hour': 1,
#  'small window': 1,
#  'several email': 1,
#  'personal email': 1,
#  'electronic interest': 1,
#  'financial breathing': 1,
#  'little effort': 1,
#  'communicative efficient': 1,
#  'future need': 1,
#  'seamless application': 1,
#  'financial circumstance': 2,
#  'stressful transition': 1,
#  'next step': 2,
#  'stressful period': 1,
#  'first credit': 1,
#  'weary applying': 1,
#  'certain company': 1,
#  'healthier shape': 1,
#  'right track': 1,
#  'whole picture': 1,
#  'back question': 1,
#  'helpful return': 1,
#  'fellow resident': 1,
#  'good employer': 1,
#  'great appreciate': 1,
#  'clear term': 2,
#  'fantastic organization': 1,
#  'easy access': 1,
#  'individual process': 1,
#  'willing help': 1,
#  'costly season': 1,
#  'alex assistance': 1,
#  'objective attentive': 1,
#  'resourceful research': 1,
#  'good description': 1,
#  'wonderful team': 1,
#  'pushed thing': 1,
#  'med school': 1,
#  'possible debt': 1,
#  'future business': 1,
#  'absolute pleasure': 1,
#  'entire team': 2,
#  'simple loan': 1,
#  'financial stress': 1,
#  'real time': 1,
#  'great move': 1,
#  'minimum payment': 1,
#  'friendly customer': 1,
#  'appropriate time': 1,
#  'quick kind': 1,
#  'helpful service': 2,
#  'personable staff': 1,
#  'supportive customer': 1,
#  'due debt': 1,
#  'transparent communication': 2,
#  'personal phone': 1,
#  'pleasant work': 1,
#  'easy breeze': 1,
#  'amazing concept': 1,
#  'able talk': 1,
#  'financial package': 1,
#  'predatory work': 1,
#  'hard support': 1,
#  'tough find': 1,
#  'patient kind': 1,
#  'single complaint': 1,
#  'responsive work': 1,
#  'odd hour': 1,
#  'medical practice': 1,
#  'right product': 1,
#  'helpful guiding': 1,
#  'approachable question': 1,
#  'continual outreach': 1,
#  'general email': 1,
#  'individual loan': 1,
#  'transparent loan': 1,
#  'nice work': 1,
#  'specific need': 1,
#  'costumer service': 1,
#  'regular job': 1,
#  'representative company': 1,
#  'lower loan': 1,
#  'amazing think': 1,
#  'timely delivery': 1,
#  'amazing work': 2,
#  'answered question': 2,
#  'right choice': 1,
#  'little time': 1,
#  'away parker': 1,
#  'appreciated help': 1,
#  'available walk': 1,
#  'whole transaction': 1,
#  'ongoing relationship': 1,
#  'many classmate': 1,
#  'awesome service': 1,
#  'fast response': 1,
#  'clear instruction': 1,
#  'fast decision': 1,
#  'better banking': 1,
#  'financial hope': 1,
#  'impressed product': 1,
#  'med student': 4,
#  'right way': 1,
#  'fast guiding': 1,
#  'best loan': 1,
#  'close credit': 1,
#  'timely service': 1,
#  'top notch': 1,
#  'resident loan': 1,
#  'grateful opportunity': 1,
#  'incredible company': 1,
#  'personal detail': 1,
#  'prior residency': 1,
#  'pleasant straightforward': 1,
#  'first proceed': 1,
#  'huge lifesaver': 1,
#  'focused customer': 1,
#  'costly time': 1,
#  'large school': 1,
#  'lifelong customer': 1,
#  'much frustration': 1,
#  'enough disbursement': 1,
#  'recommend use': 1,
#  'financial customer': 1,
#  'future panacea': 1,
#  'medical trainee': 1,
#  'new residency': 1,
#  'awesome experience': 1,
#  'electronic course': 1,
#  'financial stability': 1,
#  'next year': 1,
#  'appropriate reminder': 1,
#  'longer schedule': 1,
#  'easy end': 1,
#  'big thanks': 1,
#  'minor snag': 1,
#  'quick hassle': 1,
#  'middle icu': 1,
#  'dedicate time': 1,
#  'financial process': 1,
#  'whole team': 1,
#  'recommend option': 1,
#  'easiest loan': 1,
#  'little documentation': 1,
#  'multiple bank': 1,
#  'ridiculous option': 1,
#  'personal experience': 1,
#  'generous lender': 1,
#  'friendly spot': 1,
#  'wonderful gentleman': 1,
#  'reputable institution': 1,
#  'new service': 1,
#  'reputable company': 1,
#  'exceptional customer': 1,
#  'efficient response': 1,
#  'online chat': 1,
#  'smooth process': 1,
#  'difficult prn': 1,
#  'fantastic customer': 1,
#  'simple product': 1,
#  'financial consideration': 1,
#  'low risk': 1,
#  'comparable panacea': 1,
#  'happier website': 1,
#  'exceptional service': 1,
#  'busy schedule': 1,
#  'personal fund': 1,
#  'professional way': 1,
#  'easy swag': 1,
#  'awesome bonus': 1,
#  'financial application': 1,
#  'soft credit': 1,
#  'brilliant fact': 1,
#  'future earnings': 1,
#  'standard credit': 1,
#  'able sign': 1,
#  'early afternoon': 1,
#  'informed fund': 1,
#  'next business': 1,
#  'little hour': 1,
#  'busy nd': 1,
#  'able call': 1,
#  'courteous service': 1,
#  'enough update': 1,
#  'last minute': 1,
#  'new checking': 2,
#  'excellent rate': 1,
#  'recommend company': 1,
#  'medical resident': 1,
#  'large amount': 1,
#  'future income': 1,
#  'potential account': 1,
#  'better lender': 1,
#  'online interface': 1,
#  'joined family': 1,
#  'available responds': 1,
#  'important feel': 1,
#  'easy set': 1,
#  'low maintenance': 1,
#  'decent interest': 1,
#  'much ease': 1,
#  'incredible clarity': 1,
#  'sure question': 1,
#  'actual account': 1,
#  'free checking': 1,
#  'financial product': 1,
#  'happier bank': 1,
#  'simple knowledge': 1,
#  'personalized contact': 1,
#  'great banking': 1,
#  'human call': 1,
#  'robust ability': 1,
#  'different bank': 1}

# %%
unique_keywords = freq_count.keys()
unique_keywords
# Out:
# dict_keys(['easy loan', 'hidden fee', 'amazing job', 'professional customer', 'medical school', 'hectic schedule', 'available time', 'better clarity', 'financial transaction', 'slow process', 'current balance', 'long time', 'welcome package', 'postal mail', 'last name', 'closed account', 'great life', 'pleasant response', 'wonderful answer', 'faster parker', 'professional offering', 'entire process', 'efficient service', 'grateful help', 'highest professionalism', 'medical office', 'high yield', 'medical student', 'amazed account', 'online bank', 'personal banker', 'primary contact', 'private student', 'great option', 'monthly payment', 'better interest', 'primary care', 'recommend service', 'private loan', 'multiple loan', 'lower interest', 'best experience', 'myriad company', 'easy effortless', 'excellent service', 'medical field', 'financial service', 'early career', 'easy hope', 'good thing', 'closed loan', 'amazing customer', 'great bank', 'dental office', 'polite people', 'smoother process', 'huge bank', 'financial institution', 'appropriate value', 'online personable', 'seamless experience', 'wonderful work', 'good experience', 'timely manner', 'financial support', 'excellent communication', 'unbeatable rate', 'easy application', 'thankful support', 'easy banker', 'helpful guide', 'specific person', 'much money', 'able pay', 'financial situation', 'top stress', 'first year', 'financial burden', 'new city', 'financial advisor', 'big bill', 'marginal income', 'amazing experience', 'easy panacea', 'new resident', 'amazing product', 'great interest', 'financial track', 'individual medicine', 'financial risk', 'inappropriate panacea', 'recommend panacea', 'quick seamless', 'diligent interface', 'timely completion', 'smooth experience', 'larger investment', 'first time', 'quick help', 'financial need', 'excellent experience', 'best market', 'great job', 'recommend bank', 'easy process', 'grateful institution', 'great customer', 'pleasant one', 'financial employee', 'whole process', 'financial help', 'medical training', 'easy work', 'quick turnaround', 'exceptional banker', 'great rate', 'hard credit', 'quick disbursement', 'high interest', 'unexpected expense', 'helpful loan', 'prompt response', 'enough answer', 'positive experience', 'financial credit', 'medical education', 'worried afford', 'new state', 'secure loan', 'first conversation', 'personal loan', 'first job', 'highest level', 'professional service', 'extra mile', 'financial planner', 'quick respond', 'competitive transparency', 'second none', 'amazing service', 'competitive rate', 'responsive question', 'great work', 'shannon rest', 'fantastic experience', 'navigate website', 'professional communication', 'efficient work', 'prompt respond', 'available help', 'best physician', 'available market', 'primary banker', 'great experience', 'true life', 'saver intern', 'helpful way', 'financial providing', 'financial portion', 'smooth user', 'extra money', 'close construction', 'efficient encounter', 'great coordinating', 'quick loan', 'wonderful experience', 'entire loan', 'new panacea', 'much panacea', 'wonderful customer', 'able help', 'little week', 'main coordinator', 'able answer', 'similar position', 'excellent customer', 'financial organization', 'helpless credit', 'fast day', 'future loan', 'professional need', 'dental clinic', 'couple week', 'scheduled effort', 'many lender', 'easy apply', 'awesome deal', 'attentive need', 'painless love', 'financial struggle', 'decent amount', 'perfect fact', 'spare income', 'efficient process', 'helpful process', 'great communication', 'hectic transition', 'financial team', 'fourth year', 'extra fund', 'best rate', 'free banker', 'happy answer', 'complete fund', 'real person', 'large institution', 'physical location', 'able transaction', 'long waiting', 'normal daytime', 'unique privilege', 'amazing communication', 'alex panacea', 'outstanding communication', 'reasonable rate', 'important thing', 'navigate time', 'rich parent' ...

# %%
clustures = []

used_keywords = []

for i in tqdm(unique_keywords):
    current_custer = [i]
    
    if (i in used_keywords):
        continue
    
    used_keywords.append(i)
    
    
    for j in unique_keywords:
        if  (j in used_keywords):
            continue
    
        current_score = similarity_calc(i,j)
        if current_score>0.7:
            current_custer.append(j)
            used_keywords.append(j)
            
    
    clustures.append(current_custer)
        
#     break
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 773/773 [31:27<00:00,  2.44s/it]

# %%
len(clustures)
# Out:
# 358

# %%
clustures[:10]
# Out:
# [['easy loan',
#   'private loan',
#   'helpful loan',
#   'personal loan',
#   'quick loan',
#   'entire loan',
#   'future loan',
#   'many loan',
#   'extra loan',
#   'responsive loan',
#   'satisfied loan',
#   'open loan',
#   'pleasant loan',
#   'easy banking',
#   'medium loan',
#   'awesome loan',
#   'better loan',
#   'simple loan',
#   'individual loan',
#   'transparent loan',
#   'lower loan',
#   'best loan',
#   'easiest loan'],
#  ['hidden fee', 'unexpected expense'],
#  ['amazing job',
#   'wonderful work',
#   'amazing experience',
#   'excellent experience',
#   'great job',
#   'amazing service',
#   'great work',
#   'great experience',
#   'incredible experience',
#   'fantastic work',
#   'incredible job',
#   'remarkable experience',
#   'great process',
#   'pleasant work',
#   'nice work',
#   'amazing work',
#   'awesome experience',
#   'brilliant fact'],
#  ['professional customer',
#   'professional offering',
#   'amazing customer',
#   'great customer',
#   'professional service',
#   'wonderful customer',
#   'excellent customer',
#   'proffesional employee',
#   'nice customer',
#   'courteous professional',
#   'personable customer',
#   'friendly customer',
#   'supportive customer',
#   'lifelong customer',
#   'exceptional customer'],
#  ['medical school',
#   'medical office',
#   'medical student',
#   'medical field',
#   'medical training',
#   'medical education',
#   'medical doctor',
#   'medical profession',
#   'young physician',
#   'med school',
#   'medical practice',
#   'medical trainee'],
#  ['hectic schedule',
#   'hectic transition',
#   'crazy schedule',
#   'well schedule',
#   'longer schedule',
#   'busy schedule'],
#  ['available time',
#   'navigate time',
#   'appropriate time',
#   'little time',
#   'dedicate time'],
#  ['better clarity', 'incredible clarity'],
#  ['financial transaction',
#   'financial service',
#   'financial situation',
#   'financial track',
#   'financial help',
#   'financial credit',
#   'financial providing',
#   'financial portion',
#   'financial organization',
#   'financial struggle',
#   'able transaction',
#   'personal banking',
#   'financial instrument',
#   'financial group',
#   'financial project',
#   'financial field',
#   'financial circumstance',
#   'whole transaction',
#   'financial customer',
#   'financial process',
#   'financial consideration',
#   'financial application',
#   'financial product'],
#  ['slow process',
#   'smoother process',
#   'efficient process',
#   'fast problem',
#   'streamlined process',
#   'tedious process',
#   'smooth process']]

# %%
final_result = []
for cp in clustures:
    cluster_key_count = {}
    for key_c in cp:
        cluster_key_count[key_c] = freq_count[key_c]
    
    items = []
    for i in list(tuple(cluster_key_count.keys())):
        items.append(i.split()[0])
    dict1 = {}
    for item in items:
        if not item in dict1:
            dict1[item] = items.count(item)
    dict1 = sorted(dict1.keys(), reverse=True)[0]

    curr_cul_keys = list(cluster_key_count.keys())
    curr_cul_values = list(cluster_key_count.values())
    sum_of_similar_words = np.sum(curr_cul_values)
    highest_count_key = curr_cul_keys[np.argmax(curr_cul_values)]
    highest_count_value = np.max(curr_cul_values)
    final_result.append([cluster_key_count,sum_of_similar_words,highest_count_key,len(cluster_key_count), dict1])
    
#     break

# %%
final_result
# Out:
# [[{'easy loan': 2,
#    'private loan': 4,
#    'helpful loan': 1,
#    'personal loan': 22,
#    'quick loan': 1,
#    'entire loan': 2,
#    'future loan': 2,
#    'many loan': 1,
#    'extra loan': 1,
#    'responsive loan': 1,
#    'satisfied loan': 1,
#    'open loan': 1,
#    'pleasant loan': 1,
#    'easy banking': 1,
#    'medium loan': 1,
#    'awesome loan': 1,
#    'better loan': 1,
#    'simple loan': 1,
#    'individual loan': 1,
#    'transparent loan': 1,
#    'lower loan': 1,
#    'best loan': 1,
#    'easiest loan': 1},
#   50,
#   'personal loan',
#   23,
#   'transparent'],
#  [{'hidden fee': 2, 'unexpected expense': 2},
#   4,
#   'hidden fee',
#   2,
#   'unexpected'],
#  [{'amazing job': 2,
#    'wonderful work': 2,
#    'amazing experience': 5,
#    'excellent experience': 12,
#    'great job': 2,
#    'amazing service': 5,
#    'great work': 4,
#    'great experience': 26,
#    'incredible experience': 1,
#    'fantastic work': 1,
#    'incredible job': 1,
#    'remarkable experience': 1,
#    'great process': 1,
#    'pleasant work': 1,
#    'nice work': 1,
#    'amazing work': 2,
#    'awesome experience': 1,
#    'brilliant fact': 1},
#   69,
#   'great experience',
#   18,
#   'wonderful'],
#  [{'professional customer': 1,
#    'professional offering': 1,
#    'amazing customer': 5,
#    'great customer': 9,
#    'professional service': 1,
#    'wonderful customer': 2,
#    'excellent customer': 12,
#    'proffesional employee': 1,
#    'nice customer': 1,
#    'courteous professional': 1,
#    'personable customer': 1,
#    'friendly customer': 1,
#    'supportive customer': 1,
#    'lifelong customer': 1,
#    'exceptional customer': 1},
#   39,
#   'excellent customer',
#   15,
#   'wonderful'],
#  [{'medical school': 21,
#    'medical office': 1,
#    'medical student': 30,
#    'medical field': 5,
#    'medical training': 1,
#    'medical education': 2,
#    'medical doctor': 1,
#    'medical profession': 1,
#    'young physician': 1,
#    'med school': 1,
#    'medical practice': 1,
#    'medical trainee': 1},
#   66,
#   'medical student',
#   12,
#   'young'],
#  [{'hectic schedule': 1,
#    'hectic transition': 1,
#    'crazy schedule': 1,
#    'well schedule': 1,
#    'longer schedule': 1,
#    'busy schedule': 1},
#   6,
#   'hectic schedule',
#   6,
#   'well'],
#  [{'available time': 3,
#    'navigate time': 1,
#    'appropriate time': 1,
#    'little time': 1,
#    'dedicate time': 1},
#   7,
#   'available time',
#   5,
#   'navigate'],
#  [{'better clarity': 1, 'incredible clarity': 1},
#   2,
#   'better clarity',
#   2,
#   'incredible'],
#  [{'financial transaction': 2,
#    'financial service': 3,
#    'financial situation': 5,
#    'financial track': 1,
#    'financial help': 3,
#    'financial credit': 1,
#    'financial providing': 1,
#    'financial portion': 1,
#    'financial organization': 1,
#    'financial struggle': 1,
#    'able transaction': 1,
#    'personal banking': 1,
#    'financial instrument': 1,
#    'financial group': 1,
#    'financial project': 1,
#    'financial field': 1,
#    'financial circumstance': 2,
#    'whole transaction': 1,
#    'financial customer': 1,
#    'financial process': 1,
#    'financial consideration': 1,
#    'financial application': 1,
#    'financial product': 1},
#   33,
#   'financial situation',
#   23,
#   'whole'],
#  [{'slow process': 1,
#    'smoother process': 2,
#    'efficient process': 3,
#    'fast problem': 1,
#    'streamlined process': 1,
#    'tedious process': 1,
#    'smooth process': 1},
#   10,
#   'efficient process',
#   7,
#   'tedious'],
#  [{'current balance': 1}, 1, 'current balance', 1, 'current'],
#  [{'long time': 2, 'long waiting': 1, 'long period': 1, 'longer term': 1},
#   5,
#   'long time',
#   4,
#   'longer'],
#  [{'welcome package': 1}, 1, 'welcome package', 1, 'welcome'],
#  [{'postal mail': 1,
#    'responsive email': 1,
#    'available email': 1,
#    'personal email': 1,
#    'general email': 1},
#   5,
#   'postal mail',
#   5,
#   'responsive'],
#  [{'last name': 1}, 1, 'last name', 1, 'last'],
#  [{'closed account': 1}, 1, 'closed account', 1, 'closed'],
#  [{'great life': 1, 'true life': 1, 'major life': 1},
#   3,
#   'great life',
#   3,
#   'true'],
#  [{'pleasant response': 1,
#    'good thing': 2,
#    'pleasant one': 1,
#    'happy answer': 1,
#    'excellent response': 1,
#    'quick reply': 1,
#    'happier result': 1,
#    'true thank': 1,
#    'great appreciate': 1,
#    'pleasant straightforward': 1},
#   11,
#   'good thing',
#   10,
#   'true'],
#  [{'wonderful answer': 1,
#    'perfect fact': 1,
#    'wonderful deal': 1,
#    'amazing concept': 1},
#   4,
#   'wonderful answer',
#   4,
#   'wonderful'],
#  [{'faster parker': 1, 'existent parker': 1}, 2, 'faster parker', 2, 'faster'],
#  [{'entire process': 10,
#    'easy process': 6,
#    'whole process': 21,
#    'overall process': 1,
#    'conducted process': 1,
#    'straightforward process': 1,
#    'best process': 1,
#    'individual process': 1},
#   42,
#   'whole process',
#   8,
#   'whole'],
#  [{'efficient service': 1,
#    'excellent service': 5,
#    'fantastic service': 1,
#    'efficient manner': 1,
#    'satisfactory service': 1,
#    'many service': 1,
#    'great service': 5,
#    'wonderful service': 1,
#    'quick service': 1,
#    'efficient experience': 1,
#    'helpful service': 2,
#    'awesome service': 1,
#    'timely service': 1,
#    'exceptional service': 1},
#   23,
#   'excellent service',
#   14,
#   'wonderful'],
#  [{'grateful help': 3,
#    'thankful support': 1,
#    'grateful institution': 1,
#    'helpful way': 1,
#    'great help': 1,
#    'grateful company': 1,
#    'many thanks': 1,
#    'helpful assistance': 1,
#    'grateful work': 1,
#    'thankful care': 1,
#    'willing help': 1,
#    'appreciated help': 1,
#    'grateful opportunity': 1,
#    'big thanks': 1},
#   16,
#   'grateful help',
#   14,
#   'willing'],
#  [{'highest professionalism': 1,
#    'impressed professionalism': 1,
#    'professional kind': 3,
#    'utmost professionalism': 1},
#   6,
#   'professional kind',
#   4,
#   'utmost'],
#  [{'high yield': 1}, 1, 'high yield', 1, 'high'],
#  [{'amazed account': 1}, 1, 'amazed account', 1, 'amazed'],
#  [{'online bank': 2,
#    'great bank': 1,
#    'recommend bank': 1,
#    'regular bank': 1,
#    'online account': 1,
#    'nice bank': 1,
#    'awesome bank': 1,
#    'online banking': 2,
#    'many bank': 1,
#    'different bank': 1},
#   12,
#   'online bank',
#   10,
#   'regular'],
#  [{'personal banker': 24,
#    'easy banker': 2,
#    'exceptional banker': 1,
#    'primary banker': 11,
#    'free banker': 1,
#    'fantastic banker': 1,
#    'straightforward banker': 1,
#    'seamless banker': 1,
#    'reasonable banker': 1,
#    'great banking': 1},
#   44,
#   'personal banker',
#   10,
#   'straightforward'],
#  [{'primary contact': 1, 'first contact': 1},
#   2,
#   'primary contact',
#   2,
#   'primary'],
#  [{'private student': 3}, 3, 'private student', 1, 'private'],
#  [{'great option': 3,
#    'best option': 1,
#    'best decision': 1,
#    'recommend option': 1},
#   6,
#   'great option',
#   4,
#   'recommend'],
#  [{'monthly payment': 5,
#    'able pay': 3,
#    'early payment': 1,
#    'direct payment': 1,
#    'easy payment': 1,
#    'minimum payment': 1},
#   12,
#   'monthly payment',
#   6,
#   'monthly'],
#  [{'better interest': 1,
#    'great interest': 4,
#    'high interest': 7,
#    'best interest': 2,
#    'highest interest': 1,
#    'decent interest': 1},
#   16,
#   'high interest',
#   6,
#   'highest'],
#  [{'primary care': 24, 'personal care': 1}, 25, 'primary care', 2, 'primary'],
#  [{'recommend service': 1,
#    'friendly service': 1,
#    'recommend others': 1,
#    'recommend company': 1},
#   4,
#   'recommend service',
#   4,
#   'recommend'],
#  [{'multiple loan': 1, 'multiple bank': 1}, 2, 'multiple loan', 2, 'multiple'],
#  [{'lower interest': 2, 'lowest interest': 1, 'low fund': 2},
#   5,
#   'lower interest',
#   3,
#   'lowest'],
#  [{'best experience': 3,
#    'seamless experience': 2,
#    'good experience': 4,
#    'fantastic experience': 2,
#    'wonderful experience': 6,
#    'whole experience': 1,
#    'delightful experience': 1,
#    'unparalleled experience': 1,
#    'personal experience': 1},
#   21,
#   'wonderful experience',
#   9,
#   'wonderful'],
#  [{'myriad company': 1, 'certain company': 1},
#   2,
#   'myriad company',
#   2,
#   'myriad'],
#  [{'easy effortless': 1, 'easy work': 9, 'easy apply': 1, 'little effort': 1},
#   12,
#   'easy work',
#   4,
#   'little'],
#  [{'early career': 2, 'first job': 1}, 3, 'early career', 2, 'first'],
#  [{'easy hope': 1, 'great hope': 1}, 2, 'easy hope', 2, 'great'],
#  [{'closed loan': 1, 'close credit': 1}, 2, 'closed loan', 2, 'closed'],
#  [{'dental office': 1,
#    'dental clinic': 1,
#    'dental school': 1,
#    'dental practice': 2},
#   5,
#   'dental practice',
#   4,
#   'dental'],
#  [{'polite people': 1, 'polite calm': 1, 'courteous service': 1},
#   3,
#   'polite people',
#   3,
#   'polite'],
#  [{'huge bank': 1, 'best bank': 1, 'large bank': 3},
#   5,
#   'large bank',
#   3,
#   'large'],
#  [{'financial institution': 14,
#    'financial advisor': 1,
#    'financial employee': 1,
#    'financial planner': 1,
#    'financial team': 3,
#    'financial security': 1,
#    'financial healthcare': 1},
#   22,
#   'financial institution',
#   7,
#   'financial'],
#  [{'appropriate value': 1, 'decent amount': 1},
#   2,
#   'appropriate value',
#   2,
#   'decent'],
#  [{'online personable': 1, 'online experience': 1},
#   2,
#   'online personable',
#   2,
#   'online'],
#  [{'timely manner': 4,
#    'timely completion': 1,
#    'timely response': 2,
#    'timely delivery': 1},
#   8,
#   'timely manner',
#   4,
#   'timely'],
#  [{'financial support': 3,
#    'financial burden': 4,
#    'financial need': 7,
#    'financial relief': 2,
#    'financial aid': 1,
#    'financial hardship': 1,
#    'financial hope': 1},
#   19,
#   'financial need',
#   7,
#   'financial'],
#  [{'excellent communication': 3,
#    'professional communication': 1,
#    'great communication': 1,
#    'amazing communication': 1,
#    'outstanding communication': 1,
#    'good communication': 2,
#    'quick communication': 1,
#    'easy communication': 1,
#    'unparalleled communication': 1,
#    'mean communication': 1,
#    'communicative efficient': 1},
#   14,
#   'excellent communication',
#   11,
#   'unparalleled'],
#  [{'unbeatable rate': 1,
#    'great rate': 2,
#    'reasonable rate': 1,
#    'amazing rate': 1,
#    'excellent rate': 1},
#   6,
#   'great rate',
#   5,
#   'unbeatable'],
#  [{'easy application': 4,
#    'helpful application': 1,
#    'complete application': 2,
#    'straightforward application': 1,
#    'friendly application': 1,
#    'easy use': 2,
#    'great application': 1,
#    'seamless application': 1,
#    'easy access': 1},
#   14,
#   'easy application',
#   9,
#   'straightforward'],
#  [{'helpful guide': 1,
#    'available help': 2,
#    'helpful process': 3,
#    'helpful working': 1,
#    'helpful guiding': 1},
#   8,
#   'helpful process',
#   5,
#   'helpful'],
#  [{'specific person': 1}, 1, 'specific person', 1, 'specific'],
#  [{'much money': 1, 'extra money': 3, 'costly time': 1, 'large amount': 1},
#   6,
#   'extra money',
#   4,
#   'much'],
#  [{'top stress': 1,
#    'easy stress': 1,
#    'simple stress': 1,
#    'stressful period': 1},
#   4,
#   'top stress',
#   4,
#   'top'],
#  [{'first year': 4, 'first month': 2, 'past year': 1},
#   7,
#   'first year',
#   3,
#   'past'],
#  [{'new city': 1, 'new place': 1}, 2, 'new city', 2, 'new'],
#  [{'big bill': 1}, 1, 'big bill', 1, 'big'],
#  [{'marginal income': 1, 'spare income': 1, 'verifiable income': 1},
#   3,
#   'marginal income',
#   3,
#   'verifiable'],
#  [{'easy panacea': 1,
#    'recommend panacea': 3,
#    'new panacea': 1,
#    'much panacea': 1,
#    'grateful panacea': 3,
#    'pleased panacea': 1,
#    'future panacea': 1,
#    'comparable panacea': 1},
#   12,
#   'recommend panacea',
#   8,
#   'recommend'],
#  [{'new resident': 2,
#    'unable resident': 1,
#    'enough resident': 1,
#    'fellow resident': 1,
#    'new residency': 1},
#   6,
#   'new resident',
#   5,
#   'unable'],
#  [{'amazing product': 1,
#    'new product': 1,
#    'right product': 1,
#    'impressed product': 1,
#    'incredible company': 1},
#   5,
#   'amazing product',
#   5,
#   'right'],
#  [{'individual medicine': 1}, 1, 'individual medicine', 1, 'individual'],
#  [{'financial risk': 1,
#    'financial safety': 1,
#    'financial stress': 1,
#    'low risk': 1},
#   4,
#   'financial risk',
#   4,
#   'low'],
#  [{'inappropriate panacea': 1},
#   1,
#   'inappropriate panacea',
#   1,
#   'inappropriate'],
#  [{'quick seamless': 1, 'quick help': 1, 'quick hassle': 1},
#   3,
#   'quick seamless',
#   3,
#   'quick'],
#  [{'diligent interface': 1}, 1, 'diligent interface', 1, 'diligent'],
#  [{'smooth experience': 2, 'much ease': 1},
#   3,
#   'smooth experience',
#   2,
#   'smooth'],
#  [{'larger investment': 1}, 1, 'larger investment', 1, 'larger'],
#  [{'first time': 3}, 3, 'first time', 1, 'first'],
#  [{'best market': 1,
#    'available market': 1,
#    'best customer': 3,
#    'best consumer': 1},
#   6,
#   'best customer',
#   4,
#   'best'],
#  [{'quick turnaround': 1}, 1, 'quick turnaround', 1, 'quick'],
#  [{'hard credit': 2,
#    'helpless credit': 1,
#    'better credit': 1,
#    'future credit': 1,
#    'third credit': 1,
#    'tremendous credit': 1,
#    'first credit': 1,
#    'soft credit': 1,
#    'standard credit': 1},
#   10,
#   'hard credit',
#   9,
#   'tremendous'],
#  [{'quick disbursement': 2, 'enough disbursement': 1},
#   3,
#   'quick disbursement',
#   2,
#   'quick'],
#  [{'prompt response': 2,
#    'quick respond': 4,
#    'prompt respond': 1,
#    'quick response': 2,
#    'available responds': 1},
#   10,
#   'quick respond',
#   5,
#   'quick'],
#  [{'enough answer': 1}, 1, 'enough answer', 1, 'enough'],
#  [{'positive experience': 1, 'happy experience': 1},
#   2,
#   'positive experience',
#   2,
#   'positive'],
#  [{'worried afford': 1}, 1, 'worried afford', 1, 'worried'],
#  [{'new state': 2}, 2, 'new state', 1, 'new'],
#  [{'secure loan': 2, 'secure fund': 1}, 3, 'secure loan', 2, 'secure'],
#  [{'first conversation': 1}, 1, 'first conversation', 1, 'first'],
#  [{'highest level': 1}, 1, 'highest level', 1, 'highest'],
#  [{'extra mile': 3}, 3, 'extra mile', 1, 'extra'],
#  [{'competitive transparency': 1},
#   1,
#   'competitive transparency',
#   1,
#   'competitive'],
#  [{'second none': 2}, 2, 'second none', 1, 'second'],
#  [{'competitive rate': 3, 'competitive interest': 1},
#   4,
#   'competitive rate',
#   2,
#   'competitive'],
#  [{'responsive question': 2, 'responsive work': 1},
#   3,
#   'responsive question',
#   2,
#   'responsive'],
#  [{'shannon rest': 1}, 1, 'shannon rest', 1, 'shannon'],
#  [{'navigate website': 1}, 1, 'navigate website', 1, 'navigate'],
#  [{'efficient work': 1}, 1, 'efficient work', 1, 'efficient'],
#  [{'best physician': 1, 'resident physician': 2},
#   3,
#   'resident physician',
#   2,
#   'resident'],
#  [{'saver intern': 1}, 1, 'saver intern', 1, 'saver'],
#  [{'smooth user': 1}, 1, 'smooth user', 1, 'smooth'],
#  [{'close construction': 1}, 1, 'close construction', 1, 'close'],
#  [{'efficient encounter': 1}, 1, 'efficient encounter', 1, 'efficient'],
#  [{'great coordinating': 1}, 1, 'great coordinating', 1, 'great'],
#  [{'able help': 2,
#    'able answer': 4,
#    'hard help': 1,
#    'much help': 1,
#    'difficult way': 1,
#    'able solve': 1},
#   10,
#   'able answer',
#   6,
#   'much'],
#  [{'little week': 1, 'couple week': 1, 'little hour': 1},
#   3,
#   'little week',
#   3,
#   'little'],
#  [{'main coordinator': 1}, 1, 'main coordinator', 1, 'main'],
#  [{'similar position': 1, 'catered position': 1},
#   2,
#   'similar position',
#   2,
#   'similar'],
#  [{'fast day': 1}, 1, 'fast day', 1, 'fast'],
#  [{'professional need': 1,
#    'professional staff': 1,
#    'professional process': 1,
#    'professional nationwide': 1,
#    'professional way': 1},
#   5,
#   'professional need',
#   5,
#   'professional'],
#  [{'scheduled effort': 1}, 1, 'scheduled effort', 1, 'scheduled'],
#  [{'many lender': 1,
#    'several lender': 1,
#    'generous lender': 1,
#    'better lender': 1},
#   4,
#   'many lender',
#   4,
#   'several'],
#  [{'awesome deal': 1, 'awesome bonus': 1}, 2, 'awesome deal', 2, 'awesome'],
#  [{'attentive need': 1, 'attentive kind': 1, 'objective attentive': 1},
#   3,
#   'attentive need',
#   3,
#   'objective'],
#  [{'painless love': 1}, 1, 'painless love', 1, 'painless'],
#  [{'fourth year': 5, 'last year': 1, 'final year': 1},
#   7,
#   'fourth year',
#   3,
#   'last'],
#  [{'extra fund': 3,
#    'complete fund': 1,
#    'extra finance': 1,
#    'additional fund': 1,
#    'simple fund': 1,
#    'full fund': 1},
#   8,
#   'extra fund',
#   6,
#   'simple'],
#  [{'best rate': 3}, 3, 'best rate', 1, 'best'],
#  [{'real person': 3, 'real deal': 1}, 4, 'real person', 2, 'real'],
#  [{'large institution': 1, 'great institution': 1, 'large school': 1},
#   3,
#   'large institution',
#   3,
#   'large'],
#  [{'physical location': 2}, 2, 'physical location', 1, 'physical'],
#  [{'normal daytime': 1}, 1, 'normal daytime', 1, 'normal'],
#  [{'unique privilege': 1}, 1, 'unique privilege', 1, 'unique'],
#  [{'alex panacea': 1}, 1, 'alex panacea', 1, 'alex'],
#  [{'important thing': 1, 'relevant detail': 1},
#   2,
#   'important thing',
#   2,
#   'relevant'],
#  [{'rich parent': 1}, 1, 'rich parent', 1, 'rich'],
#  [{'prior banking': 1, 'future banking': 1, 'better banking': 1},
#   3,
#   'prior banking',
#   3,
#   'prior'],
#  [{'great correspondence': 1}, 1, 'great correspondence', 1, 'great'],
#  [{'first choice': 1, 'right choice': 1, 'first proceed': 1},
#   3,
#   'first choice',
#   3,
#   'right'],
#  [{'phenomenal experience': 1}, 1, 'phenomenal experience', 1, 'phenomenal'],
#  [{'professional training': 1,
#    'complete training': 1,
#    'fresh training': 1,
#    'recommend trainee': 1},
#   4,
#   'professional training',
#   4,
#   'recommend'],
#  [{'legitimate see': 1}, 1, 'legitimate see', 1, 'legitimate'],
#  [{'couple hour': 1, 'half hour': 1, 'odd hour': 1},
#   3,
#   'couple hour',
#   3,
#   'odd'],
#  [{'speak phone': 1,
#    'representative phone': 1,
#    'accessible phone': 2,
#    'personal phone': 1,
#    'human call': 1},
#   6,
#   'accessible phone',
#   5,
#   'speak'],
#  [{'frequent reminder': 1, 'appropriate reminder': 1},
#   2,
#   'frequent reminder',
#   2,
#   'frequent'],
#  [{'primary account': 1, 'available account': 1, 'actual account': 1},
#   3,
#   'primary account',
#   3,
#   'primary'],
#  [{'happy costumer': 1}, 1, 'happy costumer', 1, 'happy'],
#  [{'easier email': 1, 'several email': 1}, 2, 'easier email', 2, 'several'],
#  [{'federal interest': 1}, 1, 'federal interest', 1, 'federal'],
#  [{'entire time': 3}, 3, 'entire time', 1, 'entire'],
#  [{'strict requirement': 1, 'specific need': 1},
#   2,
#   'strict requirement',
#   2,
#   'strict'],
#  [{'fair interest': 2}, 2, 'fair interest', 1, 'fair'],
#  [{'quick cash': 1}, 1, 'quick cash', 1, 'quick'],
#  [{'quick painless': 1}, 1, 'quick painless', 1, 'quick'],
#  [{'efficient underwriting': 1, 'easy underwriting': 1},
#   2,
#   'efficient underwriting',
#   2,
#   'efficient'],
#  [{'honest application': 1}, 1, 'honest application', 1, 'honest'],
#  [{'happy service': 1}, 1, 'happy service', 1, 'happy'],
#  [{'high student': 1, 'professional student': 1, 'med student': 4},
#   6,
#   'med student',
#   3,
#   'professional'],
#  [{'unparalleled customer': 1}, 1, 'unparalleled customer', 1, 'unparalleled'],
#  [{'difficult time': 2, 'hard time': 1}, 3, 'difficult time', 2, 'hard'],
#  [{'amazing raquel': 1, 'straightforward raquel': 1},
#   2,
#   'amazing raquel',
#   2,
#   'straightforward'],
#  [{'helpful staff': 1, 'friendly staff': 3, 'personable staff': 1},
#   5,
#   'friendly staff',
#   3,
#   'personable'],
#  [{'great partner': 1}, 1, 'great partner', 1, 'great'],
#  [{'initial deposit': 1}, 1, 'initial deposit', 1, 'initial'],
#  [{'frantic cost': 1}, 1, 'frantic cost', 1, 'frantic'],
#  [{'worth peace': 1, 'much peace': 1}, 2, 'worth peace', 2, 'worth'],
#  [{'happy decision': 1}, 1, 'happy decision', 1, 'happy'],
#  [{'fast headache': 1}, 1, 'fast headache', 1, 'fast'],
#  [{'free prn': 1}, 1, 'free prn', 1, 'free'],
#  [{'best trust': 1, 'excellent trust': 1}, 2, 'best trust', 2, 'excellent'],
#  [{'multiple pre': 1}, 1, 'multiple pre', 1, 'multiple'],
#  [{'soft inquiry': 1}, 1, 'soft inquiry', 1, 'soft'],
#  [{'special shout': 1}, 1, 'special shout', 1, 'special'],
#  [{'alex kugler': 3, 'alex assistance': 1}, 4, 'alex kugler', 2, 'alex'],
#  [{'true definition': 1}, 1, 'true definition', 1, 'true'],
#  [{'speedy turnover': 1}, 1, 'speedy turnover', 1, 'speedy'],
#  [{'high card': 1}, 1, 'high card', 1, 'high'],
#  [{'medical loan': 1}, 1, 'medical loan', 1, 'medical'],
#  [{'fair repayment': 1}, 1, 'fair repayment', 1, 'fair'],
#  [{'easy identity': 1}, 1, 'easy identity', 1, 'easy'],
#  [{'new chapter': 1}, 1, 'new chapter', 1, 'new'],
#  [{'higher income': 1, 'future income': 1}, 2, 'higher income', 2, 'higher'],
#  [{'easy transaction': 2}, 2, 'easy transaction', 1, 'easy'],
#  [{'professional interaction': 1},
#   1,
#   'professional interaction',
#   1,
#   'professional'],
#  [{'amazing prompt': 1}, 1, 'amazing prompt', 1, 'amazing'],
#  [{'excellent expedient': 1, 'excellent resource': 2},
#   3,
#   'excellent resource',
#   2,
#   'excellent'],
#  [{'fast quality': 1}, 1, 'fast quality', 1, 'fast'],
#  [{'sincere recommendation': 1, 'recommend friend': 1},
#   2,
#   'sincere recommendation',
#   2,
#   'sincere'],
#  [{'full time': 1}, 1, 'full time', 1, 'full'],
#  [{'late payment': 2}, 2, 'late payment', 1, 'late'],
#  [{'red flag': 1}, 1, 'red flag', 1, 'red'],
#  [{'small mistake': 1}, 1, 'small mistake', 1, 'small'],
#  [{'correct approve': 1}, 1, 'correct approve', 1, 'correct'],
#  [{'expensive book': 1}, 1, 'expensive book', 1, 'expensive'],
#  [{'academic activity': 1}, 1, 'academic activity', 1, 'academic'],
#  [{'experian credit': 1}, 1, 'experian credit', 1, 'experian'],
#  [{'best way': 1, 'right way': 1}, 2, 'best way', 2, 'right'],
#  [{'bad effect': 2}, 2, 'bad effect', 1, 'bad'],
#  [{'entire debt': 1,
#    'large debt': 1,
#    'personal debt': 1,
#    'possible debt': 1,
#    'due debt': 1},
#   5,
#   'entire debt',
#   5,
#   'possible'],
#  [{'advertisement panacea': 1},
#   1,
#   'advertisement panacea',
#   1,
#   'advertisement'],
#  [{'illogical reason': 1, 'main reason': 2}, 3, 'main reason', 2, 'main'],
#  [{'usual keep': 1}, 1, 'usual keep', 1, 'usual'],
#  [{'quick love': 1, 'quick kind': 1}, 2, 'quick love', 2, 'quick'],
#  [{'early interest': 1}, 1, 'early interest', 1, 'early'],
#  [{'rare find': 1, 'impossible find': 1}, 2, 'rare find', 2, 'rare'],
#  [{'nice change': 1}, 1, 'nice change', 1, 'nice'],
#  [{'online bot': 1}, 1, 'online bot', 1, 'online'],
#  [{'efficient keeping': 1}, 1, 'efficient keeping', 1, 'efficient'],
#  [{'last month': 1, 'many month': 1}, 2, 'last month', 2, 'many'],
#  [{'personal touch': 1, 'personalized contact': 1},
#   2,
#   'personal touch',
#   2,
#   'personalized'],
#  [{'single person': 1}, 1, 'single person', 1, 'single'],
#  [{'happier attention': 1, 'happier website': 1},
#   2,
#   'happier attention',
#   2,
#   'happier'],
#  [{'cumbersome process': 1}, 1, 'cumbersome process', 1, 'cumbersome'],
#  [{'second time': 1, 'second year': 1}, 2, 'second time', 2, 'second'],
#  [{'technical difficulty': 2}, 2, 'technical difficulty', 1, 'technical'],
#  [{'several point': 1}, 1, 'several point', 1, 'several'],
#  [{'special opportunity': 1}, 1, 'special opportunity', 1, 'special'],
#  [{'several hit': 1}, 1, 'several hit', 1, 'several'],
#  [{'digital age': 1}, 1, 'digital age', 1, 'digital'],
#  [{'fortunate company': 1, 'precious company': 1},
#   2,
#   'fortunate company',
#   2,
#   'precious'],
#  [{'low income': 1, 'little salary': 1}, 2, 'low income', 2, 'low'],
#  [{'reliable company': 1, 'reputable company': 1},
#   2,
#   'reliable company',
#   2,
#   'reputable'],
#  [{'limited communication': 1}, 1, 'limited communication', 1, 'limited'],
#  [{'easy document': 1, 'simple paperwork': 1},
#   2,
#   'easy document',
#   2,
#   'simple'],
#  [{'personalized lending': 1}, 1, 'personalized lending', 1, 'personalized'],
#  [{'simple term': 1}, 1, 'simple term', 1, 'simple'],
#  [{'reasonable student': 1}, 1, 'reasonable student', 1, 'reasonable'],
#  [{'write review': 1}, 1, 'write review', 1, 'write'],
#  [{'financial accident': 1}, 1, 'financial accident', 1, 'financial'],
#  [{'mic drop': 1}, 1, 'mic drop', 1, 'mic'],
#  [{'net catch': 1}, 1, 'net catch', 1, 'net'],
#  [{'full weekend': 1}, 1, 'full weekend', 1, 'full'],
#  [{'easy decision': 1}, 1, 'easy decision', 1, 'easy'],
#  [{'crazy hour': 1}, 1, 'crazy hour', 1, 'crazy'],
#  [{'late midnight': 1}, 1, 'late midnight', 1, 'late'],
#  [{'many others': 1}, 1, 'many others', 1, 'many'],
#  [{'easy representative': 1}, 1, 'easy representative', 1, 'easy'],
#  [{'friendly fund': 1, 'personal fund': 1, 'informed fund': 1},
#   3,
#   'friendly fund',
#   3,
#   'personal'],
#  [{'multiple time': 1}, 1, 'multiple time', 1, 'multiple'],
#  [{'personalized service': 1, 'personal service': 1},
#   2,
#   'personalized service',
#   2,
#   'personalized'],
#  [{'responsive opening': 1}, 1, 'responsive opening', 1, 'responsive'],
#  [{'efficient kind': 1}, 1, 'efficient kind', 1, 'efficient'],
#  [{'first generation': 2}, 2, 'first generation', 1, 'first'],
#  [{'middle class': 1}, 1, 'middle class', 1, 'middle'],
#  [{'first phone': 1}, 1, 'first phone', 1, 'first'],
#  [{'massive priority': 1}, 1, 'massive priority', 1, 'massive'],
#  [{'thoughtful approach': 1}, 1, 'thoughtful approach', 1, 'thoughtful'],
#  [{'expensive city': 1}, 1, 'expensive city', 1, 'expensive'],
#  [{'enough physician': 1}, 1, 'enough physician', 1, 'enough'],
#  [{'similar situation': 1, 'unusual circumstance': 1},
#   2,
#   'similar situation',
#   2,
#   'unusual'],
#  [{'nice love': 1, 'overall love': 1}, 2, 'nice love', 2, 'overall'],
#  [{'attentive customer': 1, 'focused customer': 1},
#   2,
#   'attentive customer',
#   2,
#   'focused'],
#  [{'fast employee': 1}, 1, 'fast employee', 1, 'fast'],
#  [{'def work': 1}, 1, 'def work', 1, 'def'],
#  [{'super kind': 1}, 1, 'super kind', 1, 'super'],
#  [{'residant prn': 1}, 1, 'residant prn', 1, 'residant'],
#  [{'complete pay': 1}, 1, 'complete pay', 1, 'complete'],
#  [{'helpful concierge': 1}, 1, 'helpful concierge', 1, 'helpful'],
#  [{'private practice': 1}, 1, 'private practice', 1, 'private'],
#  [{'financial future': 1, 'financial life': 2, 'future earnings': 1},
#   4,
#   'financial life',
#   3,
#   'future'],
#  [{'available answer': 1, 'available question': 4},
#   5,
#   'available question',
#   2,
#   'available'],
#  [{'great resource': 1, 'resourceful research': 1},
#   2,
#   'great resource',
#   2,
#   'resourceful'],
#  [{'amazing people': 1, 'fantastic organization': 1},
#   2,
#   'amazing people',
#   2,
#   'fantastic'],
#  [{'respectful lack': 1}, 1, 'respectful lack', 1, 'respectful'],
#  [{'new account': 3, 'potential account': 1},
#   4,
#   'new account',
#   2,
#   'potential'],
#  [{'fast interest': 1, 'fast asset': 1}, 2, 'fast interest', 2, 'fast'],
#  [{'simple team': 1, 'whole team': 1}, 2, 'simple team', 2, 'whole'],
#  [{'great texting': 1}, 1, 'great texting', 1, 'great'],
#  [{'easy need': 1}, 1, 'easy need', 1, 'easy'],
#  [{'complete residency': 2, 'prior residency': 1},
#   3,
#   'complete residency',
#   2,
#   'prior'],
#  [{'skeptical system': 1}, 1, 'skeptical system', 1, 'skeptical'],
#  [{'free process': 1}, 1, 'free process', 1, 'free'],
#  [{'wonderful start': 1}, 1, 'wonderful start', 1, 'wonderful'],
#  [{'friendly employee': 1}, 1, 'friendly employee', 1, 'friendly'],
#  [{'quick enroll': 1}, 1, 'quick enroll', 1, 'quick'],
#  [{'online minute': 1}, 1, 'online minute', 1, 'online'],
#  [{'helpful question': 1}, 1, 'helpful question', 1, 'helpful'],
#  [{'fast funding': 1}, 1, 'fast funding', 1, 'fast'],
#  [{'short coat': 1}, 1, 'short coat', 1, 'short'],
#  [{'free transfer': 1}, 1, 'free transfer', 1, 'free'],
#  [{'quick answer': 1}, 1, 'quick answer', 1, 'quick'],
#  [{'nationwide atm': 1}, 1, 'nationwide atm', 1, 'nationwide'],
#  [{'deceptive wording': 1}, 1, 'deceptive wording', 1, 'deceptive'],
#  [{'online purchase': 1}, 1, 'online purchase', 1, 'online'],
#  [{'mobile app': 1}, 1, 'mobile app', 1, 'mobile'],
#  [{'basic thing': 1, 'simple product': 1}, 2, 'basic thing', 2, 'simple'],
#  [{'great accessory': 1}, 1, 'great accessory', 1, 'great'],
#  [{'fast contract': 1}, 1, 'fast contract', 1, 'fast'],
#  [{'back time': 1}, 1, 'back time', 1, 'back'],
#  [{'small window': 1}, 1, 'small window', 1, 'small'],
#  [{'electronic interest': 1}, 1, 'electronic interest', 1, 'electronic'],
#  [{'financial breathing': 1}, 1, 'financial breathing', 1, 'financial'],
#  [{'future need': 1, 'future business': 1}, 2, 'future need', 2, 'future'],
#  [{'stressful transition': 1}, 1, 'stressful transition', 1, 'stressful'],
#  [{'next step': 2}, 2, 'next step', 1, 'next'],
#  [{'weary applying': 1}, 1, 'weary applying', 1, 'weary'],
#  [{'healthier shape': 1}, 1, 'healthier shape', 1, 'healthier'],
#  [{'right track': 1}, 1, 'right track', 1, 'right'],
#  [{'whole picture': 1}, 1, 'whole picture', 1, 'whole'],
#  [{'back question': 1}, 1, 'back question', 1, 'back'],
#  [{'helpful return': 1}, 1, 'helpful return', 1, 'helpful'],
#  [{'good employer': 1}, 1, 'good employer', 1, 'good'],
#  [{'clear term': 2}, 2, 'clear term', 1, 'clear'],
#  [{'costly season': 1}, 1, 'costly season', 1, 'costly'],
#  [{'good description': 1}, 1, 'good description', 1, 'good'],
#  [{'wonderful team': 1, 'entire team': 2}, 3, 'entire team', 2, 'wonderful'],
#  [{'pushed thing': 1}, 1, 'pushed thing', 1, 'pushed'],
#  [{'absolute pleasure': 1}, 1, 'absolute pleasure', 1, 'absolute'],
#  [{'real time': 1}, 1, 'real time', 1, 'real'],
#  [{'great move': 1}, 1, 'great move', 1, 'great'],
#  [{'transparent communication': 2},
#   2,
#   'transparent communication',
#   1,
#   'transparent'],
#  [{'easy breeze': 1}, 1, 'easy breeze', 1, 'easy'],
#  [{'able talk': 1, 'online chat': 1, 'able call': 1},
#   3,
#   'able talk',
#   3,
#   'online'],
#  [{'financial package': 1}, 1, 'financial package', 1, 'financial'],
#  [{'predatory work': 1}, 1, 'predatory work', 1, 'predatory'],
#  [{'hard support': 1}, 1, 'hard support', 1, 'hard'],
#  [{'tough find': 1}, 1, 'tough find', 1, 'tough'],
#  [{'patient kind': 1}, 1, 'patient kind', 1, 'patient'],
#  [{'single complaint': 1}, 1, 'single complaint', 1, 'single'],
#  [{'approachable question': 1}, 1, 'approachable question', 1, 'approachable'],
#  [{'continual outreach': 1}, 1, 'continual outreach', 1, 'continual'],
#  [{'costumer service': 1}, 1, 'costumer service', 1, 'costumer'],
#  [{'regular job': 1}, 1, 'regular job', 1, 'regular'],
#  [{'representative company': 1},
#   1,
#   'representative company',
#   1,
#   'representative'],
#  [{'amazing think': 1}, 1, 'amazing think', 1, 'amazing'],
#  [{'answered question': 2}, 2, 'answered question', 1, 'answered'],
#  [{'away parker': 1}, 1, 'away parker', 1, 'away'],
#  [{'available walk': 1}, 1, 'available walk', 1, 'available'],
#  [{'ongoing relationship': 1}, 1, 'ongoing relationship', 1, 'ongoing'],
#  [{'many classmate': 1}, 1, 'many classmate', 1, 'many'],
#  [{'fast response': 1, 'efficient response': 1},
#   2,
#   'fast response',
#   2,
#   'fast'],
#  [{'clear instruction': 1}, 1, 'clear instruction', 1, 'clear'],
#  [{'fast decision': 1}, 1, 'fast decision', 1, 'fast'],
#  [{'fast guiding': 1}, 1, 'fast guiding', 1, 'fast'],
#  [{'top notch': 1}, 1, 'top notch', 1, 'top'],
#  [{'resident loan': 1}, 1, 'resident loan', 1, 'resident'],
#  [{'personal detail': 1}, 1, 'personal detail', 1, 'personal'],
#  [{'huge lifesaver': 1}, 1, 'huge lifesaver', 1, 'huge'],
#  [{'much frustration': 1}, 1, 'much frustration', 1, 'much'],
#  [{'recommend use': 1}, 1, 'recommend use', 1, 'recommend'],
#  [{'electronic course': 1}, 1, 'electronic course', 1, 'electronic'],
#  [{'financial stability': 1}, 1, 'financial stability', 1, 'financial'],
#  [{'next year': 1}, 1, 'next year', 1, 'next'],
#  [{'easy end': 1}, 1, 'easy end', 1, 'easy'],
#  [{'minor snag': 1}, 1, 'minor snag', 1, 'minor'],
#  [{'middle icu': 1}, 1, 'middle icu', 1, 'middle'],
#  [{'little documentation': 1}, 1, 'little documentation', 1, 'little'],
#  [{'ridiculous option': 1}, 1, 'ridiculous option', 1, 'ridiculous'],
#  [{'friendly spot': 1}, 1, 'friendly spot', 1, 'friendly'],
#  [{'wonderful gentleman': 1}, 1, 'wonderful gentleman', 1, 'wonderful'],
#  [{'reputable institution': 1}, 1, 'reputable institution', 1, 'reputable'],
#  [{'new service': 1}, 1, 'new service', 1, 'new'],
#  [{'difficult prn': 1}, 1, 'difficult prn', 1, 'difficult'],
#  [{'fantastic customer': 1}, 1, 'fantastic customer', 1, 'fantastic'],
#  [{'easy swag': 1}, 1, 'easy swag', 1, 'easy'],
#  [{'able sign': 1}, 1, 'able sign', 1, 'able'],
#  [{'early afternoon': 1}, 1, 'early afternoon', 1, 'early'],
#  [{'next business': 1}, 1, 'next business', 1, 'next'],
#  [{'busy nd': 1}, 1, 'busy nd', 1, 'busy'],
#  [{'enough update': 1}, 1, 'enough update', 1, 'enough'],
#  [{'last minute': 1}, 1, 'last minute', 1, 'last'],
#  [{'new checking': 2}, 2, 'new checking', 1, 'new'],
#  [{'medical resident': 1}, 1, 'medical resident', 1, 'medical'],
#  [{'online interface': 1}, 1, 'online interface', 1, 'online'],
#  [{'joined family': 1}, 1, 'joined family', 1, 'joined'],
#  [{'important feel': 1}, 1, 'important feel', 1, 'important'],
#  [{'easy set': 1}, 1, 'easy set', 1, 'easy'],
#  [{'low maintenance': 1}, 1, 'low maintenance', 1, 'low'],
#  [{'sure question': 1}, 1, 'sure question', 1, 'sure'],
#  [{'free checking': 1}, 1, 'free checking', 1, 'free'],
#  [{'happier bank': 1}, 1, 'happier bank', 1, 'happier'],
#  [{'simple knowledge': 1}, 1, 'simple knowledge', 1, 'simple'],
#  [{'robust ability': 1}, 1, 'robust ability', 1, 'robust']]

# %%
df = pd.DataFrame(final_result,columns=["similar_words_and_count","count_of_similar_words","most_used_similar_word","total_similar_words", "associated_words"])

# %%
sorted_df = df.sort_values('total_similar_words',ascending=False).reset_index(drop=True)

# %%
sorted_df
# Out:
#                                similar_words_and_count  \
# 0    {'easy loan': 2, 'private loan': 4, 'helpful l...
# 1    {'financial transaction': 2, 'financial servic...
# 2    {'amazing job': 2, 'wonderful work': 2, 'amazi...
# 3    {'professional customer': 1, 'professional off...
# 4    {'efficient service': 1, 'excellent service': ...
# ..                                                 ...
# 353                              {'early interest': 1}
# 354                                 {'nice change': 1}
# 355                                  {'online bot': 1}
# 356                           {'efficient keeping': 1}
# 357                              {'robust ability': 1}
#
#      count_of_similar_words most_used_similar_word  total_similar_words  \
# 0                        50          personal loan                   23
# 1                        33    financial situation                   23
# 2                        69       great experience                   18
# 3                        39     excellent customer                   15
# 4                        23      excellent service                   14
# ..                      ...                    ...                  ...
# 353                       1         early interest                    1
# 354                       1            nice change                    1
# 355                       1             online bot                    1
# 356                       1      efficient keeping                    1
# 357                       1         robust ability                    1
#
#     associated_words
# 0        transparent
# 1              whole
# 2          wonderful
# 3          wonderful
# 4          wonderful
# ..               ...
# 353            early
# 354             nice
# 355           online
# 356        efficient
# 357           robust
#
# [358 rows x 5 columns]

# %%
sorted_df.to_csv("/home/heptagon/Desktop/nps_review_analysis/dataset/BankPanacea_detail_associated_words.csv", index=False)

# %%
print((sorted_df.most_used_similar_word).to_list()[:20])
# Out:
# ['personal loan', 'financial situation', 'great experience', 'excellent customer', 'excellent service', 'grateful help', 'medical student', 'excellent communication', 'good thing', 'personal banker', 'online bank', 'wonderful experience', 'easy application', 'hard credit', 'whole process', 'recommend panacea', 'financial need', 'financial institution', 'efficient process', 'high interest']

# %%
print((sorted_df.associated_words).to_list()[:20])
# Out:
# ['transparent', 'whole', 'wonderful', 'wonderful', 'wonderful', 'willing', 'young', 'unparalleled', 'true', 'straightforward', 'regular', 'wonderful', 'straightforward', 'tremendous', 'whole', 'recommend', 'financial', 'financial', 'tedious', 'highest']

# %%
# Problem Statement : Now can you find out the keywords or expressions related to these keywords
#   Ex: Battery: Good, bad, slow charging etc, for wach keyword

# we are getting list of keywords so
# 1. currently taking 1st most word from the keywords
# 2. Thinking : To apply a specific Algo on entire datasets
